# %% [markdown]
# # Визуализация в Pandas

# %%
import pandas as pd
import numpy as np

# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_vacancy = pd.read_csv('hh_vacancy.csv')
df_vacancy = df_vacancy.sample(frac=0.2)
df_vacancy
# Out:
#              id  area_id                     area_name  employer_id  \
# 2516   25402352        1                        Москва     618956.0
# 6909   22717887       53                     Краснодар    2118134.0
# 11119  24952632       88                        Казань     156424.0
# 17116  25041489        1                        Москва      78638.0
# 9540   24263857       49                         Киров     675435.0
# 4916   23192648       43                        Калуга     725989.0
# 11615  14291886        3                  Екатеринбург      71812.0
# 13018  24835070        3                  Екатеринбург      41862.0
# 8796   25662761       54                    Красноярск     869546.0
# 19611  25650397        2               Санкт-Петербург    2520442.0
# 15108  24478297       98                     Ульяновск       1740.0
# 5154   25360116       61                    Йошкар-Ола    1136961.0
# 5783   25226311        1                        Москва       1057.0
# ...

# %%
df_vacancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3967 entries, 2516 to 714
# Data columns (total 18 columns):
# id                     3967 non-null int64
# area_id                3967 non-null int64
# area_name              3967 non-null object
# employer_id            3961 non-null float64
# employment_id          3958 non-null object
# employment_name        3958 non-null object
# experience_id          3958 non-null object
# experience_name        3958 non-null object
# key_skills             1372 non-null object
# name                   3967 non-null object
# published_at           3967 non-null object
# salary_currency        2132 non-null object
# salary_from            1998 non-null float64
# salary_to              947 non-null float64
# schedule_id            3958 non-null object
# schedule_name          3958 non-null object
# specialization_id      3967 non-null int64
# specialization_name    3967 non-null object
# dtypes: float64(3), int64(3), object(12)
# ...

# %%
df_vacancy.describe()
# Out:
#                  id      area_id   employer_id    salary_from      salary_to  \
# count  3.967000e+03  3967.000000  3.961000e+03    1998.000000     947.000000
# mean   2.471575e+07   272.989917  7.153049e+05   53005.740741   85391.995776
# std    1.457677e+06   712.666606  8.833045e+05   36185.814703   57082.318250
# min    7.160726e+06     1.000000  1.900000e+01      30.000000     170.000000
# 25%    2.466296e+07     1.000000  3.873900e+04   30000.000000   40000.000000
# 50%    2.526053e+07     4.000000  1.971350e+05   43000.000000   70000.000000
# 75%    2.548276e+07    87.000000  1.122462e+06   70000.000000  120000.000000
# max    2.568461e+07  5120.000000  3.391409e+06  250000.000000  400000.000000
#
#        specialization_id
# count        3967.000000
# mean            3.624149
# std             5.072361
# min             1.000000
# 25%             1.000000
# 50%             1.000000
# 75%             4.000000
# max            26.000000

# %%
df_cities = pd.read_csv('cities.csv')
df_cities.head()
# Out:
#      Индекс Тип региона     Регион Тип района Район Тип города          Город  \
# 0  385200.0        Респ     Адыгея        NaN   NaN          г       Адыгейск
# 1  385000.0        Респ     Адыгея        NaN   NaN          г         Майкоп
# 2  649000.0        Респ      Алтай        NaN   NaN          г  Горно-Алтайск
# 3  658125.0        край  Алтайский        NaN   NaN          г         Алейск
# 4  656000.0        край  Алтайский        NaN   NaN          г        Барнаул
#
#   Тип н/п  Н/п      Код КЛАДР    ...    Уровень по ФИАС  \
# 0     NaN  NaN   100000200000    ...           4: город
# 1     NaN  NaN   100000100000    ...           4: город
# 2     NaN  NaN   400000100000    ...           4: город
# 3     NaN  NaN  2200000200000    ...           4: город
# 4     NaN  NaN  2200000100000    ...           4: город
#
#   Признак центра района или региона    Код ОКАТО     Код ОКТМО  Код ИФНС  \
# 0                                 0  79403000000  7.970300e+10       107
# ...

# %% [markdown]
# ## Гистограмма

# %%
df_vacancy['employment_name'].hist()

# %%
df_vacancy['salary_from'].hist(bins=30)

# %% [markdown]
# ## Распределение

# %%
df_vacancy['salary_from'].plot.kde()

# %% [markdown]
# ## Ящик с усами

# %%
df_vacancy.boxplot(column='salary_from')

# %% [markdown]
# Для выбранных данных:

# %%
df_vacancy.loc[df_vacancy.area_name == 'Пермь'].boxplot(column='salary_from')

# %% [markdown]
# Группировка по какому-либо признаку:

# %%
df_vacancy.boxplot(column='salary_from',  by='experience_name', figsize=(10,10))
plt.show()

# %% [markdown]
# ## Диаграмма рассеивания

# %%
df_cities.plot.scatter(x='Долгота', y='Широта')

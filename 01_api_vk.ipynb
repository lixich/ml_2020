# %% [markdown]
# # API Вконтакте

# %% [markdown]
# API Вконтакте — это интерфейс, который позволяет получать информацию из базы данных vk.com с помощью http-запросов к специальному серверу. Вам не нужно знать в подробностях, как устроена база, из каких таблиц и полей каких типов она состоит — достаточно того, что API-запрос об этом «знает».
#
# Например, для получения данных о пользователе с идентификатором 210700286 необходимо составить запрос такого вида: https://api.vk.com/method/users.get?user_id=210700286&v=5.52
#
# Рассмотрим отдельно все его составляющие:
# * https:// — протокол соединения.
# * api.vk.com/method — адрес API-сервиса.
# * users.get — название метода API ВКонтакте.
# * ?user_id=210700286&v=5.52 — параметры запроса.
#
# В ответ сервер вернет JSON-объект с запрошенными данными (или сообщение об ошибке, если что-то пошло не так):
#
# ```{"response":[{"id":210700286,"first_name":"Lindsey","last_name":"Stirling"}]}```

# %%
import requests
import numpy as np

access_token = 'ff657386ff657386ff657386f0ff0b1b2afff65ff657386a28c242ff8cbed4f0f5d7ee5'
api_version = '5.89'
parametrs = {
    'access_token': access_token,
    'v': api_version,
    'group_id': 'megapteka'
}
method_name = 'groups.getById'
r = requests.get('https://api.vk.com/method/' + method_name, params=parametrs)
r.json()
# Out:
# {'response': [{'id': 157033364,
#    'is_closed': 0,
#    'name': 'MEGAPTEKA.RU⠀|⠀МЕГАПТЕКА.РУ — поиск лекарств',
#    'photo_100': 'https://sun3-13.userapi.com/impf/c840025/v840025390/765bf/Fc9HvD-kw8Y.jpg?size=100x0&quality=88&crop=0,0,200,200&sign=9ecb99bd4f52c4678926793cf0f72099&c_uniq_tag=u4xwc_SM5lHHx-6HcxTmUd-ImibR9x8kKoI_PJ3lsrE&ava=1',
#    'photo_200': 'https://sun3-13.userapi.com/impf/c840025/v840025390/765bf/Fc9HvD-kw8Y.jpg?size=200x0&quality=88&crop=0,0,200,200&sign=414747b180cebdaf9afab946105415ff&c_uniq_tag=KUmqT3RAu3nHEMjPyaMOAeeeLxtILmOMyABValrEQE0&ava=1',
#    'photo_50': 'https://sun3-13.userapi.com/impf/c840025/v840025390/765bf/Fc9HvD-kw8Y.jpg?size=50x0&quality=88&crop=0,0,200,200&sign=eb9234738dad3ba86002a8ec96107026&c_uniq_tag=AqcAm6KrbVhSGumo6AJjjl5J2K2X0wKhpmhVE0lRMVM&ava=1',
#    'screen_name': 'megapteka',
#    'type': 'page'}]}

# %%
groups = ['domoidostavim', 'megapteka', 'eshfresh59', 'semyaperm', 'pizzburg']
parametrs = {
    'access_token': access_token,
    'v': api_version,
    'group_id': 'megapteka',
    'fields': 'name,sex,city',
    'offset': 0
}
method_name = 'groups.getMembers'
r = requests.get('https://api.vk.com/method/' +\
                 method_name, params=parametrs)
r.json()
# Out:
# {'response': {'count': 2495,
#   'items': [{'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Yana',
#     'id': 114886,
#     'is_closed': False,
#     'last_name': 'Valyuzhenich',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Anastasia',
#     'id': 145198,
#     'is_closed': False,
#     'last_name': 'Chistyakova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Viktor',
#     'id': 244850,
#     'is_closed': False,
#     'last_name': 'Andreenko',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Natasha',
#     'id': 301593,
#     'is_closed': False,
#     'last_name': 'Egorova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Katerina',
#     'id': 342238,
#     'is_closed': True,
#     'last_name': 'Vyatkina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 1, 'title': 'Moscow'},
#     'first_name': 'Vlad',
#     'id': 615271,
#     'is_closed': False,
#     'last_name': 'Dyakonov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Mo',
#     'id': 1215634,
#     'is_closed': False,
#     'last_name': 'Mo',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 133, 'title': 'Sochi'},
#     'first_name': 'Nadezhda',
#     'id': 1257717,
#     'is_closed': False,
#     'last_name': 'Kontsevaya',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Dmitry',
#     'id': 1354430,
#     'is_closed': False,
#     'last_name': 'Grishin',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 21856, 'title': 'Troitsk'},
#     'first_name': 'Alyona',
#     'id': 1383629,
#     'is_closed': False,
#     'last_name': 'Anshina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Svetlana',
#     'id': 1429574,
#     'is_closed': True,
#     'last_name': 'Osipova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Lesya',
#     'id': 1529682,
#     'is_closed': False,
#     'last_name': 'Petukhova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 93, 'title': 'Nizhnevartovsk'},
#     'first_name': 'Anna',
#     'id': 1570323,
#     'is_closed': False,
#     'last_name': 'Dundukova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Artyom',
#     'id': 1614943,
#     'is_closed': False,
#     'last_name': 'Filimonov',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 138, 'title': 'Syktyvkar'},
#     'first_name': 'Olesya',
#     'id': 1806582,
#     'is_closed': True,
#     'last_name': 'Avtamonova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 138, 'title': 'Syktyvkar'},
#     'first_name': 'Tatyana',
#     'id': 1885978,
#     'is_closed': True,
#     'last_name': 'Kabanova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Darya',
#     'id': 1981502,
#     'is_closed': False,
#     'last_name': 'Zakharova-Trifonova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Tatyana',
#     'id': 2256714,
#     'is_closed': False,
#     'last_name': 'Chesnykh',
#     'sex': 1},
#    {'can_access_closed': False,
#     'first_name': 'Larisa',
#     'id': 2354693,
#     'is_closed': True,
#     'last_name': 'Matyushenko',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Natalya',
#     'id': 2563583,
#     'is_closed': False,
#     'last_name': 'Shulgina',
#     'sex': 1},
#    {'deactivated': 'deleted',
#     'first_name': 'Yulia',
#     'id': 2567413,
#     'last_name': 'Shishkova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Dina',
#     'id': 2866390,
#     'is_closed': False,
#     'last_name': 'Koshka',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Natasha',
#     'id': 2961711,
#     'is_closed': False,
#     'last_name': 'Vladimirova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'first_name': 'Rustam',
#     'id': 3024324,
#     'is_closed': True,
#     'last_name': 'Gabitov',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Veronika',
#     'id': 3061376,
#     'is_closed': True,
#     'last_name': 'Ilmaz',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 1054308, 'title': 'Domodedovo'},
#     'first_name': 'Shaitan',
#     'id': 3448957,
#     'is_closed': False,
#     'last_name': 'Bandittes',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Elenochka',
#     'id': 3503045,
#     'is_closed': False,
#     'last_name': 'Goncharova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 156, 'title': 'Chaykovsky'},
#     'first_name': 'Tatyana',
#     'id': 3518379,
#     'is_closed': False,
#     'last_name': 'Kalabina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 49, 'title': 'Yekaterinburg'},
#     'first_name': 'Ekaterina',
#     'id': 3537596,
#     'is_closed': False,
#     'last_name': 'Akimova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Anastasia',
#     'id': 3538224,
#     'is_closed': False,
#     'last_name': 'Rylova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Oksana',
#     'id': 3613752,
#     'is_closed': False,
#     'last_name': 'Skovron',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Ekaterina',
#     'id': 3644753,
#     'is_closed': False,
#     'last_name': 'Karpovich',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Ekaterina',
#     'id': 3681734,
#     'is_closed': False,
#     'last_name': 'Starikova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 14300, 'title': 'Kizner'},
#     'first_name': 'Artyom',
#     'id': 3783597,
#     'is_closed': False,
#     'last_name': 'Artyomin',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Tatyana',
#     'id': 4169622,
#     'is_closed': False,
#     'last_name': 'Gridasova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 158, 'title': 'Chelyabinsk'},
#     'first_name': 'Ksenia',
#     'id': 4246879,
#     'is_closed': False,
#     'last_name': 'Fedotova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Maria',
#     'id': 4276728,
#     'is_closed': False,
#     'last_name': 'Ogibalova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Ekaterina',
#     'id': 4346785,
#     'is_closed': False,
#     'last_name': 'Zagidullina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Maria',
#     'id': 4382491,
#     'is_closed': False,
#     'last_name': 'Kalashnik',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Svetlana',
#     'id': 4420064,
#     'is_closed': False,
#     'last_name': 'Shveina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Anna',
#     'id': 4545399,
#     'is_closed': False,
#     'last_name': 'Kryuchkova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Anna',
#     'id': 4623965,
#     'is_closed': False,
#     'last_name': 'Shpenova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 123, 'title': 'Samara'},
#     'first_name': 'Yulia',
#     'id': 4715868,
#     'is_closed': False,
#     'last_name': 'Abramova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Anna',
#     'id': 4743770,
#     'is_closed': True,
#     'last_name': 'Gorbunova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Marina',
#     'id': 4790617,
#     'is_closed': False,
#     'last_name': 'Rudina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Ilya',
#     'id': 4848345,
#     'is_closed': False,
#     'last_name': 'Moiseev',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Tatyana',
#     'id': 4850402,
#     'is_closed': False,
#     'last_name': 'Tolkovaya',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 80, 'title': 'Lyubertsy'},
#     'first_name': 'Svetlana',
#     'id': 4851548,
#     'is_closed': False,
#     'last_name': 'Baryshnikova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Vladimir',
#     'id': 4887555,
#     'is_closed': False,
#     'last_name': 'Kazantsev',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Darya',
#     'id': 4892014,
#     'is_closed': False,
#     'last_name': 'Skidnova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Semen',
#     'id': 5006906,
#     'is_closed': False,
#     'last_name': 'Yuzhanin',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Alina',
#     'id': 5008436,
#     'is_closed': True,
#     'last_name': 'Galanova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Polina',
#     'id': 5082625,
#     'is_closed': False,
#     'last_name': 'Spirina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 1386, 'title': 'Sergiev Posad'},
#     'first_name': 'Dmitry',
#     'id': 5092240,
#     'is_closed': True,
#     'last_name': 'Lobushev',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 750, 'title': 'Bruxelles'},
#     'first_name': 'Evgenia',
#     'id': 5164212,
#     'is_closed': True,
#     'last_name': 'Totmyanina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Nuria',
#     'id': 5179533,
#     'is_closed': False,
#     'last_name': 'Zhdanova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Galina',
#     'id': 5180391,
#     'is_closed': False,
#     'last_name': 'Kuznetsova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Olya',
#     'id': 5305838,
#     'is_closed': False,
#     'last_name': 'Pechenkina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 93, 'title': 'Nizhnevartovsk'},
#     'first_name': 'Olga',
#     'id': 5439395,
#     'is_closed': True,
#     'last_name': 'Ovsyannikova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Oksana',
#     'id': 5512410,
#     'is_closed': True,
#     'last_name': 'Shilova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 95, 'title': 'Nizhny Novgorod'},
#     'first_name': 'Elena',
#     'id': 5612031,
#     'is_closed': True,
#     'last_name': 'Koscheeva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 16969, 'title': 'Tuxa'},
#     'first_name': 'Anastasia',
#     'id': 5639814,
#     'is_closed': True,
#     'last_name': 'Konosova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Ekaterina',
#     'id': 6222962,
#     'is_closed': False,
#     'last_name': 'Gridina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Svetlana',
#     'id': 6238807,
#     'is_closed': True,
#     'last_name': 'Tronina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 72, 'title': 'Krasnodar'},
#     'first_name': 'Anna',
#     'id': 6357618,
#     'is_closed': False,
#     'last_name': 'Maltseva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 5574, 'title': 'Kungur'},
#     'first_name': 'Maria',
#     'id': 6406432,
#     'is_closed': True,
#     'last_name': 'Doronina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Lena',
#     'id': 6515796,
#     'is_closed': False,
#     'last_name': 'Kashirina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Maria',
#     'id': 6794729,
#     'is_closed': True,
#     'last_name': 'Zheltonogova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 1150591, 'title': 'Kylasovo'},
#     'first_name': 'Eduard',
#     'id': 7003716,
#     'is_closed': True,
#     'last_name': 'Startsev',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 60, 'title': 'Kazan'},
#     'first_name': 'Andrey',
#     'id': 7006469,
#     'is_closed': False,
#     'last_name': 'Pavlov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 45, 'title': 'Glazov'},
#     'first_name': 'Natalya',
#     'id': 7036227,
#     'is_closed': False,
#     'last_name': 'Yugova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Anna',
#     'id': 7077549,
#     'is_closed': False,
#     'last_name': 'Fattakhova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 22, 'title': 'Arkhangelsk'},
#     'first_name': 'Nadezhda',
#     'id': 7099500,
#     'is_closed': False,
#     'last_name': 'Galaktionova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Anna',
#     'id': 7156486,
#     'is_closed': False,
#     'last_name': 'Dubova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Igor',
#     'id': 7262335,
#     'is_closed': True,
#     'last_name': 'Katunin',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 190, 'title': 'Vorkuta'},
#     'first_name': 'Zhanna',
#     'id': 7448052,
#     'is_closed': True,
#     'last_name': 'Sambor',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Olga',
#     'id': 7555818,
#     'is_closed': False,
#     'last_name': 'Borzenko',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Tatyana',
#     'id': 7715486,
#     'is_closed': False,
#     'last_name': 'Khoroshukhina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 4410, 'title': 'Kudymkar'},
#     'first_name': 'Nadezhda',
#     'id': 7728944,
#     'is_closed': False,
#     'last_name': 'Krokhaleva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Alexey',
#     'id': 7897817,
#     'is_closed': False,
#     'last_name': 'Sukhikh',
#     'sex': 2},
#    {'can_access_closed': True,
#     'first_name': 'Anastasia',
#     'id': 7914658,
#     'is_closed': False,
#     'last_name': 'Galimullina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Anna',
#     'id': 7941200,
#     'is_closed': False,
#     'last_name': 'Vedernikova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 93, 'title': 'Nizhnevartovsk'},
#     'first_name': 'Artem',
#     'id': 8022371,
#     'is_closed': False,
#     'last_name': 'Shitov',
#     'sex': 2},
#    {'can_access_closed': False,
#     'first_name': 'Irina',
#     'id': 8036893,
#     'is_closed': True,
#     'last_name': 'Lebedeva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Sergey',
#     'id': 8044268,
#     'is_closed': True,
#     'last_name': 'Ponomaryov',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 1710182, 'title': 'Rio de Janeiro'},
#     'first_name': 'Natalya',
#     'id': 8300613,
#     'is_closed': True,
#     'last_name': 'Bazhina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Ekaterina',
#     'id': 8454228,
#     'is_closed': True,
#     'last_name': 'Pogoreltseva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Dmitry',
#     'id': 8570455,
#     'is_closed': True,
#     'last_name': 'Yagodnikov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 149, 'title': 'Ulyanovsk'},
#     'first_name': 'Ekaterina',
#     'id': 8642241,
#     'is_closed': False,
#     'last_name': 'Dmitrichenko',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Evgeny',
#     'id': 8677927,
#     'is_closed': False,
#     'last_name': 'Bobrov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 133, 'title': 'Sochi'},
#     'first_name': 'Svetlana',
#     'id': 8701752,
#     'is_closed': False,
#     'last_name': 'Poltaratskaya',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Igor',
#     'id': 8704065,
#     'is_closed': False,
#     'last_name': 'Blinov',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 93, 'title': 'Nizhnevartovsk'},
#     'first_name': 'Tatyana',
#     'id': 8858796,
#     'is_closed': True,
#     'last_name': 'Batsman',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Irina',
#     'id': 8892627,
#     'is_closed': False,
#     'last_name': 'Rumyantseva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 95, 'title': 'Nizhny Novgorod'},
#     'first_name': 'Natalya',
#     'id': 9047024,
#     'is_closed': False,
#     'last_name': 'Kucharina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Vladimir',
#     'id': 9124961,
#     'is_closed': False,
#     'last_name': 'Dobryakov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 1303, 'title': 'Krasnovishersk'},
#     'first_name': 'Yulia',
#     'id': 9188554,
#     'is_closed': False,
#     'last_name': 'Yakunina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Anna',
#     'id': 9191722,
#     'is_closed': False,
#     'last_name': 'Navarich',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Maria',
#     'id': 9221996,
#     'is_closed': False,
#     'last_name': 'Pyankova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'first_name': 'Natella',
#     'id': 9352205,
#     'is_closed': True,
#     'last_name': 'Vlyublennaya',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 60, 'title': 'Kazan'},
#     'first_name': 'Elena',
#     'id': 9363903,
#     'is_closed': False,
#     'last_name': 'Anisimova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 1, 'title': 'Moscow'},
#     'first_name': 'Maria',
#     'id': 9436423,
#     'is_closed': False,
#     'last_name': 'Kudryavtseva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Zazz',
#     'id': 9438808,
#     'is_closed': False,
#     'last_name': 'Offline',
#     'sex': 2},
#    {'can_access_closed': True,
#     'first_name': 'Tatyana',
#     'id': 9522782,
#     'is_closed': False,
#     'last_name': 'Nakaryakova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Svetlana',
#     'id': 9582809,
#     'is_closed': False,
#     'last_name': 'Korepanova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Ilya',
#     'id': 9656585,
#     'is_closed': False,
#     'last_name': 'Dubov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Tatyana',
#     'id': 9754658,
#     'is_closed': False,
#     'last_name': 'Beckenbauer',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Albina',
#     'id': 10026261,
#     'is_closed': True,
#     'last_name': 'Talipova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 133, 'title': 'Sochi'},
#     'first_name': 'Yulia',
#     'id': 10096164,
#     'is_closed': False,
#     'last_name': 'Markelova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 141, 'title': 'Tver'},
#     'first_name': 'Evgenia',
#     'id': 10107398,
#     'is_closed': True,
#     'last_name': 'Belyaeva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2117, 'title': 'Krasnokamsk'},
#     'first_name': 'Natalya',
#     'id': 10171264,
#     'is_closed': False,
#     'last_name': 'Sidyakina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Alexey',
#     'id': 10305147,
#     'is_closed': True,
#     'last_name': 'Khadenkov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Andrey',
#     'id': 10330038,
#     'is_closed': False,
#     'last_name': 'Konev',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 72, 'title': 'Krasnodar'},
#     'first_name': 'Olga',
#     'id': 10389057,
#     'is_closed': False,
#     'last_name': 'Lebedeva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 73, 'title': 'Krasnoyarsk'},
#     'first_name': 'Marina',
#     'id': 10404052,
#     'is_closed': False,
#     'last_name': 'Pokonechnykh',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 1, 'title': 'Moscow'},
#     'first_name': 'Ekaterina',
#     'id': 10428023,
#     'is_closed': True,
#     'last_name': 'Konovalova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Natalya',
#     'id': 10464351,
#     'is_closed': True,
#     'last_name': 'Bichevaya',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Ivan',
#     'id': 10627549,
#     'is_closed': False,
#     'last_name': 'Pavlov',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Elena',
#     'id': 10643963,
#     'is_closed': True,
#     'last_name': 'Kochakova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Maria',
#     'id': 10739815,
#     'is_closed': False,
#     'last_name': 'Makarova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Kristina',
#     'id': 10846925,
#     'is_closed': False,
#     'last_name': 'Ermalyuk',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Raya',
#     'id': 10938689,
#     'is_closed': False,
#     'last_name': 'Satybaldina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 138, 'title': 'Syktyvkar'},
#     'first_name': 'Lenok',
#     'id': 10972431,
#     'is_closed': False,
#     'last_name': 'Bachinskaya',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Anastasia',
#     'id': 11006160,
#     'is_closed': False,
#     'last_name': 'Sidorova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Yulia',
#     'id': 11052066,
#     'is_closed': False,
#     'last_name': 'Goncharova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 899, 'title': 'Berezniki'},
#     'first_name': 'Irina',
#     'id': 11327435,
#     'is_closed': False,
#     'last_name': 'Zhuravlyova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Olga',
#     'id': 11338564,
#     'is_closed': False,
#     'last_name': 'Ermolova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 135, 'title': 'Sterlitamak'},
#     'first_name': 'Evgeny',
#     'id': 11613497,
#     'is_closed': True,
#     'last_name': 'Aushev',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 26, 'title': 'Belgorod'},
#     'first_name': 'Anastasia',
#     'id': 11765328,
#     'is_closed': False,
#     'last_name': 'Putintseva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 136, 'title': 'Surgut'},
#     'first_name': 'Ruslan',
#     'id': 11830021,
#     'is_closed': False,
#     'last_name': 'Chuntonov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 93, 'title': 'Nizhnevartovsk'},
#     'first_name': 'Elena',
#     'id': 11971436,
#     'is_closed': False,
#     'last_name': 'Savelyeva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Anastasia',
#     'id': 12068547,
#     'is_closed': False,
#     'last_name': 'Zhuravleva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 891, 'title': 'Sortavala'},
#     'first_name': 'Galina',
#     'id': 12194666,
#     'is_closed': False,
#     'last_name': 'Shinareva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 483, 'title': 'Krasnogorsk'},
#     'first_name': 'Irina',
#     'id': 12330072,
#     'is_closed': True,
#     'last_name': 'Andreeva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Yulia',
#     'id': 12347120,
#     'is_closed': True,
#     'last_name': 'Naletova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 88, 'title': 'Naberezhnye Chelny'},
#     'first_name': 'Maria',
#     'id': 12360814,
#     'is_closed': False,
#     'last_name': 'Mingaleeva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 10833, 'title': 'Lysva'},
#     'first_name': 'Tanechka',
#     'id': 12524167,
#     'is_closed': False,
#     'last_name': 'Pechkina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 93, 'title': 'Nizhnevartovsk'},
#     'first_name': 'Kristina',
#     'id': 12644214,
#     'is_closed': False,
#     'last_name': 'Konovalova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Yulia',
#     'id': 12806198,
#     'is_closed': False,
#     'last_name': 'Lashina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Marat',
#     'id': 12949962,
#     'is_closed': False,
#     'last_name': 'Beysenbaev',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 4410, 'title': 'Kudymkar'},
#     'first_name': 'Ksenia',
#     'id': 12967755,
#     'is_closed': False,
#     'last_name': 'Isypova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 138, 'title': 'Syktyvkar'},
#     'first_name': 'Elina',
#     'id': 13174496,
#     'is_closed': False,
#     'last_name': 'Volkova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Andrey',
#     'id': 13335037,
#     'is_closed': False,
#     'last_name': 'Reznikov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'first_name': 'Natalya',
#     'id': 13374413,
#     'is_closed': False,
#     'last_name': 'Vorobyeva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Alexander',
#     'id': 13643211,
#     'is_closed': False,
#     'last_name': 'Pleshivykh',
#     'sex': 2},
#    {'can_access_closed': True,
#     'first_name': 'Nastya',
#     'id': 13741607,
#     'is_closed': False,
#     'last_name': 'Pozdeeva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Olesya',
#     'id': 13837304,
#     'is_closed': True,
#     'last_name': 'Tereschenko',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 157, 'title': 'Cheboxary'},
#     'first_name': 'Dmitry',
#     'id': 14039146,
#     'is_closed': False,
#     'last_name': 'Ivanov',
#     'sex': 2},
#    {'deactivated': 'deleted',
#     'first_name': 'DELETED',
#     'id': 14162966,
#     'last_name': '',
#     'sex': 2},
#    {'can_access_closed': True,
#     'first_name': 'Aleksandra',
#     'id': 14317378,
#     'is_closed': False,
#     'last_name': 'Otinova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 1, 'title': 'Moscow'},
#     'first_name': 'Svetlana',
#     'id': 14379830,
#     'is_closed': False,
#     'last_name': 'Antonova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Olya',
#     'id': 15048304,
#     'is_closed': True,
#     'last_name': '***',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 99, 'title': 'Novosibirsk'},
#     'first_name': 'Vasily',
#     'id': 15079303,
#     'is_closed': False,
#     'last_name': 'Samokhvalov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 156, 'title': 'Chaykovsky'},
#     'first_name': 'Yana',
#     'id': 15140372,
#     'is_closed': False,
#     'last_name': 'Klyachina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 60, 'title': 'Kazan'},
#     'first_name': 'Tatyana',
#     'id': 15163173,
#     'is_closed': False,
#     'last_name': 'Kolesnikova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 72, 'title': 'Krasnodar'},
#     'first_name': 'Irina',
#     'id': 15190583,
#     'is_closed': False,
#     'last_name': 'Makarova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Irina',
#     'id': 15225574,
#     'is_closed': False,
#     'last_name': 'Utrobina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 1299, 'title': 'Navapolatsk'},
#     'first_name': 'Larisa',
#     'id': 15286531,
#     'is_closed': True,
#     'last_name': 'Orlova-Divulskaya',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Marina',
#     'id': 15313272,
#     'is_closed': False,
#     'last_name': 'Madonova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 899, 'title': 'Berezniki'},
#     'first_name': 'Ekaterina',
#     'id': 15385596,
#     'is_closed': False,
#     'last_name': 'Onufrienko',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 1, 'title': 'Moscow'},
#     'first_name': 'Andrey',
#     'id': 15437015,
#     'is_closed': True,
#     'last_name': 'Andrianov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Taniko',
#     'id': 15443939,
#     'is_closed': False,
#     'last_name': 'Kozhanova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 58, 'title': 'Ishim'},
#     'first_name': 'Tatyana',
#     'id': 16006833,
#     'is_closed': False,
#     'last_name': 'Sukhanova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 147, 'title': 'Tyumen'},
#     'first_name': 'Maria',
#     'id': 16083930,
#     'is_closed': True,
#     'last_name': 'Nikolaevna',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Yana',
#     'id': 16132926,
#     'is_closed': False,
#     'last_name': 'Sharifulina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Yuliya',
#     'id': 16137785,
#     'is_closed': False,
#     'last_name': 'Savenko',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Tanyusha',
#     'id': 16161504,
#     'is_closed': False,
#     'last_name': 'Vanyukova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Yulia',
#     'id': 16236491,
#     'is_closed': True,
#     'last_name': 'Krivosheina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 22, 'title': 'Arkhangelsk'},
#     'first_name': 'Natalya',
#     'id': 16731363,
#     'is_closed': True,
#     'last_name': 'Andrianova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Alexey',
#     'id': 16737867,
#     'is_closed': False,
#     'last_name': 'Maltsev',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 99, 'title': 'Novosibirsk'},
#     'first_name': 'Natalya',
#     'id': 16931202,
#     'is_closed': False,
#     'last_name': 'Belich',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Regina',
#     'id': 17007006,
#     'is_closed': False,
#     'last_name': 'Rakhimova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 22, 'title': 'Arkhangelsk'},
#     'first_name': 'Olga',
#     'id': 17049458,
#     'is_closed': False,
#     'last_name': 'Vologdina(Patrusheva)',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 93, 'title': 'Nizhnevartovsk'},
#     'first_name': 'ELIZAVETA',
#     'id': 17273924,
#     'is_closed': False,
#     'last_name': 'MARAKUShA (KOKhAN)',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Irina',
#     'id': 17483268,
#     'is_closed': False,
#     'last_name': 'Komolova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 49, 'title': 'Yekaterinburg'},
#     'first_name': 'Ekaterina',
#     'id': 17507004,
#     'is_closed': True,
#     'last_name': 'Semenova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Yulia',
#     'id': 17559503,
#     'is_closed': False,
#     'last_name': 'Yurgel',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 22, 'title': 'Arkhangelsk'},
#     'first_name': 'Andrey',
#     'id': 17859352,
#     'is_closed': False,
#     'last_name': 'Orlov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Denis',
#     'id': 17901821,
#     'is_closed': False,
#     'last_name': 'Vikhrov',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Anastasia',
#     'id': 17902344,
#     'is_closed': True,
#     'last_name': 'Klisheva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 60, 'title': 'Kazan'},
#     'first_name': 'Rashid',
#     'id': 17932957,
#     'is_closed': False,
#     'last_name': 'Safiulin',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 144, 'title': 'Tomsk'},
#     'first_name': 'Yulia',
#     'id': 18034299,
#     'is_closed': False,
#     'last_name': 'Anisimova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 122, 'title': 'Ryazan'},
#     'first_name': 'Mikhail',
#     'id': 18081057,
#     'is_closed': True,
#     'last_name': 'Sorokin',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Nadezhda',
#     'id': 18235955,
#     'is_closed': False,
#     'last_name': 'Shvetsova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 147, 'title': 'Tyumen'},
#     'first_name': 'Yulia',
#     'id': 18242780,
#     'is_closed': True,
#     'last_name': 'Bagmutova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Masha',
#     'id': 18317944,
#     'is_closed': False,
#     'last_name': 'Yakunina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Maria',
#     'id': 18518691,
#     'is_closed': False,
#     'last_name': 'Medvedeva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'first_name': 'Evgeny',
#     'id': 18853389,
#     'is_closed': True,
#     'last_name': 'Kartashov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 6582, 'title': 'Chernushka'},
#     'first_name': 'Irina',
#     'id': 19027247,
#     'is_closed': False,
#     'last_name': 'Gerasimova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 22, 'title': 'Arkhangelsk'},
#     'first_name': 'Larisa',
#     'id': 19036160,
#     'is_closed': True,
#     'last_name': 'Markina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Sergey',
#     'id': 19313890,
#     'is_closed': False,
#     'last_name': 'Pugovkin',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Alyona',
#     'id': 19548168,
#     'is_closed': False,
#     'last_name': 'Bazhina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 382, 'title': 'Nefteyugansk'},
#     'first_name': 'Sabrina',
#     'id': 19930562,
#     'is_closed': True,
#     'last_name': 'Gasanova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'first_name': 'Alexandra',
#     'id': 20000975,
#     'is_closed': True,
#     'last_name': 'Kurmanova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Sveta',
#     'id': 20057404,
#     'is_closed': False,
#     'last_name': 'Erofeeva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Olesya',
#     'id': 20094333,
#     'is_closed': False,
#     'last_name': 'Komleva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Irina',
#     'id': 20428804,
#     'is_closed': False,
#     'last_name': 'Nikiforova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 158, 'title': 'Chelyabinsk'},
#     'first_name': 'Aygul',
#     'id': 20447125,
#     'is_closed': True,
#     'last_name': 'Mistyunina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 106, 'title': 'Orenburg'},
#     'first_name': 'Yana',
#     'id': 20458771,
#     'is_closed': False,
#     'last_name': 'Koroleva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Olya',
#     'id': 20467699,
#     'is_closed': False,
#     'last_name': 'Ketova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 132, 'title': 'Solikamsk'},
#     'first_name': 'Yulchik',
#     'id': 20509331,
#     'is_closed': True,
#     'last_name': 'Shashkina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 123, 'title': 'Samara'},
#     'first_name': 'Olesya',
#     'id': 20907738,
#     'is_closed': True,
#     'last_name': 'Kuznetsova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 66, 'title': 'Kirov'},
#     'first_name': 'Anyuta',
#     'id': 21007728,
#     'is_closed': False,
#     'last_name': 'Ikonnikova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Evgenia',
#     'id': 21019952,
#     'is_closed': False,
#     'last_name': 'Katargina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Elena',
#     'id': 21066041,
#     'is_closed': False,
#     'last_name': 'Koksharova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Tatyana',
#     'id': 21100380,
#     'is_closed': False,
#     'last_name': 'Tenyakova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Elena',
#     'id': 21284141,
#     'is_closed': True,
#     'last_name': 'Smirnova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Nadezhda',
#     'id': 21346037,
#     'is_closed': True,
#     'last_name': 'Cheremisova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 158, 'title': 'Chelyabinsk'},
#     'first_name': 'Dmitry',
#     'id': 21378730,
#     'is_closed': False,
#     'last_name': 'Kuzmin',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Anastasia',
#     'id': 21577995,
#     'is_closed': True,
#     'last_name': 'Kaletina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 17906, 'title': 'Ilinsko-Podomskoe'},
#     'first_name': 'Yulia',
#     'id': 21622551,
#     'is_closed': False,
#     'last_name': 'Vladimirova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Natalya',
#     'id': 21680701,
#     'is_closed': True,
#     'last_name': 'Kedrova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 158, 'title': 'Chelyabinsk'},
#     'first_name': 'Galina',
#     'id': 21880883,
#     'is_closed': False,
#     'last_name': 'Ivanova-Abdulina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 147, 'title': 'Tyumen'},
#     'first_name': 'Ekaterina',
#     'id': 21895787,
#     'is_closed': False,
#     'last_name': 'Abramova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 152, 'title': 'Ukhta'},
#     'first_name': 'Marina',
#     'id': 21919224,
#     'is_closed': True,
#     'last_name': 'Sukharnikova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 158, 'title': 'Chelyabinsk'},
#     'first_name': 'Nailya',
#     'id': 22072371,
#     'is_closed': True,
#     'last_name': 'Shafikova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Yury',
#     'id': 22181539,
#     'is_closed': True,
#     'last_name': 'Stepanov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 147, 'title': 'Tyumen'},
#     'first_name': 'Elizaveta',
#     'id': 22361697,
#     'is_closed': False,
#     'last_name': 'Bazanova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Olga',
#     'id': 22619295,
#     'is_closed': False,
#     'last_name': 'Chekushkina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 88, 'title': 'Naberezhnye Chelny'},
#     'first_name': 'Alfia',
#     'id': 22785870,
#     'is_closed': False,
#     'last_name': 'Iskhakova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 66, 'title': 'Kirov'},
#     'first_name': 'Olga',
#     'id': 22898351,
#     'is_closed': False,
#     'last_name': 'Soboleva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Tatyana',
#     'id': 23237047,
#     'is_closed': False,
#     'last_name': 'Imaykina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 60, 'title': 'Kazan'},
#     'first_name': 'Klara',
#     'id': 23279217,
#     'is_closed': False,
#     'last_name': 'Miletkina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 112, 'title': 'Petrozavodsk'},
#     'first_name': 'Gennady',
#     'id': 23330904,
#     'is_closed': True,
#     'last_name': 'Pirozhenko',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 1, 'title': 'Moscow'},
#     'first_name': 'Galina',
#     'id': 23414357,
#     'is_closed': True,
#     'last_name': 'Boeva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'first_name': 'Irina',
#     'id': 23427233,
#     'is_closed': True,
#     'last_name': 'Borisova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 66, 'title': 'Kirov'},
#     'first_name': 'Nadezhda',
#     'id': 23433560,
#     'is_closed': False,
#     'last_name': 'Kuligina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 141, 'title': 'Tver'},
#     'first_name': 'Kirill',
#     'id': 23455562,
#     'is_closed': False,
#     'last_name': 'Belov',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 4410, 'title': 'Kudymkar'},
#     'first_name': 'Kristina',
#     'id': 23561525,
#     'is_closed': True,
#     'last_name': 'Kozminykh',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Olga',
#     'id': 23654890,
#     'is_closed': True,
#     'last_name': 'Pechyonkina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 45, 'title': 'Glazov'},
#     'first_name': 'Sergey',
#     'id': 23806291,
#     'is_closed': False,
#     'last_name': 'Dyakonov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 123, 'title': 'Samara'},
#     'first_name': 'Natalya',
#     'id': 23822741,
#     'is_closed': False,
#     'last_name': 'Povarova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Evgenia',
#     'id': 24067549,
#     'is_closed': False,
#     'last_name': 'Alexandrova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Galina',
#     'id': 24355967,
#     'is_closed': False,
#     'last_name': 'Matrosova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Olga',
#     'id': 24439832,
#     'is_closed': False,
#     'last_name': 'Pogudina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 9014, 'title': 'Kizel'},
#     'first_name': 'Tatyana',
#     'id': 24671414,
#     'is_closed': False,
#     'last_name': 'Kuzminykh',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 22, 'title': 'Arkhangelsk'},
#     'first_name': 'Lyudmila',
#     'id': 24809447,
#     'is_closed': False,
#     'last_name': 'Gorbunova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'first_name': 'Olga',
#     'id': 24865759,
#     'is_closed': True,
#     'last_name': 'Konischeva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Katya',
#     'id': 25036101,
#     'is_closed': False,
#     'last_name': 'Sidorenko',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Sania',
#     'id': 25097023,
#     'is_closed': False,
#     'last_name': 'Beysenbaeva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Yana',
#     'id': 25170145,
#     'is_closed': False,
#     'last_name': 'Smirnova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'first_name': 'Ekaterina',
#     'id': 25616519,
#     'is_closed': True,
#     'last_name': 'Khozyasheva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Alexandra',
#     'id': 26054720,
#     'is_closed': False,
#     'last_name': 'Leontyeva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 45, 'title': 'Glazov'},
#     'first_name': 'Evgenia',
#     'id': 26110053,
#     'is_closed': True,
#     'last_name': 'Zlobina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Marina',
#     'id': 26284121,
#     'is_closed': False,
#     'last_name': 'Bereslavets',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 11, 'title': 'Severodvinsk'},
#     'first_name': 'Nadezhda',
#     'id': 26298628,
#     'is_closed': False,
#     'last_name': 'Shubtsova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 78, 'title': 'Lipetsk'},
#     'first_name': 'Elena',
#     'id': 26353043,
#     'is_closed': False,
#     'last_name': 'Vovkina',
#     'sex': 1},
#    {'deactivated': 'deleted',
#     'first_name': 'DELETED',
#     'id': 26514071,
#     'last_name': '',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Darya',
#     'id': 26520132,
#     'is_closed': True,
#     'last_name': 'Sobina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Nadezhda',
#     'id': 26569707,
#     'is_closed': False,
#     'last_name': 'Levchenko',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 61, 'title': 'Kaliningrad'},
#     'first_name': 'Yulia',
#     'id': 26778881,
#     'is_closed': False,
#     'last_name': 'Shaposhnik',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Svetlana',
#     'id': 26802982,
#     'is_closed': True,
#     'last_name': 'Tyagunova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 66, 'title': 'Kirov'},
#     'first_name': 'Ulyana',
#     'id': 26816473,
#     'is_closed': True,
#     'last_name': 'Leukhina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 45, 'title': 'Glazov'},
#     'first_name': 'Natalia',
#     'id': 26974150,
#     'is_closed': True,
#     'last_name': 'Vladykina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Anna',
#     'id': 26996580,
#     'is_closed': True,
#     'last_name': 'Pasyuk',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Viktor',
#     'id': 27081281,
#     'is_closed': False,
# ...
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 5574, 'title': 'Kungur'},
#     'first_name': 'Irina',
#     'id': 141173968,
#     'is_closed': True,
#     'last_name': 'Petukhova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Ulyana',
#     'id': 141456252,
#     'is_closed': False,
#     'last_name': 'Lemeseva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 74, 'title': 'Kurgan'},
#     'first_name': 'Darya',
#     'id': 141485032,
#     'is_closed': False,
#     'last_name': 'Voropaeva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 589, 'title': 'Pechora'},
#     'first_name': 'Maria',
#     'id': 141544832,
#     'is_closed': True,
#     'last_name': 'Loginova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 66, 'title': 'Kirov'},
#     'first_name': 'Irina',
#     'id': 142194475,
#     'is_closed': True,
#     'last_name': 'Ustyugova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 10833, 'title': 'Lysva'},
#     'first_name': 'Elena',
#     'id': 142225646,
#     'is_closed': False,
#     'last_name': 'Baranova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 66, 'title': 'Kirov'},
#     'first_name': 'Irina',
#     'id': 142245170,
#     'is_closed': True,
#     'last_name': 'Kuznetsova',
#     'sex': 1},
#    {'deactivated': 'banned',
#     'first_name': 'Elena',
#     'id': 142334561,
#     'last_name': 'Gromova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2117, 'title': 'Krasnokamsk'},
#     'first_name': 'Natalya',
#     'id': 142372597,
#     'is_closed': False,
#     'last_name': 'Goldobina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 1067122, 'title': 'Trosna'},
#     'first_name': 'Ekaterina',
#     'id': 142426709,
#     'is_closed': False,
#     'last_name': 'Fomenko',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 93, 'title': 'Nizhnevartovsk'},
#     'first_name': 'Eduard',
#     'id': 142431236,
#     'is_closed': False,
#     'last_name': 'Prokopiv',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Kristina',
#     'id': 142462568,
#     'is_closed': False,
#     'last_name': 'Loginova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 93, 'title': 'Nizhnevartovsk'},
#     'first_name': 'Oksana',
#     'id': 142538744,
#     'is_closed': True,
#     'last_name': 'Rozhkina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 311, 'title': 'Sharypovo'},
#     'first_name': 'Ekaterina',
#     'id': 142672328,
#     'is_closed': False,
#     'last_name': 'Popova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Darya',
#     'id': 142714699,
#     'is_closed': True,
#     'last_name': 'Melnikova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Polina',
#     'id': 142725711,
#     'is_closed': True,
#     'last_name': 'Kovinova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Olga',
#     'id': 142867705,
#     'is_closed': False,
#     'last_name': 'Dada',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 147, 'title': 'Tyumen'},
#     'first_name': 'Irina',
#     'id': 143021771,
#     'is_closed': False,
#     'last_name': 'Sokratova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Olesya',
#     'id': 143164933,
#     'is_closed': True,
#     'last_name': 'Pepelyaeva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Irina',
#     'id': 143206471,
#     'is_closed': False,
#     'last_name': 'Belyaeva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 1966, 'title': 'Mozhga'},
#     'first_name': 'Olga',
#     'id': 143291980,
#     'is_closed': False,
#     'last_name': 'Semenova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Maria',
#     'id': 143408077,
#     'is_closed': False,
#     'last_name': 'Chuchina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 5574, 'title': 'Kungur'},
#     'first_name': 'Elena',
#     'id': 143426112,
#     'is_closed': False,
#     'last_name': 'Batrakova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Valentina',
#     'id': 143561120,
#     'is_closed': False,
#     'last_name': 'Nadymova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 1148884, 'title': 'Vereschagino'},
#     'first_name': 'Tatyana',
#     'id': 143780466,
#     'is_closed': False,
#     'last_name': 'Starkova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Svetlana',
#     'id': 143860829,
#     'is_closed': False,
#     'last_name': 'Bayandina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 45, 'title': 'Glazov'},
#     'first_name': 'Lena',
#     'id': 143889584,
#     'is_closed': False,
#     'last_name': 'Pleteneva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 5574, 'title': 'Kungur'},
#     'first_name': 'Irina',
#     'id': 143957532,
#     'is_closed': True,
#     'last_name': 'Luzina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 1148884, 'title': 'Vereschagino'},
#     'first_name': 'Yulia',
#     'id': 144036068,
#     'is_closed': True,
#     'last_name': 'Tiunova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 3992, 'title': 'Gubakha'},
#     'first_name': 'Sergey',
#     'id': 144144023,
#     'is_closed': False,
#     'last_name': 'Goryachikh',
#     'sex': 2},
#    {'can_access_closed': True,
#     'first_name': 'Lyubov',
#     'id': 144173855,
#     'is_closed': False,
#     'last_name': 'Chirkova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 4410, 'title': 'Kudymkar'},
#     'first_name': 'Elizaveta',
#     'id': 144230812,
#     'is_closed': True,
#     'last_name': 'Nadymova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Nadezhda',
#     'id': 144273780,
#     'is_closed': False,
#     'last_name': 'Starkova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'first_name': 'Natalya',
#     'id': 144273850,
#     'is_closed': True,
#     'last_name': 'Platonova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 74, 'title': 'Kurgan'},
#     'first_name': 'Sveta',
#     'id': 144321308,
#     'is_closed': True,
#     'last_name': 'Zykova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 346, 'title': 'Kirovo-Chepetsk'},
#     'first_name': 'Natalya',
#     'id': 144322982,
#     'is_closed': False,
#     'last_name': 'Obukhova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 156, 'title': 'Chaykovsky'},
#     'first_name': 'Diana',
#     'id': 144323097,
#     'is_closed': False,
#     'last_name': 'Romashova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 18, 'title': 'Almetyevsk'},
#     'first_name': 'Natalya',
#     'id': 144414125,
#     'is_closed': False,
#     'last_name': 'Sozontova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 66, 'title': 'Kirov'},
#     'first_name': 'Irina',
#     'id': 144471780,
#     'is_closed': False,
#     'last_name': 'Gudina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 132, 'title': 'Solikamsk'},
#     'first_name': 'Natalia',
#     'id': 144534314,
#     'is_closed': True,
#     'last_name': 'Dvinyaninova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'first_name': 'Marina',
#     'id': 144560753,
#     'is_closed': True,
#     'last_name': 'Martemyanova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 135, 'title': 'Sterlitamak'},
#     'first_name': 'Nadezhda',
#     'id': 144672789,
#     'is_closed': False,
#     'last_name': 'Axyonova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 21713, 'title': 'Usinsk'},
#     'first_name': 'Snezhana',
#     'id': 144776602,
#     'is_closed': True,
#     'last_name': 'Tanacheva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 58, 'title': 'Ishim'},
#     'first_name': 'Ekaterina',
#     'id': 144984648,
#     'is_closed': False,
#     'last_name': 'Radionova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 899, 'title': 'Berezniki'},
#     'first_name': 'Ekaterina',
#     'id': 144994623,
#     'is_closed': True,
#     'last_name': 'Vylegzhanina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Ksyukha',
#     'id': 145088730,
#     'is_closed': False,
#     'last_name': 'Litvinenko',
#     'sex': 1},
#    {'can_access_closed': True,
#     'first_name': 'Kristyushka',
#     'id': 145168688,
#     'is_closed': False,
#     'last_name': 'Vorobyeva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 5574, 'title': 'Kungur'},
#     'first_name': 'Anya',
#     'id': 145178743,
#     'is_closed': True,
#     'last_name': 'Koksharova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 132, 'title': 'Solikamsk'},
#     'first_name': 'Svetlana',
#     'id': 145246659,
#     'is_closed': False,
#     'last_name': 'Belkina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 1957236, 'title': 'Baku'},
#     'first_name': 'Saida',
#     'id': 145309975,
#     'is_closed': False,
#     'last_name': 'Gulieva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 132, 'title': 'Solikamsk'},
#     'first_name': 'Anastasia',
#     'id': 145403547,
#     'is_closed': True,
#     'last_name': 'Seleverstova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 110, 'title': 'Perm'},
#     'first_name': 'Ivan',
#     'id': 145418157,
#     'is_closed': True,
#     'last_name': 'Buzmakov',
#     'sex': 2},
#    {'can_access_closed': False,
#     'first_name': 'Elena',
#     'id': 145549010,
#     'is_closed': True,
#     'last_name': 'Stroykina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Irina',
#     'id': 145742749,
#     'is_closed': False,
#     'last_name': 'Fominykh',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 5110, 'title': 'Firovo'},
#     'first_name': 'Anastasia',
#     'id': 145971640,
#     'is_closed': True,
#     'last_name': 'Komolova',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 5574, 'title': 'Kungur'},
#     'first_name': 'Viktoria',
#     'id': 146252232,
#     'is_closed': False,
#     'last_name': 'Nabiullina',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 13198, 'title': 'Kilmez'},
#     'first_name': 'Darya',
#     'id': 146461113,
#     'is_closed': False,
#     'last_name': 'Vinokurova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 88, 'title': 'Naberezhnye Chelny'},
#     'first_name': 'Valery',
#     'id': 146617069,
#     'is_closed': False,
#     'last_name': 'Zhigalov',
#     'sex': 2},
#    {'can_access_closed': True,
#     'city': {'id': 2999, 'title': 'Kotelnich'},
#     'first_name': 'Irina',
#     'id': 146929903,
#     'is_closed': False,
#     'last_name': 'Nevazhno',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 899, 'title': 'Berezniki'},
#     'first_name': 'Marina',
#     'id': 146976212,
#     'is_closed': True,
#     'last_name': 'Martemyanova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Olga',
#     'id': 147130725,
#     'is_closed': False,
#     'last_name': 'Vozhennikova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 152, 'title': 'Ukhta'},
#     'first_name': 'Svetlana',
#     'id': 147270707,
#     'is_closed': False,
#     'last_name': 'Kozulina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 1109720, 'title': 'Zavyalovo'},
#     'first_name': 'Natalya',
#     'id': 147391998,
#     'is_closed': True,
#     'last_name': 'Semyonova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 1303, 'title': 'Krasnovishersk'},
#     'first_name': 'Elena',
#     'id': 147541106,
#     'is_closed': False,
#     'last_name': 'Usanina',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 4410, 'title': 'Kudymkar'},
#     'first_name': 'Galina',
#     'id': 147633870,
#     'is_closed': True,
#     'last_name': 'Klimova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 346, 'title': 'Kirovo-Chepetsk'},
#     'first_name': 'Ksenia',
#     'id': 147787052,
#     'is_closed': False,
#     'last_name': 'Kalabina',
#     'sex': 1},
#    {'deactivated': 'banned',
#     'first_name': 'Angelina',
#     'id': 148021319,
#     'last_name': 'Nekrasova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 56, 'title': 'Izhevsk'},
#     'first_name': 'Yura',
#     'id': 148078998,
#     'is_closed': False,
#     'last_name': 'Kazakov',
#     'sex': 2},
#    {'can_access_closed': False,
#     'city': {'id': 7585, 'title': 'Kochevo'},
#     'first_name': 'Oksana',
#     'id': 148138070,
#     'is_closed': True,
#     'last_name': 'Tarasova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 156, 'title': 'Chaykovsky'},
#     'first_name': 'Nadezhda',
#     'id': 148154370,
#     'is_closed': False,
#     'last_name': 'Martynova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 49, 'title': 'Yekaterinburg'},
#     'first_name': 'Natalya',
#     'id': 148215853,
#     'is_closed': True,
#     'last_name': 'Li',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 66, 'title': 'Kirov'},
#     'first_name': 'Galina',
#     'id': 148375935,
#     'is_closed': True,
#     'last_name': 'Mikisheva',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 1303, 'title': 'Krasnovishersk'},
#     'first_name': 'Anyutka',
#     'id': 148381335,
#     'is_closed': False,
#     'last_name': 'Shaad-Anisimova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2, 'title': 'Saint Petersburg'},
#     'first_name': 'Natalya',
#     'id': 148414893,
#     'is_closed': False,
#     'last_name': 'Yangirova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 66, 'title': 'Kirov'},
#     'first_name': 'Anastasia',
#     'id': 149085034,
#     'is_closed': False,
#     'last_name': 'Syuzeva',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 49, 'title': 'Yekaterinburg'},
#     'first_name': 'Oksana',
#     'id': 149095229,
#     'is_closed': True,
#     'last_name': 'Bergman',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 7557, 'title': 'Vereschagino'},
#     'first_name': 'Ekaterina',
#     'id': 149176149,
#     'is_closed': False,
#     'last_name': 'Ovchinnikova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 5574, 'title': 'Kungur'},
#     'first_name': 'Nadya',
#     'id': 149549212,
#     'is_closed': True,
#     'last_name': 'Arapova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Olenka',
#     'id': 150162982,
#     'is_closed': False,
#     'last_name': 'Kosinova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 104, 'title': 'Omsk'},
#     'first_name': 'Viktoria',
#     'id': 150295272,
#     'is_closed': False,
#     'last_name': 'Moskovets',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 147, 'title': 'Tyumen'},
#     'first_name': 'Anastasia',
#     'id': 150404165,
#     'is_closed': True,
#     'last_name': 'Shabalova-Dyatlova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 93, 'title': 'Nizhnevartovsk'},
#     'first_name': 'Olga',
#     'id': 150479465,
#     'is_closed': True,
#     'last_name': 'Cherkasova',
#     'sex': 1},
#    {'can_access_closed': False,
#     'city': {'id': 18, 'title': 'Almetyevsk'},
#     'first_name': 'Larisa',
#     'id': 150503726,
#     'is_closed': True,
#     'last_name': 'Krasnova',
#     'sex': 1},
#    {'can_access_closed': True,
#     'city': {'id': 2980, 'title': 'Nytva'},
#     'first_name': 'Alexandra',
#     'id': 150525846,
#     'is_closed': False,
#     'last_name': 'Sembel',
#     'sex': 1}]}}

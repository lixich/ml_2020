# %% [markdown]
# # Парсинг HTML-страниц
#
# *Текст лекции: Будылин Р.Я., Щуров И.В., НИУ ВШЭ*
#
# Другие материалы курса [странице курса](https://github.com/ischurov/pythonhse).

# %% [markdown]
# ### Немного про HTML
#
# То, что вы видите выше — HTML-страница. HTML (HyperText Markup Language) — это такой язык разметки, являющийся частным случаем стандарта SGML. Другим частным случаем SGML является XML, с которым мы еще встретимся.
#
# Напишем простенькую HTML-страницу. Удобнее всего это делать в каком-либо редакторе. Но я запишу ее в файл через ноутбук.

# %%
my_html = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset = "UTF-8">
    <title>Title</title>
</head>
<body>
<h1>Hello</h1>
<p>I'm a paragraph.</p>
<hr>
<ol>
    <li>One</li>
    <li>Two</li>
</ol>
    
</body>
</html>
'''

# %%
with open('my.html', 'w', encoding='utf-8') as f:
    f.write(my_html)

# %% [markdown]
# Откройте `my.html` браузером и вы увидите простую веб-страничку. Видно что HTML разбит на специальные фрагменты, которые называются тегами. В тексте выше есть теги: `<html>`, `<head>`, `<title>` и т.д. Каждый тег отмечает какой-то кусочек веб-страницы. Тег `<title>` — это заголовок страницы. Тег `<ol>` отмечает упорядоченный список. Тег `<li>` отвечает элементу списка. Тег `<p>` — абзац (paragraph). Все перечисленные теги являются *парными*: они отмечают какой-то фрагмент текста (возможно, содержащий другие теги), помещая его между соответствующим открывающим и закрывающим тегом (например, `<li>` — открывающий тег, а `</li>` — закрывающий; всё, что между ними — это элемент списка). Исключением здесь является тег `<hr>`, который рисует горизонтальную линию (он работает и без `</hr>`).
#
# Фактически HTML-страница представляет собой набор вложенных тегов. Можно сказать, что это дерево с корнем в теге `<html>`. У каждого тега есть потомки - те теги, которые непосредственно вложены в него. Например, у тега `<body>` потомками будут `<h1>`, `<p>`, `<hr>`, `<ol>`. Получается такое как бы генеалогическое древо.

# %% [markdown]
# HTML нас интересует с целью извлечения информации из такого дерева. Одним из наиболее популярных объектов для хранения информации являются таблицы, поэтмоу давайте вставим в наш файл небольшую таблицу: она обозначается тегом `<table>`, каждая строка таблицы выделяется тегом `<tr>` внутри `<table>`, а каждая ячейка — тегом `<td>` внутри `<tr>`.

# %%
my_html = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset = "UTF-8">
    <title>Title</title>
    <style type='text/css;'>
        table {
        border-collapse: collapse;
    }

    table, th, td {
        border: 1px solid black;
    }
    </style>
</head>
<body>
<h1>Hello</h1>
<p>I'm a paragraph.</p>
<hr>
<ol>
    <li>One</li>
    <li>Two</li>
</ol>
<table>
    <tr>
        <td>
            Cell 1
        </td>
        <td>
            Cell 2
        </td>
    </tr>
    <tr>
        <td>
            Cell 3
        </td>
        <td>
            Cell 4
        </td>
    </tr>
</table>
</body>
</html>
'''
with open('my.html', 'w') as f:
    f.write(my_html)

# %% [markdown]
# ## BeautifulSoup

# %% [markdown]
# Для обработки веб-страниц существует множество пакетов. Проблема с HTML в том, что большинство браузеров ведет себя «прощающе», и поэтому в вебе много плохо-написанных (не по стандарту HTML) HTML-страниц. Впрочем, обработка даже не вполне корректного HTML-кода не так сложна, если под рукой есть подходящие инструменты.
#
# Мы будем пользоваться пакетом *Beautiful Soup 4*. Он входит в стандартную поставку *Anaconda*, но если вы используете другой дистрибутив Python, возможно, вам придётся его установить вручную с помощью `pip install beautifulsoup4`.
#
# > Пакет под названием `BeautifulSoup` — скорее всего, не то, что вам нужно. Это третья версия (*Beautiful Soup 3*), а мы будем использовать четвертую. Так что нам нужен пакет `beautifulsoup4`. Чтобы было совсем весело, при импорте нужно указывать другое название пакета — `bs4`, а импортировать функцию под названием `BeautifulSoup`. В общем, сначала легко запутаться, но эти трудности нужно преодолеть однажды, а потом будет проще.

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# Чтобы использовать *Beautiful Soup*, нужно передать функции `BeautifulSoup` текст веб-страницы (в виде одной строки). Чтобы он не ругался, я также вручную указываю название парсера (той программы, которая как раз и осуществляет обработку HTML) — с целью совместимости я использую `html.parser` (он входит в поставку Python и не требует установки), но вы можете также попробовать использовать `lxml`, если он у вас установлен.

# %%
page = BeautifulSoup(my_html, 'html.parser')

# %% [markdown]
# Что теперь лежит в переменной `page`? Давайте посмотрим.

# %%
page
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Title</title>
# <style type="text/css;">
#         table {
#         border-collapse: collapse;
#     }
#
#     table, th, td {
#         border: 1px solid black;
#     }
#     </style>
# </head>
# <body>
# <h1>Hello</h1>
# <p>I'm a paragraph.</p>
# <hr/>
# <ol>
# <li>One</li>
# <li>Two</li>
# </ol>
# <table>
# <tr>
# <td>
#             Cell 1
#         </td>
# <td>
#             Cell 2
#         </td>
# </tr>
# <tr>
# <td>
#             Cell 3
#         </td>
# <td>
#             Cell 4
#         </td>
# </tr>
# </table>
# </body>
# </html>

# %% [markdown]
# Мы видим, что объект `page` очень похож на строку, но, на самом деле, это не просто строка. К `page` можно делать запросы. Например:

# %%
page.html
# Out:
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Title</title>
# <style type="text/css;">
#         table {
#         border-collapse: collapse;
#     }
#
#     table, th, td {
#         border: 1px solid black;
#     }
#     </style>
# </head>
# <body>
# <h1>Hello</h1>
# <p>I'm a paragraph.</p>
# <hr/>
# <ol>
# <li>One</li>
# <li>Two</li>
# </ol>
# <table>
# <tr>
# <td>
#             Cell 1
#         </td>
# <td>
#             Cell 2
#         </td>
# </tr>
# <tr>
# <td>
#             Cell 3
#         </td>
# <td>
#             Cell 4
#         </td>
# </tr>
# </table>
# </body>
# </html>

# %% [markdown]
# Мы видим то, что внутри тега `<html>` (это почти вся страница, но самая первая строчка «отрезалась»). Можно пойти вглубь и посмотреть на содержимое `<head>`.

# %%
page.html.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Title</title>
# <style type="text/css;">
#         table {
#         border-collapse: collapse;
#     }
#
#     table, th, td {
#         border: 1px solid black;
#     }
#     </style>
# </head>

# %% [markdown]
# Теперь мы видим только то, что внутри тега `<head>`. Мы можем пойти еще глубже, и получить то, что находится внутри тега `<title>`, который в свою очередь находится внутри тега `<head>` (говорят, что `<title>` является *потомком* `<head>`:

# %%
page.html.head.title
# Out:
# <title>Title</title>

# %% [markdown]
# Впрочем, можно было бы и не писать так подробно — поскольку в документе есть только один тег `<title>`, мы бы могли не указывать, что он находится внутри `<head>`, который находится внутри `<html>`.

# %%
page.head.title
# Out:
# <title>Title</title>

# %%
page.title
# Out:
# <title>Title</title>

# %% [markdown]
# Одним из потомков `<body>` является `<table>`. Ее можно получить вот так.

# %%
page.body.table
# Out:
# <table>
# <tr>
# <td>
#             Cell 1
#         </td>
# <td>
#             Cell 2
#         </td>
# </tr>
# <tr>
# <td>
#             Cell 3
#         </td>
# <td>
#             Cell 4
#         </td>
# </tr>
# </table>

# %% [markdown]
# Допустим, что мне нужно получить несколько элементов с одинаковым тегом, например, все строки `<tr>`. Для этого используется такой синтаксис:

# %%
rows = page.body.table.findAll('tr')
rows
# Out:
# [<tr>
#  <td>
#              Cell 1
#          </td>
#  <td>
#              Cell 2
#          </td>
#  </tr>, <tr>
#  <td>
#              Cell 3
#          </td>
#  <td>
#              Cell 4
#          </td>
#  </tr>]

# %%
len(rows)
# Out:
# 2

# %% [markdown]
# Мы видим, что это список из двух элементов. Так что по нему можно пройти циклом.

# %%
for i, row in enumerate(rows):
    print(i)
    print(row)
# Out:
# 0
# <tr>
# <td>
#             Cell 1
#         </td>
# <td>
#             Cell 2
#         </td>
# </tr>
# 1
# <tr>
# <td>
#             Cell 3
#         </td>
# <td>
#             Cell 4
#         </td>
# </tr>

# %% [markdown]
# У нас есть 2 строчки и каждая из них является таким же объектом BeautifulSoup, как и все предыдущие. Так что к ним можно применить конструкцию row.td

# %%
for i, row in enumerate(rows):
    print(i)
    print(row.td)
# Out:
# 0
# <td>
#             Cell 1
#         </td>
# 1
# <td>
#             Cell 3
#         </td>

# %% [markdown]
# Мы видим, что если внутри тега `<row>` есть несколько тегов `<td>`, то row.td возьмет первый из них. Поэтому мы получили первый столбец. Но нас интересует не сам тег `<td>`, а строка, которая там лежит. Её можно напечатать вот так.

# %%
for i, row in enumerate(rows):
    print(i)
    print(row.td.text)
# Out:
# 0
#
#             Cell 1
#
# 1
#
#             Cell 3

# %% [markdown]
# Видно, что перед строкой идут ненужные пробелы. Удалим их командой strip

# %%
for i, row in enumerate(rows):
    print(i)
    print(row.td.text.strip())
# Out:
# 0
# Cell 1
# 1
# Cell 3

# %% [markdown]
# Давайте загрузим таблицу в виде списка списков

# %%
table = []
for i, row in enumerate(rows):
    table.append([])
    for cell in row.findAll('td'):
        table[i].append(cell.text.strip())
print(table)
# Out:
# [['Cell 1', 'Cell 2'], ['Cell 3', 'Cell 4']]

# %% [markdown]
# У тегов, кроме названия, бывают еще свойства — например, в строчке `<html lang="en">` мы видим свойство `lang` у тега `<html>`, имеющее значение `"en"`. Другим важным примером тега со свойствами является тег `<a>`, который создает ссылку. У него есть свойство `href`, которое хранит собственно ссылку.

# %% [markdown]
# > Например, строка
# > `<a href="http://math-info.hse.ru/s15/m">Курс по Python</a>`
# > превращается в ссылку
# > <a href="http://math-info.hse.ru/s15/m">Курс по Python</a>,
# > ведущую на страницу нашего курса.

# %% [markdown]
# Теперь представим себе, что мы хотим сделать робота, который будет ходить по веб-страницам, и переходить с одной страницы на другую по ссылкам. Тогда мы сталкиваемся с задачей извлечь из страницы все гиперссылки.
# Для этого нужно найти все теги `<a>` на странице, и у всех них взять параметр `<href>`. Для начала покажем как получить свойство объекта, например, `lang` у `html`. Это делается так как будто наш объект словарь, и мы берем его значение по ключу.

# %%
page.html['lang']
# Out:
# 'en'

# %% [markdown]
# Если запросить свойство, которое тег не имеет, то мы получим KeyError, как и со словарем.

# %%
page.html['strange']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-d0983219eed8> in <module>()
# ----> 1 page.html['strange']
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1009         """tag[key] returns the value of the 'key' attribute for the tag,
#    1010         and throws an exception if it's not there."""
# -> 1011         return self.attrs[key]
#    1012
#    1013     def __iter__(self):
#
# KeyError: 'strange'

# %% [markdown]
# Так же, как у словаря, есть метод `get()`, который ничего не возвращает, если такого свойства нет. Или возвращает значение по умолчанию, определенное нами.

# %%
page.html.get('strange')

# %%
page.html.get('strange', 'no-such-tag')
# Out:
# 'no-such-tag'

# %% [markdown]
# Теперь извлечем все ссылки с какого-нибудь сайта

# %%
import requests
r = requests.get('http://perm.hse.ru')
page = BeautifulSoup(r.text, 'html.parser')

# %% [markdown]
# Вот все ссылки на нашей странице.

# %%
page('a')
# Out:
# [<a class="link no-visited with-icon with-icon_flag-msk" href="//hse.ru/">Москва</a>,
#  <a class="link no-visited with-icon with-icon_flag-spb" href="//spb.hse.ru/">Санкт-Петербург</a>,
#  <a class="link no-visited with-icon with-icon_flag-nn" href="//nnov.hse.ru/">Нижний Новгород</a>,
#  <a class="campus_list__item link_no-underline link no-visited" href="//hse.ru/">Москва</a>,
#  <a class="campus_list__item link_no-underline link no-visited" href="//spb.hse.ru/">Санкт-Петербург</a>,
#  <a class="campus_list__item link_no-underline link no-visited" href="//nnov.hse.ru/">Нижний Новгород</a>,
#  <a class="link link_no-visited link_no-underline" href="https://perm.hse.ru/">RU</a>,
#  <a class="link link_no-visited link_no-underline" href="https://perm.hse.ru/en/">EN</a>,
#  <a class="control control_user is-desktop" href="https://www.hse.ru/user/" title="Личный кабинет сотрудника ВШЭ"><ins><svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA"></path></svg></ins></a>,
#  <a class="link link_dark no-visited" href="https://perm.hse.ru/search/search.html?simple=0&amp;searchid=2284688">
#  										Расширенный поиск
#  									</a>,
#  <a class="external with-icon with-icon_vk-blue link" href="https://vk.com/hsestudents" target="_blank" title="ВКонтакте">
#  <span class="navigation__title">ВКонтакте </span>
#  </a>,
#  <a class="external with-icon with-icon_inst-blue link" href="http://instagram.com/hse_perm/" target="_blank" title="Инстаграм">
#  <span class="navigation__title">Инстаграм </span>
#  </a>,
#  <a class="external with-icon with-icon_fb-blue link" href="https://www.facebook.com/hseperm/" target="_blank" title="Фейсбук">
#  <span class="navigation__title">Фейсбук </span>
#  </a>,
#  <a class="external with-icon with-icon_yt-blue link" href="https://gaming.youtube.com/channel/UCmvnSTjj7GF0HmmN76LrKVA" rel="nofollow" target="_blank" title="Ютуб">
#  <span class="navigation__title">Ютуб </span>
#  </a>,
#  <a class="external with-icon with-icon_tw-blue link" href="https://twitter.com/HSE_PERM" target="_blank" title="Твиттер">
#  <span class="navigation__title">Твиттер </span>
#  </a>,
#  <a class="external with-icon with-icon_flag-perm link" href="http://perm.hse.ru/press" target="_blank" title="Мы в СМИ">
#  <span class="navigation__title">Мы в СМИ </span>
#  </a>,
#  <a href="#news">Новости</a>,
#  <a href="#events">Мероприятия</a>,
#  <a href="#around_360">Вышка 360°</a>,
#  <a href="#around_hse">Вокруг Вышки</a>,
#  <a href="#contacts">Контакты</a>,
#  <a href="#sitemap">Карта сайта</a>,
#  <a class="link_no-underline" href="https://spinner.hse.ru">
#  <img alt="" class="logo__img" src="/images/main_en/hse_ru_logo.svg"/>
#  </a>,
#  <a href="http://strategy.hse.ru/">Программа развития</a>,
#  <a href="https://perm.hse.ru/structure/">Подразделения</a>,
#  <a href="http://www.hse.ru/org/persons/?udept=135213">Преподаватели и сотрудники</a>,
#  <a href="http://mailperm.hse.ru">Корпоративная почта</a>,
#  <a href="https://perm.hse.ru/upr/inoffice/">Международное сотрудничество</a>,
#  <a href="https://spasibo.hse.ru/perm_projects">Спасибо, Вышка</a>,
#  <a class="header__important_in js-mobile_menu_content link_no-underline" href="https://www.hse.ru/our/">
#  <span class="important">Студентам и сотрудникам</span>
#  <p class="c-gray">Вышка для своих</p>
#  </a>,
#  <a class="link link_no-visited link_no-underline" href="https://perm.hse.ru/">RU</a>,
#  <a class="link link_no-visited link_no-underline" href="https://perm.hse.ru/en/">EN</a>,
#  <a class="control control_user control_white" href="https://www.hse.ru/user/" title="Личный кабинет сотрудника ВШЭ"><ins><svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA"></path></svg></ins></a>,
#  <a class="link_white" href="https://perm.hse.ru/search/search.html?simple=0&amp;searchid=2284688">Расширенный поиск</a>,
#  <a class="link_white link_no-underline" href="https://perm.hse.ru/">
#  <div class="logo__title">Высшая школа экономики</div>
#  <span class="logo__subtitle">Национальный исследовательский университет</span>
#  </a>,
#  <a class="js-dropdown_link" href="http://perm.hse.ru/abiturient/">Поступление</a>,
#  <a class="js-dropdown_link" href="http://perm.hse.ru/education/">Образование</a>,
#  <a class="js-dropdown_link" href="http://perm.hse.ru/scienceperm/">Наука</a>,
#  <a class="js-dropdown_link" href="https://perm.hse.ru/info">О Вышке</a>,
#  <a href="https://shkolnikam.hse.ru/perm/">Довузовская подготовка</a>,
#  <a href="http://perm.hse.ru/bacalavr/">Бакалавриат</a>,
#  <a href="http://perm.hse.ru/magistr/">Магистратура</a>,
#  <a href="https://perm.hse.ru/asp/">Аспирантура</a>,
#  <a href="https://perm.hse.ru/business_education/">Дополнительное и бизнес-образование </a>,
#  <a href="https://perm.hse.ru/admissions">Иностранным абитуриентам</a>,
#  <a href="https://perm.hse.ru/rcprocurement/">Подготовка в сфере закупок</a>,
#  <a href="http://distant.hse.perm.ru/course/mezhdunarodnye-standarty-finansovoy-otchetnosti/">
#  								Международные стандарты финансовой отчетности
#  							</a>,
#  <a href="https://olymp.hse.ru/championship/">
#  								Всероссийский кейс-чемпионат школьников по экономике и предпринимательству
#  							</a>,
#  <a href="https://perm.hse.ru/fdp/vishiipilotaj">
#  								Отборочный этап Регионального конкурса исследовательских и проектных работ школьников «Высший пилотаж – Пермь»
#  							</a>,
#  <a href="https://olymp.hse.ru/ma/">
#  								Олимпиада студентов и выпускников «Высшая лига»
#  							</a>,
#  <a href="https://olymp1.hse.ru/stud.html#signin">Регистрация участников до 20 января 2020 г.</a>,
#  <a href="https://olymp.hse.ru/ma/2020/list">Направления и профили олимпиады</a>,
#  <a href="https://olymp.hse.ru/ma/2020/demo">Материалы для подготовки</a>,
#  <a href="https://olymp.hse.ru/ma/2020/timetable">Очные состязания: 14-16 февраля 2020 г.</a>,
#  <a href="https://olymp.hse.ru/ma/2020/place">Города проведения</a>,
#  <a href="https://olymp.hse.ru/ma/2020/timetable/proct">Заочные состязания: 19-21 февраля 2020 г.</a>,
#  <a href="https://shkolnikam.hse.ru/perm/calendar/#dec">
#  								Календарь мероприятий для школьников
#  							</a>,
#  <a id="news"></a>,
#  <a class="link rubric rubric_46 s-rubric" href="https://perm.hse.ru/news/admission/"><span>Поступающим</span><ins></ins></a>,
#  <a class="link rubric rubric_9 s-rubric" href="https://perm.hse.ru/news/edu/"><span>Образование</span><ins></ins></a>,
#  <a class="link rubric rubric_32 s-rubric" href="https://perm.hse.ru/news/science/"><span>Наука</span><ins></ins></a>,
#  <a class="link rubric rubric_5 s-rubric" href="https://perm.hse.ru/news/expertise/"><span>Экспертиза</span><ins></ins></a>,
#  <a class="link rubric rubric_4 s-rubric" href="https://perm.hse.ru/news/community/"><span>Общество</span><ins></ins></a>,
#  <a class="link rubric rubric_3 s-rubric" href="https://perm.hse.ru/news/communication/"><span>Свободное общение</span><ins></ins></a>,
#  <a class="link rubric rubric_26 s-rubric" href="https://perm.hse.ru/news/life/"><span>Университетская жизнь</span><ins></ins></a>,
#  <a class="link rubric rubric_10 s-rubric" href="https://perm.hse.ru/news/events/"><span>События</span><ins></ins></a>,
#  <a class="link rubric rubric_46 s-rubric" href="https://perm.hse.ru/news/graduate/"><span>Выпускники</span><ins></ins></a>,
#  <a class="link rubric rubric_1 s-rubric" href="https://perm.hse.ru/news/main/"><span>Главное</span><ins></ins></a>,
#  <a class="link rubric rubric_5 s-rubric" href="https://perm.hse.ru/news/sport/"><span>Спорт</span><ins></ins></a>,
#  <a class="link rubric rubric_12 s-rubric" href="https://perm.hse.ru/news/greetings/"><span>Поздравляем</span><ins></ins></a>,
#  <a class="link rubric rubric_50 s-rubric" href="https://perm.hse.ru/news/student/"><span>Студенты</span><ins></ins></a>,
#  <a class="link rubric rubric_2 s-rubric" href="https://perm.hse.ru/news/conference/"><span>Конференции</span><ins></ins></a>,
#  <a class="link rubric rubric_3 s-rubric" href="https://perm.hse.ru/news/course/"><span>Курсы</span><ins></ins></a>,
#  <a class="link rubric rubric_17 s-rubric" href="https://perm.hse.ru/news/seminar/"><span>Научные семинары университета</span><ins></ins></a>,
#  <a class="link rubric rubric_7 s-rubric" href="https://perm.hse.ru/news/declaration/"><span>Объявления</span><ins></ins></a>,
#  <a class="link rubric rubric_11 s-rubric" href="https://perm.hse.ru/news/importantly/"><span>Это важно</span><ins></ins></a>,
#  <a class="link rubric rubric_4 s-rubric" href="https://perm.hse.ru/news/open_days/"><span>Дни открытых дверей</span><ins></ins></a>,
#  <a class="link rubric rubric_28 s-rubric" href="https://perm.hse.ru/news/expert/"><span>Экспертное мнение</span><ins></ins></a>,
#  <a class="link rubric rubric_22 s-rubric" href="https://perm.hse.ru/news/bo/"><span>Бизнес-образование</span><ins></ins></a>,
#  <a class="link rubric rubric_23 s-rubric" href="https://perm.hse.ru/news/ma/"><span>Магистратура</span><ins></ins></a>,
#  <a class="link rubric rubric_51 s-rubric" href="https://perm.hse.ru/news/ba/"><span>Бакалавриат</span><ins></ins></a>,
#  <a class="link rubric rubric_48 s-rubric" href="https://perm.hse.ru/news/essex/"><span>Наши в Эссексе</span><ins></ins></a>,
#  <a class="link rubric rubric_6 s-rubric" href="https://perm.hse.ru/news/children/"><span>Одаренные дети</span><ins></ins></a>,
#  <a class="link rubric rubric_48 s-rubric" href="https://perm.hse.ru/news/profi/"><span>Профи-край</span><ins></ins></a>,
#  <a class="link rubric rubric_18 s-rubric" href="https://perm.hse.ru/news/history/"><span>История</span><ins></ins></a>,
#  <a class="link rubric rubric_47 s-rubric" href="https://perm.hse.ru/news/pe/"><span>Программная инженерия</span><ins></ins></a>,
#  <a class="link rubric rubric_47 s-rubric" href="https://perm.hse.ru/news/bi/"><span>Бизнес-информатика</span><ins></ins></a>,
#  <a class="link rubric rubric_27 s-rubric" href="https://perm.hse.ru/news/mb/"><span>Управление бизнесом</span><ins></ins></a>,
#  <a class="link rubric rubric_6 s-rubric" href="https://perm.hse.ru/news/ec/"><span>Экономика</span><ins></ins></a>,
#  <a class="link rubric rubric_8 s-rubric" href="https://perm.hse.ru/news/smart/"><span>Smart-маркетинг</span><ins></ins></a>,
#  <a class="link rubric rubric_29 s-rubric" href="https://perm.hse.ru/news/gmu/"><span>ГМУ</span><ins></ins></a>,
#  <a class="link rubric rubric_32 s-rubric" href="https://perm.hse.ru/news/ia/"><span>Информационная аналитика</span><ins></ins></a>,
#  <a class="link rubric rubric_18 s-rubric" href="https://perm.hse.ru/news/mp/"><span>Управление проектами</span><ins></ins></a>,
#  <a class="link rubric rubric_24 s-rubric" href="https://perm.hse.ru/news/fin/"><span>Финансы</span><ins></ins></a>,
#  <a class="link rubric rubric_25 s-rubric" href="https://perm.hse.ru/news/ee/"><span>Экономика впечатлений</span><ins></ins></a>,
#  <a class="link rubric rubric_41 s-rubric" href="https://perm.hse.ru/news/lb/"><span>Право в предпринимательстве</span><ins></ins></a>,
#  <a class="link rubric rubric_21 s-rubric" href="https://perm.hse.ru/news/law/"><span>Юриспруденция</span><ins></ins></a>,
#  <a class="link_no-underline post__img_href" href="https://perm.hse.ru/news/326112884.html"><img alt="Раннее приглашение к поступлению в магистратуру НИУ ВШЭ: стартовал прием заявок" class="post__img" src="/pubs/share/thumb/326113997:c1083x580+0+48:r433x232!"/></a>,
#  <a href="https://perm.hse.ru/news/326112884.html">Раннее приглашение к поступлению в магистратуру НИУ ВШЭ: стартовал прием заявок</a>,
#  <a class="rubric rubric_46" href="https://perm.hse.ru/news/admission/"><span>Поступающим</span></a>,
#  <a class="rubric rubric_11" href="https://perm.hse.ru/news/importantly/"><span>Это важно</span></a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/official/" title="официально">официально</a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/mag/" title="магистратура">магистратура</a>,
#  <a class="link_no-underline post__img_href" href="https://perm.hse.ru/news/326117022.html"><img alt="Какие факторы влияют на отношение к собственному здоровью у разных поколений россиян?" class="post__img" src="/pubs/share/thumb/326117222:c1083x580+0+23:r433x232!"/></a>,
#  <a href="https://perm.hse.ru/news/326117022.html">Какие факторы влияют на отношение к собственному здоровью у разных поколений россиян?</a>,
#  <a class="rubric rubric_32" href="https://perm.hse.ru/news/science/"><span>Наука</span></a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/practice/" title="идеи и опыт">идеи и опыт</a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/prof/" title="профессора">профессора</a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/publicat/" title="публикации">публикации</a>,
#  <a class="link_no-underline post__img_href" href="https://perm.hse.ru/news/326128805.html"><img alt="Менеджмент рулит!" class="post__img" src="/pubs/share/thumb/326129896:c1083x580+0+77:r433x232!"/></a>,
#  <a href="https://perm.hse.ru/news/326128805.html">Менеджмент рулит!</a>,
#  <a class="rubric rubric_46" href="https://perm.hse.ru/news/admission/"><span>Поступающим</span></a>,
#  <a class="rubric rubric_10" href="https://perm.hse.ru/news/events/"><span>События</span></a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/practice/" title="идеи и опыт">идеи и опыт</a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/extra/" title="не учеба">не учеба</a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/erep/" title="репортаж о событии">репортаж о событии</a>,
#  <a class="is-desktop link_no-underline post__img_href" href="https://perm.hse.ru/news/324633013.html"><img alt="Общение с экспертами-практиками, погружение в профессиональную среду: в НИУ ВШЭ &amp;ndash; Пермь завершилась Неделя публичного права" class="post__img" src="/pubs/share/thumb/326113916:c1083x580+0+29:r433x232!"/></a>,
#  <a href="https://perm.hse.ru/news/324633013.html">Общение с экспертами-практиками, погружение в профессиональную среду: в НИУ ВШЭ – Пермь завершилась Неделя публичного права</a>,
#  <a class="rubric rubric_26" href="https://perm.hse.ru/news/life/"><span>Университетская жизнь</span></a>,
#  <a class="rubric rubric_10" href="https://perm.hse.ru/news/events/"><span>События</span></a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/practice/" title="идеи и опыт">идеи и опыт</a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/stud/" title="студенты">студенты</a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/mclass/" title="мастер-классы">мастер-классы</a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/erep/" title="репортаж о событии">репортаж о событии</a>,
#  <a class="is-desktop link_no-underline post__img_href" href="https://perm.hse.ru/news/326121484.html"><img alt="Песни, танцы, 90-е: вспоминаем ArtFest &amp;mdash; 2019" class="post__img" src="/pubs/share/thumb/326126309:c1083x580+0+56:r433x232!"/></a>,
#  <a href="https://perm.hse.ru/news/326121484.html">Песни, танцы, 90-е: вспоминаем ArtFest — 2019</a>,
#  <a class="rubric rubric_26" href="https://perm.hse.ru/news/life/"><span>Университетская жизнь</span></a>,
#  <a class="rubric rubric_10" href="https://perm.hse.ru/news/events/"><span>События</span></a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/extra/" title="не учеба">не учеба</a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/stud/" title="студенты">студенты</a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/erep/" title="репортаж о событии">репортаж о событии</a>,
#  <a class="is-desktop link_no-underline post__img_href" href="//www.hse.ru/news/admission/324648726.html"><img alt="НИУ ВШЭ впервые проведет кейс-чемпионат для школьников" class="post__img" src="/pubs/share/thumb/326113974:c1083x580+0+96:r433x232!"/></a>,
#  <a href="//www.hse.ru/news/admission/324648726.html">НИУ ВШЭ впервые проведет кейс-чемпионат для школьников</a>,
#  <a class="rubric rubric_46" href="https://perm.hse.ru/news/admission/"><span>Поступающим</span></a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/newhse/" title="новое в ВШЭ">новое в ВШЭ</a>,
#  <a class="tag" href="https://perm.hse.ru/news/tags/inv/" title="приглашение к участию">приглашение к участию</a>,
#  <a class="tag" href="https://perm.hse.ru/news/keywords/73230094/" title="олимпиады НИУ ВШЭ">олимпиады НИУ ВШЭ</a>,
#  <a class="tag" href="https://perm.hse.ru/news/keywords/79066/" title="предпринимательство">предпринимательство</a>,
#  <a class="tag" href="https://perm.hse.ru/news/keywords/60396979/" title="проектная деятельность">проектная деятельность</a>,
#  <a class="tag" href="https://perm.hse.ru/news/keywords/97696135/" title="старшеклассники">старшеклассники</a>,
#  <a href="https://perm.hse.ru/news/">Все новости</a>,
#  <a id="events"></a>,
#  <a href="https://shkolnikam.hse.ru/perm/calendar">Календарь мероприятий для школьников</a>,
#  <a href="https://perm.hse.ru/fdp/vishiipilotaj">Отборочный этап Регионального конкурса исследовательских и проектных работ школьников «Высший пилотаж – Пермь»</a>,
#  <a href="https://niu-vshe-perm-events.timepad.ru/event/1217070/" rel="nofollow">Общеуниверситетские факультативы</a>,
#  <a href="https://olymp.hse.ru/mmo/2020/instr-second/">Второй (заключительный) этап Всероссийской олимпиады школьников «Высшая проба»</a>,
#  <a href="http://www.permwinterschool.ru" rel="nofollow">Perm Winter School '20</a>,
#  <a class="link" href="https://perm.hse.ru/announcements/321435895.html">Ежегодная междисциплинарная студенческая конференция на английском языке iTELL</a>,
#  <a href="https://olymp.hse.ru/championship/">Всероссийский кейс-чемпионат школьников по экономике и предпринимательству</a>,
#  <a href="https://perm.hse.ru/news/announcements/">Все мероприятия</a>,
#  <a class="subscribe_button" href="https://www.hse.ru/news/announcements/subscribe/135213/">Подписаться</a>,
#  <a id="around_360"></a>,
#  <a class="tile tile--no1 post tile--0" href="http://students.perm.hse.ru/" onclick="if (window.ga) window.ga('send', 'event', '360hse', 'click', 'Студенческая жизнь в Вышке'); return true;" style="background-image: url(/pubs/share/direct/289822209);">
#  <div class="tile__inner">
#  <div class="post__title">Студенческая жизнь в Вышке</div>
#  <div class="tile__text"></div>
#  </div>
#  </a>,
#  <a class="tile tile--no2 post tile--6" href="https://perm.hse.ru/upr/stal/career" onclick="if (window.ga) window.ga('send', 'event', '360hse', 'click', 'Развитие карьеры студентов и выпускников'); return true;" style="background-image: url(/pubs/share/direct/289822101);">
#  <div class="tile__inner">
#  <div class="post__title">Развитие карьеры студентов и выпускников</div>
#  <div class="tile__text"></div>
#  </div>
#  </a>,
#  <a class="tile tile--no3 post tile--0" href="https://perm.hse.ru/rcprocurement/" style="background-image: url(/pubs/share/direct/289823862);">
#  <div class="tile__inner">
#  <div class="post__title">Региональный центр по подготовке специалистов для системы государственных закупок</div>
#  <div class="tile__text"></div>
#  </div>
#  </a>,
#  <a class="tile tile--no4 post tile--4" href="http://students.perm.hse.ru/zelenaya_vishka" style="background-image: url(/pubs/share/direct/289824133);">
#  <div class="tile__inner">
#  <div class="post__title">Зелёная Вышка</div>
#  <div class="tile__text"></div>
#  </div>
#  </a>,
#  <a class="tile tile--no5 post tile--6" href="https://perm.hse.ru/okrug/" style="background-image: url(/pubs/share/direct/289822542);">
#  <div class="tile__inner">
#  <div class="post__title">Университетский округ</div>
#  <div class="tile__text"></div>
#  </div>
#  </a>,
#  <a class="tile tile--no6 post tile--0" href="https://perm.hse.ru/lyceum/" style="background-image: url(/pubs/share/direct/289823656);">
#  <div class="tile__inner">
#  <div class="post__title">Лицей №10 при Высшей школе экономики</div>
#  <div class="tile__text"></div>
#  </div>
#  </a>,
#  <a class="tile tile--no1 post tile--0" href="https://perm.hse.ru/upr/inoffice/" onclick="if (window.ga) window.ga('send', 'event', '360hse', 'click', 'Международное сотрудничество'); return true;" style="background-image: url(/pubs/share/direct/289821936);">
#  <div class="tile__inner">
#  <div class="post__title">Международное сотрудничество</div>
#  <div class="tile__text"></div>
#  </div>
#  </a>,
#  <a class="tile tile--no2 post tile--0" href="http://distant.hse.perm.ru/masterin/" onclick="if (window.ga) window.ga('send', 'event', '360hse', 'click', 'Прикладные программы уровня Master in'); return true;" style="background-image: url(/pubs/share/direct/289828832);">
#  <div class="tile__inner">
#  <div class="post__title">Прикладные программы уровня Master in</div>
#  <div class="tile__text"></div>
#  </div>
#  </a>,
#  <a class="tile tile--no3 post tile--7" href="https://elearning.hse.ru/mooc" style="background-image: url(/pubs/share/direct/289822905);">
#  <div class="tile__inner">
#  <div class="post__title">Массовые открытые онлайн-курсы</div>
#  <div class="tile__text"></div>
#  </div>
#  </a>,
#  <a class="tile tile--no4 post tile--6" href="https://perm.hse.ru/job/" style="background-image: url(/pubs/share/direct/289821929);">
#  <div class="tile__inner">
#  <div class="post__title">Обучение в рамках реализации «Программы повышения производительности труда и поддержки занятости»</div>
#  <div class="tile__text"></div>
#  </div>
#  </a>,
#  <a class="tile tile--no5 post tile--0" href="https://iq.hse.ru/" style="background-image: url(/pubs/share/direct/289823134);">
#  <div class="tile__inner">
#  <div class="post__title">IQ.hse.ru</div>
#  <div class="tile__text">Научный портал</div>
#  </div>
#  </a>,
#  <a class="tile tile--no6 post tile--1" href="https://perm.hse.ru/plus" style="background-image: url(/pubs/share/direct/289824217);">
#  <div class="tile__inner">
#  <div class="post__title">Бакалавр +</div>
#  <div class="tile__text"></div>
#  </div>
#  </a>,
#  <a id="around_hse"></a>,
#  <a class="from_social__image" href="https://www.instagram.com/p/B474qTJIu2-/" rel="nofollow"><img alt="sophiashabanova" src="/pubs/share/cover/thumb/318456335x135x110"/></a>,
#  <a class="from_social__author" href="https://www.instagram.com/sophiashabanova/" rel="nofollow">sophiashabanova</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/B474qTJIu2-/" rel="nofollow">Люди и современное искусство) @dr.anna.suvorova и @shafran_shafran , спасибо за интересную пару в permm⭐️</a>,
#  <a class="from_social__image" href="https://www.instagram.com/p/B44meeQI914/" rel="nofollow"><img alt="pkeu_perm" src="/pubs/share/cover/thumb/318456414x135x110"/></a>,
#  <a class="from_social__author" href="https://www.instagram.com/pkeu_perm/" rel="nofollow">pkeu_perm</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/B44meeQI914/" rel="nofollow">Открытая лекция в НИУ ВШЭ-Пермь #сбербанк #открытаялекция
#  </a>,
#  <a class="from_social__image" href="https://www.facebook.com/photo.php?fbid=2416541618394532&amp;set=pcb.2416557661726261&amp;type=3&amp;theater" rel="nofollow"><img alt="Динара Гагарина" src="/pubs/share/cover/thumb/318457511x135x110"/></a>,
#  <a class="from_social__author" href="https://www.facebook.com/dinara.gagarina" rel="nofollow">Динара Гагарина</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.facebook.com/photo.php?fbid=2416541618394532&amp;set=pcb.2416557661726261&amp;type=3&amp;theater" rel="nofollow">Дорогие лица. Семинар DH HSE</a>,
#  <a class="from_social__image" href="https://www.facebook.com/photo.php?fbid=2448617032020191&amp;set=a.2291523344396228&amp;type=3&amp;theater" rel="nofollow"><img alt="Алина Вдовина" src="/pubs/share/cover/thumb/318457364x135x110"/></a>,
#  <a class="from_social__author" href="https://www.facebook.com/profile.php?id=100006157544013" rel="nofollow">Алина Вдовина</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.facebook.com/photo.php?fbid=2448617032020191&amp;set=a.2291523344396228&amp;type=3&amp;theater" rel="nofollow">2016, ровно три года назад. Отгремела первая сессия, первый экзамен - по философии (чтобы не расслаблялись). Хочу насладиться последними днями в вышке. </a>,
#  <a class="from_social__image" href="https://www.instagram.com/p/B16tl7Nlx_oQODs5OLbcs8RwPdDHRflhGTTWrY0/" rel="nofollow"><img alt="maks.kurganov" src="/pubs/share/cover/thumb/305801038x135x110"/></a>,
#  <a class="from_social__author" href="https://www.instagram.com/maks.kurganov/" rel="nofollow">maks.kurganov</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/B16tl7Nlx_oQODs5OLbcs8RwPdDHRflhGTTWrY0/" rel="nofollow">Новый учебный год в новой команде! Впереди новые проекты, много драйва, амбициозные цели и невероятные решения. Дерзаем! #hseperm #hsefamily</a>,
#  <a class="from_social__image" href="https://www.instagram.com/p/B0NtkLRlQox/" rel="nofollow"><img alt="abykova304" src="/pubs/share/cover/thumb/301590472x135x110"/></a>,
#  <a class="from_social__author" href="https://www.instagram.com/abykova304/" rel="nofollow">abykova304</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/B0NtkLRlQox/" rel="nofollow">All together! Today we started the Summer IDLab week 2019. </a>,
#  <a class="from_social__image" href="https://www.instagram.com/p/Bz2xe7WF9Ul3sbKu3DK5C9lIA5Q-ark8tyMtTw0/" rel="nofollow"><img alt="valeriya_badinav" src="/pubs/share/cover/thumb/301590535x135x110"/></a>,
#  <a class="from_social__author" href="https://www.instagram.com/valeriya_badina/" rel="nofollow">valeriya_badinav</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/Bz2xe7WF9Ul3sbKu3DK5C9lIA5Q-ark8tyMtTw0/" rel="nofollow">Путь до получения диплома магистра был длинным и трудным. Спасибо родным, друзьям, преподавателям и коллегам! Вы - лучшие ❤</a>,
#  <a class="from_social__image" href="https://www.instagram.com/p/BzpKO5col6E/" rel="nofollow"><img alt="smart_marketing_masters" src="/pubs/share/cover/thumb/295292095x135x110"/></a>,
#  <a class="from_social__author" href="https://www.instagram.com/smart_marketing_masters/" rel="nofollow">smart_marketing_masters</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BzpKO5col6E/" rel="nofollow">5 команд представили финале свои решения. Было все: удивительное сегментирование, сложные расчеты и разговоры на языке диаграмм, идеи direct-коммуникаций, а также видеоролик, неожиданные корреляции и презентации в фирменном стиле.</a>,
#  <a class="from_social__image" href="https://www.facebook.com/photo.php?fbid=631080740721231&amp;set=a.469954356833871&amp;type=3&amp;theater" rel="nofollow"><img alt="Anastasia Polovnikova" src="/pubs/share/cover/thumb/295292128x135x110"/></a>,
#  <a class="from_social__author" href="https://www.facebook.com/profile.php?id=100014579314073" rel="nofollow">Anastasia Polovnikova</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.facebook.com/photo.php?fbid=631080740721231&amp;set=a.469954356833871&amp;type=3&amp;theater" rel="nofollow">Bachelor of Economics!🎓 Четыре сессии в год, бесконечные дедлайны, невероятно крутые проекты, курсовые, LMS, стажировки в Nestle и KPMG. Эти четыре года были лучшие, но я верю, что дальше будет ещё интереснее!</a>,
#  <a class="from_social__image" href="https://www.instagram.com/p/Bzn2q62lmPhr-_Ak1rsS8qu-YJI1W4tShJ2WTE0/" rel="nofollow"><img alt="mary_zheltikova" src="/pubs/share/cover/thumb/295292173x135x110"/></a>,
#  <a class="from_social__author" href="https://www.instagram.com/mary_zheltikova/" rel="nofollow">mary_zheltikova</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/Bzn2q62lmPhr-_Ak1rsS8qu-YJI1W4tShJ2WTE0/" rel="nofollow">Сижу рядом с звёздами @veronica_avliyarova и @aldmborisov ⭐️</a>,
#  <a class="from_social__image" href="https://www.facebook.com/photo.php?fbid=10213841923344343&amp;set=pcb.10213841933624600&amp;type=3&amp;theater" rel="nofollow"><img alt="Ирина Шафранская" src="/pubs/share/cover/thumb/292253921x135x110"/></a>,
#  <a class="from_social__author" href="https://www.facebook.com/irina.shafranskaya" rel="nofollow">Ирина Шафранская</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.facebook.com/photo.php?fbid=10213841923344343&amp;set=pcb.10213841933624600&amp;type=3&amp;theater" rel="nofollow">🚀🚀🚀CASC стартовала! Обсуждаем будущее решение кейса и ждём Дмитрий Чирков (Chirkov Dmitry) и Дмитрий Потапов.
#  #casc2019 #аналитиксоленыеуши</a>,
#  <a class="from_social__image" href="https://www.instagram.com/p/BzYBurPi-jf/" rel="nofollow"><img alt="mirspk" src="/pubs/share/cover/thumb/292253956x135x110"/></a>,
#  <a class="from_social__author" href="https://www.instagram.com/mirspk/" rel="nofollow">mirspk</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BzYBurPi-jf/" rel="nofollow">28 июня в Перми прошло третье заседание Координационного совета по цифровой экономике Прикамья. </a>,
#  <a class="from_social__image" href="https://www.instagram.com/p/BzQLccRlXzrHf09vYI_EIu7PPKcw5336bUkzxA0/" rel="nofollow"><img alt="snqelt" src="/pubs/share/cover/thumb/292254004x135x110"/></a>,
#  <a class="from_social__author" href="https://www.instagram.com/snqelt/" rel="nofollow">snqelt</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BzQLccRlXzrHf09vYI_EIu7PPKcw5336bUkzxA0/" rel="nofollow">Хогвартс the end 👩🏻‍🎓</a>,
#  <a class="from_social__image" href="https://www.instagram.com/p/BzQbPZTixru/" rel="nofollow"><img alt="jevy93" src="/pubs/share/cover/thumb/292253963x135x110"/></a>,
#  <a class="from_social__author" href="https://www.instagram.com/jevy93/" rel="nofollow">jevy93</a>,
#  <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BzQbPZTixru/" rel="nofollow">HSE Graduation 2019😎🎓
#  Smart-Маркетологи @shafran_shafran сделали очень крутую ответную речь! #hseperm #hse
#  </a>,
#  <a id="contacts"></a>,
#  <a href="https://www.hse.ru/buildinghse/perm#map">ул. Студенческая, д. 38</a>,
#  <a class="link" href="mailto:infoperm@hse.perm.ru" style="border-bottom-width: 1px; border-bottom-style: solid; border-bottom-color: rgba(0, 122, 197, 0.298039); color: rgb(0, 122, 197); cursor: pointer; background-image: none; background-position: initial;">infoperm@hse.ru</a>,
#  <a href="https://perm.hse.ru/bacalavr/">бакалавриат</a>,
#  <a href="https://perm.hse.ru/magistr/">магистратура</a>,
#  <a href="https://www.hse.ru/buildinghse/perm#map">ул. Студенческая, 38</a>,
#  <a href="mailto:abitur.perm@hse.ru">abitur.perm@hse.ru</a>,
#  <a href="https://perm.hse.ru/vzf">вечерне-заочный факультет</a>,
#  <a href="https://www.hse.ru/buildinghse/perm#map">ул. Студенческая, 38</a>,
#  <a href="mailto:vzf@hse.ru">vzf@hse.ru</a>,
#  <a href="http://distant.hse.perm.ru/">программы профессиональной переподготовки</a>,
#  <a href="https://www.hse.ru/buildinghse/perm#map">ул. Студенческая, 23</a>,
#  <a href="mailto:sdoperm@hse.ru">sdoperm@hse.ru</a>,
#  <a class="link link_dark no-visite" href="https://perm.hse.ru/pr/about">
#  								Пресс-офис НИУ ВШЭ-Пермь
#  							</a>,
#  <a href="https://www.hse.ru/buildinghse/perm#map">Студенческая, 38</a>,
#  <a href="mailto:PR-perm@hse.ru">PR-perm@hse.ru</a>,
#  <a href="https://www.hse.ru/buildinghse/perm">Карта зданий</a>,
#  <a class="navigation__link" href="https://perm.hse.ru/">О кампусе </a>,
#  <a class="navigation__link" href="https://www.hse.ru/sveden/common">Сведения об образовательной организации</a>,
#  <a class="navigation__link" href="https://perm.hse.ru/appeal">Обращения граждан в НИУ ВШЭ - Пермь</a>,
#  <a class="navigation__link" href="https://www.hse.ru/anticorruption">Противодействие коррупции</a>,
#  <a class="navigation__link" href="http://www.hse.ru/orgstructure/campus/perm/">Руководство</a>,
#  <a class="navigation__link" href="http://perm.hse.ru/structure/">Подразделения</a>,
#  <a class="navigation__link" href="http://www.hse.ru/org/persons/?udept=135213">Преподаватели и сотрудники</a>,
#  <a class="navigation__link" href="http://phone.hse.perm.ru/">Телефонный справочник</a>,
#  <a class="navigation__link" href="https://www.hse.ru/buildinghse/perm">Корпуса и общежития</a>,
#  <a class="navigation__link" href="https://perm.hse.ru/inclusive/">ВШЭ для студентов с ограниченными возможностями здоровья и инвалидностью</a>,
#  <a class="navigation__link" href="https://pay.hse.ru/perm">Единая платежная страница</a>,
#  <a class="navigation__link" href="https://perm.hse.ru/"> Образование</a>,
#  <a class="navigation__link" href="http://perm.hse.ru/fdp/">Довузовская подготовка</a>,
#  <a class="navigation__link" href="http://olymp.hse.ru/">Олимпиады</a>,
#  <a class="navigation__link" href="http://perm.hse.ru/bacalavr/">Прием в бакалавриат</a>,
#  <a class="navigation__link" href="http://perm.hse.ru/magistr/">Прием в магистратуру</a>,
#  <a class="navigation__link" href="https://perm.hse.ru/admissions">Иностранным абитуриентам</a>,
#  <a class="navigation__link" href="http://perm.hse.ru/business_education/">Дополнительное и бизнес-образование</a>,
#  <a class="navigation__link" href="https://perm.hse.ru/okrug/">Университетский округ</a>,
#  <a class="navigation__link" href="https://perm.hse.ru/">Наука</a>,
#  <a class="navigation__link" href="http://perm.hse.ru/scienceperm/">Научные центры и лаборатории</a>,
#  <a class="navigation__link" href="http://perm.hse.ru/cae/">Прикладные проекты</a>,
#  <a class="navigation__link" href="http://www.hse.ru/pubs.html">Ресурсы</a>,
#  <a class="navigation__link" href="http://www.hse.ru/pubs.html">Журналы ВШЭ</a>,
#  <a class="navigation__link" href="http://publications.hse.ru">Публикации сотрудников</a>,
#  <a class="navigation__link" href="http://sophist.hse.ru/">Единый архив экономических и социологических данных</a>,
#  <a class="navigation__link" href="https://mailperm.hse.ru/">Корпоративная почта</a>,
#  <a class="navigation__link" href="http://minobr.permkrai.ru/" rel="nofollow">Министерство образования Пермского края</a>,
#  <a class="navigation__link" href="https://perm.hse.ru/">Полезные ссылки</a>,
#  <a class="navigation__link" href="http://www.minobrnauki.gov.ru/" rel="nofollow">Министерство науки и высшего образования РФ</a>,
#  <a class="navigation__link" href="https://edu.gov.ru/" rel="nofollow">Министерство просвещения РФ</a>,
#  <a class="navigation__link" href="http://www.edu.ru" rel="nofollow">Федеральный портал «Российское образование»</a>,
#  <a class="navigation__link" href="https://elearning.hse.ru/mooc">Массовые открытые онлайн-курсы</a>,
#  <a class="navigation__link" href="http://5top100.ru/" rel="nofollow">Проект 5-100</a>,
#  <a class="navigation__link" href="https://studyinrussia.ru/" rel="nofollow">Study In Russia</a>,
#  <a id="sitemap"></a>,
#  <a class="link" href="https://www.hse.ru/adm/edit/edit.html?goto=%2AaHR0cDovL3Blcm0uaHNlLnJ1L2luZGV4Lmh0bWw%2FX3I9MTExMDE1NzcxNDU3MDEuNzI4NA%3D%3D%5E&amp;id=135213&amp;cid=10334124&amp;addon_name=default&amp;newportal=1" rel="nofollow">Редактору</a>,
#  <a href="https://www.hse.ru/copyright">Условия использования материалов</a>,
#  <a href="https://perm.hse.ru/contact?_r=305271455084432.71897&amp;__t=2201414&amp;__r=OK">Адреса и контакты</a>,
#  <a href="https://perm.hse.ru/sitemap">Карта сайта</a>,
#  <a href="http://design.hse.ru/lab">Лабораторией дизайна НИУ ВШЭ</a>]

# %% [markdown]
# Как видим, метод `findAll()` (или его сокращённая форма записи в виде просто скобочек) ищет не только по непосредственным «детям» какой-то вершины (в генеалогических терминах), но и по всем потомкам.

# %% [markdown]
# Напечатаем сами ссылки

# %%
for link in page.findAll("a"):
    print(link['href'])
# Out:
# //hse.ru/
# //spb.hse.ru/
# //nnov.hse.ru/
# //hse.ru/
# //spb.hse.ru/
# //nnov.hse.ru/
# https://perm.hse.ru/
# https://perm.hse.ru/en/
# https://www.hse.ru/user/
# https://perm.hse.ru/search/search.html?simple=0&searchid=2284688
# https://vk.com/hsestudents
# http://instagram.com/hse_perm/
# https://www.facebook.com/hseperm/
# https://gaming.youtube.com/channel/UCmvnSTjj7GF0HmmN76LrKVA
# https://twitter.com/HSE_PERM
# http://perm.hse.ru/press
# #news
# #events
# #around_360
# #around_hse
# #contacts
# #sitemap
# https://spinner.hse.ru
# http://strategy.hse.ru/
# https://perm.hse.ru/structure/
# http://www.hse.ru/org/persons/?udept=135213
# http://mailperm.hse.ru
# https://perm.hse.ru/upr/inoffice/
# https://spasibo.hse.ru/perm_projects
# https://www.hse.ru/our/
# https://perm.hse.ru/
# https://perm.hse.ru/en/
# https://www.hse.ru/user/
# https://perm.hse.ru/search/search.html?simple=0&searchid=2284688
# https://perm.hse.ru/
# http://perm.hse.ru/abiturient/
# http://perm.hse.ru/education/
# http://perm.hse.ru/scienceperm/
# https://perm.hse.ru/info
# https://shkolnikam.hse.ru/perm/
# http://perm.hse.ru/bacalavr/
# http://perm.hse.ru/magistr/
# https://perm.hse.ru/asp/
# https://perm.hse.ru/business_education/
# https://perm.hse.ru/admissions
# https://perm.hse.ru/rcprocurement/
# http://distant.hse.perm.ru/course/mezhdunarodnye-standarty-finansovoy-otchetnosti/
# https://olymp.hse.ru/championship/
# https://perm.hse.ru/fdp/vishiipilotaj
# https://olymp.hse.ru/ma/
# https://olymp1.hse.ru/stud.html#signin
# https://olymp.hse.ru/ma/2020/list
# https://olymp.hse.ru/ma/2020/demo
# https://olymp.hse.ru/ma/2020/timetable
# https://olymp.hse.ru/ma/2020/place
# https://olymp.hse.ru/ma/2020/timetable/proct
# https://shkolnikam.hse.ru/perm/calendar/#dec
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-061a98856a3a> in <module>()
#       1 for link in page.findAll("a"):
# ----> 2     print(link['href'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1009         """tag[key] returns the value of the 'key' attribute for the tag,
#    1010         and throws an exception if it's not there."""
# -> 1011         return self.attrs[key]
#    1012
#    1013     def __iter__(self):
#
# KeyError: 'href'

# %% [markdown]
# Возьем только те теги, в которых есть атрибут `href`.

# %%
links = []
for link in page("a"):
    if 'href' in link.attrs:
        links.append(link['href'])
links
# Out:
# ['//hse.ru/',
#  '//spb.hse.ru/',
#  '//nnov.hse.ru/',
#  '//hse.ru/',
#  '//spb.hse.ru/',
#  '//nnov.hse.ru/',
#  'https://perm.hse.ru/',
#  'https://perm.hse.ru/en/',
#  'https://www.hse.ru/user/',
#  'https://perm.hse.ru/search/search.html?simple=0&searchid=2284688',
#  'https://vk.com/hsestudents',
#  'http://instagram.com/hse_perm/',
#  'https://www.facebook.com/hseperm/',
#  'https://gaming.youtube.com/channel/UCmvnSTjj7GF0HmmN76LrKVA',
#  'https://twitter.com/HSE_PERM',
#  'http://perm.hse.ru/press',
#  '#news',
#  '#events',
#  '#around_360',
#  '#around_hse',
#  '#contacts',
#  '#sitemap',
#  'https://spinner.hse.ru',
#  'http://strategy.hse.ru/',
#  'https://perm.hse.ru/structure/',
#  'http://www.hse.ru/org/persons/?udept=135213',
#  'http://mailperm.hse.ru',
#  'https://perm.hse.ru/upr/inoffice/',
#  'https://spasibo.hse.ru/perm_projects',
#  'https://www.hse.ru/our/',
#  'https://perm.hse.ru/',
#  'https://perm.hse.ru/en/',
#  'https://www.hse.ru/user/',
#  'https://perm.hse.ru/search/search.html?simple=0&searchid=2284688',
#  'https://perm.hse.ru/',
#  'http://perm.hse.ru/abiturient/',
#  'http://perm.hse.ru/education/',
#  'http://perm.hse.ru/scienceperm/',
#  'https://perm.hse.ru/info',
#  'https://shkolnikam.hse.ru/perm/',
#  'http://perm.hse.ru/bacalavr/',
#  'http://perm.hse.ru/magistr/',
#  'https://perm.hse.ru/asp/',
#  'https://perm.hse.ru/business_education/',
#  'https://perm.hse.ru/admissions',
#  'https://perm.hse.ru/rcprocurement/',
#  'http://distant.hse.perm.ru/course/mezhdunarodnye-standarty-finansovoy-otchetnosti/',
#  'https://olymp.hse.ru/championship/',
#  'https://perm.hse.ru/fdp/vishiipilotaj',
#  'https://olymp.hse.ru/ma/',
#  'https://olymp1.hse.ru/stud.html#signin',
#  'https://olymp.hse.ru/ma/2020/list',
#  'https://olymp.hse.ru/ma/2020/demo',
#  'https://olymp.hse.ru/ma/2020/timetable',
#  'https://olymp.hse.ru/ma/2020/place',
#  'https://olymp.hse.ru/ma/2020/timetable/proct',
#  'https://shkolnikam.hse.ru/perm/calendar/#dec',
#  'https://perm.hse.ru/news/admission/',
#  'https://perm.hse.ru/news/edu/',
#  'https://perm.hse.ru/news/science/',
#  'https://perm.hse.ru/news/expertise/',
#  'https://perm.hse.ru/news/community/',
#  'https://perm.hse.ru/news/communication/',
#  'https://perm.hse.ru/news/life/',
#  'https://perm.hse.ru/news/events/',
#  'https://perm.hse.ru/news/graduate/',
#  'https://perm.hse.ru/news/main/',
#  'https://perm.hse.ru/news/sport/',
#  'https://perm.hse.ru/news/greetings/',
#  'https://perm.hse.ru/news/student/',
#  'https://perm.hse.ru/news/conference/',
#  'https://perm.hse.ru/news/course/',
#  'https://perm.hse.ru/news/seminar/',
#  'https://perm.hse.ru/news/declaration/',
#  'https://perm.hse.ru/news/importantly/',
#  'https://perm.hse.ru/news/open_days/',
#  'https://perm.hse.ru/news/expert/',
#  'https://perm.hse.ru/news/bo/',
#  'https://perm.hse.ru/news/ma/',
#  'https://perm.hse.ru/news/ba/',
#  'https://perm.hse.ru/news/essex/',
#  'https://perm.hse.ru/news/children/',
#  'https://perm.hse.ru/news/profi/',
#  'https://perm.hse.ru/news/history/',
#  'https://perm.hse.ru/news/pe/',
#  'https://perm.hse.ru/news/bi/',
#  'https://perm.hse.ru/news/mb/',
#  'https://perm.hse.ru/news/ec/',
#  'https://perm.hse.ru/news/smart/',
#  'https://perm.hse.ru/news/gmu/',
#  'https://perm.hse.ru/news/ia/',
#  'https://perm.hse.ru/news/mp/',
#  'https://perm.hse.ru/news/fin/',
#  'https://perm.hse.ru/news/ee/',
#  'https://perm.hse.ru/news/lb/',
#  'https://perm.hse.ru/news/law/',
#  'https://perm.hse.ru/news/326112884.html',
#  'https://perm.hse.ru/news/326112884.html',
#  'https://perm.hse.ru/news/admission/',
#  'https://perm.hse.ru/news/importantly/',
#  'https://perm.hse.ru/news/tags/official/',
#  'https://perm.hse.ru/news/tags/mag/',
#  'https://perm.hse.ru/news/326117022.html',
#  'https://perm.hse.ru/news/326117022.html',
#  'https://perm.hse.ru/news/science/',
#  'https://perm.hse.ru/news/tags/practice/',
#  'https://perm.hse.ru/news/tags/prof/',
#  'https://perm.hse.ru/news/tags/publicat/',
#  'https://perm.hse.ru/news/326128805.html',
#  'https://perm.hse.ru/news/326128805.html',
#  'https://perm.hse.ru/news/admission/',
#  'https://perm.hse.ru/news/events/',
#  'https://perm.hse.ru/news/tags/practice/',
#  'https://perm.hse.ru/news/tags/extra/',
#  'https://perm.hse.ru/news/tags/erep/',
#  'https://perm.hse.ru/news/324633013.html',
#  'https://perm.hse.ru/news/324633013.html',
#  'https://perm.hse.ru/news/life/',
#  'https://perm.hse.ru/news/events/',
#  'https://perm.hse.ru/news/tags/practice/',
#  'https://perm.hse.ru/news/tags/stud/',
#  'https://perm.hse.ru/news/tags/mclass/',
#  'https://perm.hse.ru/news/tags/erep/',
#  'https://perm.hse.ru/news/326121484.html',
#  'https://perm.hse.ru/news/326121484.html',
#  'https://perm.hse.ru/news/life/',
#  'https://perm.hse.ru/news/events/',
#  'https://perm.hse.ru/news/tags/extra/',
#  'https://perm.hse.ru/news/tags/stud/',
#  'https://perm.hse.ru/news/tags/erep/',
#  '//www.hse.ru/news/admission/324648726.html',
#  '//www.hse.ru/news/admission/324648726.html',
#  'https://perm.hse.ru/news/admission/',
#  'https://perm.hse.ru/news/tags/newhse/',
#  'https://perm.hse.ru/news/tags/inv/',
#  'https://perm.hse.ru/news/keywords/73230094/',
#  'https://perm.hse.ru/news/keywords/79066/',
#  'https://perm.hse.ru/news/keywords/60396979/',
#  'https://perm.hse.ru/news/keywords/97696135/',
#  'https://perm.hse.ru/news/',
#  'https://shkolnikam.hse.ru/perm/calendar',
#  'https://perm.hse.ru/fdp/vishiipilotaj',
#  'https://niu-vshe-perm-events.timepad.ru/event/1217070/',
#  'https://olymp.hse.ru/mmo/2020/instr-second/',
#  'http://www.permwinterschool.ru',
#  'https://perm.hse.ru/announcements/321435895.html',
#  'https://olymp.hse.ru/championship/',
#  'https://perm.hse.ru/news/announcements/',
#  'https://www.hse.ru/news/announcements/subscribe/135213/',
#  'http://students.perm.hse.ru/',
#  'https://perm.hse.ru/upr/stal/career',
#  'https://perm.hse.ru/rcprocurement/',
#  'http://students.perm.hse.ru/zelenaya_vishka',
#  'https://perm.hse.ru/okrug/',
#  'https://perm.hse.ru/lyceum/',
#  'https://perm.hse.ru/upr/inoffice/',
#  'http://distant.hse.perm.ru/masterin/',
#  'https://elearning.hse.ru/mooc',
#  'https://perm.hse.ru/job/',
#  'https://iq.hse.ru/',
#  'https://perm.hse.ru/plus',
#  'https://www.instagram.com/p/B474qTJIu2-/',
#  'https://www.instagram.com/sophiashabanova/',
#  'https://www.instagram.com/p/B474qTJIu2-/',
#  'https://www.instagram.com/p/B44meeQI914/',
#  'https://www.instagram.com/pkeu_perm/',
#  'https://www.instagram.com/p/B44meeQI914/',
#  'https://www.facebook.com/photo.php?fbid=2416541618394532&set=pcb.2416557661726261&type=3&theater',
#  'https://www.facebook.com/dinara.gagarina',
#  'https://www.facebook.com/photo.php?fbid=2416541618394532&set=pcb.2416557661726261&type=3&theater',
#  'https://www.facebook.com/photo.php?fbid=2448617032020191&set=a.2291523344396228&type=3&theater',
#  'https://www.facebook.com/profile.php?id=100006157544013',
#  'https://www.facebook.com/photo.php?fbid=2448617032020191&set=a.2291523344396228&type=3&theater',
#  'https://www.instagram.com/p/B16tl7Nlx_oQODs5OLbcs8RwPdDHRflhGTTWrY0/',
#  'https://www.instagram.com/maks.kurganov/',
#  'https://www.instagram.com/p/B16tl7Nlx_oQODs5OLbcs8RwPdDHRflhGTTWrY0/',
#  'https://www.instagram.com/p/B0NtkLRlQox/',
#  'https://www.instagram.com/abykova304/',
#  'https://www.instagram.com/p/B0NtkLRlQox/',
#  'https://www.instagram.com/p/Bz2xe7WF9Ul3sbKu3DK5C9lIA5Q-ark8tyMtTw0/',
#  'https://www.instagram.com/valeriya_badina/',
#  'https://www.instagram.com/p/Bz2xe7WF9Ul3sbKu3DK5C9lIA5Q-ark8tyMtTw0/',
#  'https://www.instagram.com/p/BzpKO5col6E/',
#  'https://www.instagram.com/smart_marketing_masters/',
#  'https://www.instagram.com/p/BzpKO5col6E/',
#  'https://www.facebook.com/photo.php?fbid=631080740721231&set=a.469954356833871&type=3&theater',
#  'https://www.facebook.com/profile.php?id=100014579314073',
#  'https://www.facebook.com/photo.php?fbid=631080740721231&set=a.469954356833871&type=3&theater',
#  'https://www.instagram.com/p/Bzn2q62lmPhr-_Ak1rsS8qu-YJI1W4tShJ2WTE0/',
#  'https://www.instagram.com/mary_zheltikova/',
#  'https://www.instagram.com/p/Bzn2q62lmPhr-_Ak1rsS8qu-YJI1W4tShJ2WTE0/',
#  'https://www.facebook.com/photo.php?fbid=10213841923344343&set=pcb.10213841933624600&type=3&theater',
#  'https://www.facebook.com/irina.shafranskaya',
#  'https://www.facebook.com/photo.php?fbid=10213841923344343&set=pcb.10213841933624600&type=3&theater',
#  'https://www.instagram.com/p/BzYBurPi-jf/',
#  'https://www.instagram.com/mirspk/',
#  'https://www.instagram.com/p/BzYBurPi-jf/',
#  'https://www.instagram.com/p/BzQLccRlXzrHf09vYI_EIu7PPKcw5336bUkzxA0/',
#  'https://www.instagram.com/snqelt/',
#  'https://www.instagram.com/p/BzQLccRlXzrHf09vYI_EIu7PPKcw5336bUkzxA0/',
#  'https://www.instagram.com/p/BzQbPZTixru/',
#  'https://www.instagram.com/jevy93/',
#  'https://www.instagram.com/p/BzQbPZTixru/',
#  'https://www.hse.ru/buildinghse/perm#map',
#  'mailto:infoperm@hse.perm.ru',
#  'https://perm.hse.ru/bacalavr/',
#  'https://perm.hse.ru/magistr/',
#  'https://www.hse.ru/buildinghse/perm#map',
#  'mailto:abitur.perm@hse.ru',
#  'https://perm.hse.ru/vzf',
#  'https://www.hse.ru/buildinghse/perm#map',
#  'mailto:vzf@hse.ru',
#  'http://distant.hse.perm.ru/',
#  'https://www.hse.ru/buildinghse/perm#map',
#  'mailto:sdoperm@hse.ru',
#  'https://perm.hse.ru/pr/about',
#  'https://www.hse.ru/buildinghse/perm#map',
#  'mailto:PR-perm@hse.ru',
#  'https://www.hse.ru/buildinghse/perm',
#  'https://perm.hse.ru/',
#  'https://www.hse.ru/sveden/common',
#  'https://perm.hse.ru/appeal',
#  'https://www.hse.ru/anticorruption',
#  'http://www.hse.ru/orgstructure/campus/perm/',
#  'http://perm.hse.ru/structure/',
#  'http://www.hse.ru/org/persons/?udept=135213',
#  'http://phone.hse.perm.ru/',
#  'https://www.hse.ru/buildinghse/perm',
#  'https://perm.hse.ru/inclusive/',
#  'https://pay.hse.ru/perm',
#  'https://perm.hse.ru/',
#  'http://perm.hse.ru/fdp/',
#  'http://olymp.hse.ru/',
#  'http://perm.hse.ru/bacalavr/',
#  'http://perm.hse.ru/magistr/',
#  'https://perm.hse.ru/admissions',
#  'http://perm.hse.ru/business_education/',
#  'https://perm.hse.ru/okrug/',
#  'https://perm.hse.ru/',
#  'http://perm.hse.ru/scienceperm/',
#  'http://perm.hse.ru/cae/',
#  'http://www.hse.ru/pubs.html',
#  'http://www.hse.ru/pubs.html',
#  'http://publications.hse.ru',
#  'http://sophist.hse.ru/',
#  'https://mailperm.hse.ru/',
#  'http://minobr.permkrai.ru/',
#  'https://perm.hse.ru/',
#  'http://www.minobrnauki.gov.ru/',
#  'https://edu.gov.ru/',
#  'http://www.edu.ru',
#  'https://elearning.hse.ru/mooc',
#  'http://5top100.ru/',
#  'https://studyinrussia.ru/',
#  'https://www.hse.ru/adm/edit/edit.html?goto=%2AaHR0cDovL3Blcm0uaHNlLnJ1L2luZGV4Lmh0bWw%2FX3I9MTExMDE1NzcxNDU3MDEuNzI4NA%3D%3D%5E&id=135213&cid=10334124&addon_name=default&newportal=1',
#  'https://www.hse.ru/copyright',
#  'https://perm.hse.ru/contact?_r=305271455084432.71897&__t=2201414&__r=OK',
#  'https://perm.hse.ru/sitemap',
#  'http://design.hse.ru/lab']

# %% [markdown]
# Попробуем отфильтровать теги по атрибуту `class`.

# %%
links = []
for link in page.findAll("a", {'class':"navigation__link"}):
    links.append(link['href'])
links
# Out:
# ['https://perm.hse.ru/',
#  'https://www.hse.ru/sveden/common',
#  'https://perm.hse.ru/appeal',
#  'https://www.hse.ru/anticorruption',
#  'http://www.hse.ru/orgstructure/campus/perm/',
#  'http://perm.hse.ru/structure/',
#  'http://www.hse.ru/org/persons/?udept=135213',
#  'http://phone.hse.perm.ru/',
#  'https://www.hse.ru/buildinghse/perm',
#  'https://perm.hse.ru/inclusive/',
#  'https://pay.hse.ru/perm',
#  'https://perm.hse.ru/',
#  'http://perm.hse.ru/fdp/',
#  'http://olymp.hse.ru/',
#  'http://perm.hse.ru/bacalavr/',
#  'http://perm.hse.ru/magistr/',
#  'https://perm.hse.ru/admissions',
#  'http://perm.hse.ru/business_education/',
#  'https://perm.hse.ru/okrug/',
#  'https://perm.hse.ru/',
#  'http://perm.hse.ru/scienceperm/',
#  'http://perm.hse.ru/cae/',
#  'http://www.hse.ru/pubs.html',
#  'http://www.hse.ru/pubs.html',
#  'http://publications.hse.ru',
#  'http://sophist.hse.ru/',
#  'https://mailperm.hse.ru/',
#  'http://minobr.permkrai.ru/',
#  'https://perm.hse.ru/',
#  'http://www.minobrnauki.gov.ru/',
#  'https://edu.gov.ru/',
#  'http://www.edu.ru',
#  'https://elearning.hse.ru/mooc',
#  'http://5top100.ru/',
#  'https://studyinrussia.ru/']

# %% [markdown]
# ## Задача 1
# Выгрузить только валидные ссылки и их подписи.

# %%
import pandas as pd
links_with_name = [
    {
        'link': 'https://perm.hse.ru/',
        'name': 'Сайт Вышки'
    }
]
df = pd.DataFrame(links_with_name)
df
# Out:
#                    link        name
# 0  https://perm.hse.ru/  Сайт Вышки

# %% [markdown]
# ## Задача 2
#
# 1. Собрать данные о квартирах c avito.ru (структурировать информацию).
# 2. Подсчитать статистику (самая дорогая/дешевая квартира, самая высокая, оценить кол-во квартир в каждом районе).
# 3. Написать программу, которая находит наиболее подходящую квартиру по заданным параметрам.

# %%
import requests
r = requests.get('https://www.avito.ru/perm/kvartiry')
page = BeautifulSoup(r.text, 'lxml')
page
# Out:
# <!DOCTYPE html>
# <html> <head> <script>
#  try {
#  window.firstHiddenTime = document.visibilityState === 'hidden' ? 0 : Infinity;
#  document.addEventListener('visibilitychange', function (event) {
#  window.firstHiddenTime = Math.min(window.firstHiddenTime, event.timeStamp);
#  }, { once: true });
#  if ('PerformanceLongTaskTiming' in window) {
#  var globalStats = window.__statsLongTasks = { tasks: [] };
#  globalStats.observer = new PerformanceObserver(function(list) {
#  globalStats.tasks = globalStats.tasks.concat(list.getEntries());
#  });
#  globalStats.observer.observe({ entryTypes: ['longtask'] });
#  }
#  if (PerformanceObserver && (PerformanceObserver.supportedEntryTypes || []).some(function(e) {
#  return e === 'element'
#  })) {
#  if (!window.oet) {
#  window.oet = [];
#  }
#  new PerformanceObserver(function(l) {
#  window.oet.push.apply(window.oet, l.getEntries());
#  }).observe({ entryTypes: ['element'] });
#  }
#  } catch (e) {
#  console.error(e);
#  }
#  </script>
# <script>
#  window.dataLayer = [{"userAuth":0,"pageType":"Other","cityName":"perm","regionName":"R12"}];
#  (function(w, d, s, l, i) {
#  w[l] = w[l] || [];
#  w[l].push({
#  'gtm.start': new Date().getTime(),
#  event: 'gtm.js'
#  });
#  var f = d.getElementsByTagName(s)[0],
#  j = d.createElement(s),
#  dl = l != 'dataLayer' ? '&l=' + l : '';
#  j.async = true;
#  j.src = '//www.googletagmanager.com/gtm.js?id=' + i + dl;
#  f.parentNode.insertBefore(j, f);
#  })(window, document, 'script', 'dataLayer', 'GTM-KP9Q9H');
#  </script>
# <meta charset="utf-8"/>
# <meta content="telephone=no" name="format-detection"/> <meta content="7iEzRRMJ2_0p66pVS7wTYYvhZZSFBdzL5FVml4IKUS0" name="google-site-verification"/> <title>Квартиры в Перми 🏢: продажа, покупка и аренда | Авито</title>
# <link href="//an.yandex.ru/" rel="dns-prefetch"/>
# <link as="script" href="//an.yandex.ru/system/context.js" rel="preload"/>
# <script async="" src="//an.yandex.ru/system/context.js"></script>
# <link href="//yastatic.net/" rel="dns-prefetch"/>
# <link as="script" href="//yastatic.net/pcode/adfox/loader.js" rel="preload"/>
# <script async="" src="//yastatic.net/pcode/adfox/loader.js"></script>
# <link href="//securepubads.g.doubleclick.net/" rel="dns-prefetch"/>
# <link as="script" href="//www.googletagservices.com/tag/js/gpt.js" rel="preload"/>
# <script async="" src="//www.googletagservices.com/tag/js/gpt.js"></script>
# <meta content="Объявления об аренде, продаже и покупке квартир в Перми 🏢 на Авито. Большой выбор квартир в новостройках и вторичном рынке. Объявления от собственников и проверенных агентств. Поиск покупателей и арендаторов квартир без посредников. Выбор по району, площади, цене и другим параметрам." name="description"/><meta content="" name="keywords"/><meta content="Объявления об аренде, продаже и покупке квартир в Перми 🏢 на Авито. Большой выбор квартир в новостройках и вторичном рынке. Объявления от собственников и проверенных агентств. Поиск покупателей и арендаторов квартир без посредников. Выбор по району, площади, цене и другим параметрам." property="og:description"/><link href="https://www.avito.ru/perm/kvartiry" rel="canonical"/><link href="android-app://com.avito.android/ru.avito/1/items?locationId=644200&amp;categoryId=24" rel="alternate"/><link href="ios-app://417281773/ru.avito/1/items?locationId=644200&amp;categoryId=24" rel="alternate"/><link href="https://m.avito.ru/perm/kvartiry" media="only screen and (max-width: 640px)" rel="alternate"/><meta content="499bdc75d3636c55" name="yandex-verification"/><link href="https://static.avito.ru/s/cc/styles/edcf951a50e7eae10aeb.css" rel="stylesheet"/><script src="https://static.avito.ru/s/cc/bundles/fa18de6967ab3c508f27.js"></script><link href="https://static.avito.ru/s/cc/styles/91e7e7f9a9fd5933e804.css" rel="stylesheet"/><script src="https://static.avito.ru/s/cc/bundles/a8a8544b54ac243e7415.js"></script><link href="https://static.avito.ru/@avito/bx-single-page-catalog/2.327.0/prod/web/styles/62af768f180bf1c86951.css" rel="stylesheet"/><link href="https://static.avito.ru/s/cc/styles/4564f9c2b6272b3e67e9.css" rel="stylesheet"/><script src="https://static.avito.ru/s/cc/bundles/24ad337506aa383c9e01.js"></script><link href="https://static.avito.ru/s/cc/styles/0064d545d99cf9e8fc0f.css" rel="stylesheet"/><script src="https://static.avito.ru/s/cc/bundles/61f0882c93f54409a849.js"></script><link href="https://static.avito.ru/s/cc/styles/31457b2d2c6c6a8f486c.css" rel="stylesheet"/><script src="https://static.avito.ru/s/cc/bundles/807714b755083be0583c.js"></script><link href="https://www.avito.st/s/common/touch-icons/common/apple-touch-icon-180x180-precomposed.png?57be3fb" rel="apple-touch-icon-precomposed" sizes="180x180"/><link href="https://www.avito.st/s/common/touch-icons/common/apple-touch-icon-152x152-precomposed.png?cac4f2a" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="https://www.avito.st/s/common/touch-icons/common/apple-touch-icon-144x144-precomposed.png?9615e61" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="https://www.avito.st/s/common/touch-icons/common/apple-touch-icon-120x120-precomposed.png?2a32f09" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="https://www.avito.st/s/common/touch-icons/common/apple-touch-icon-114x114-precomposed.png?174e153" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="https://www.avito.st/s/common/touch-icons/common/apple-touch-icon-76x76-precomposed.png?28e6cfb" rel="apple-touch-icon-precomposed" sizes="76x76"/><link href="https://www.avito.st/s/common/touch-icons/common/apple-touch-icon-72x72-precomposed.png?aeb90b3" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="https://www.avito.st/s/common/touch-icons/common/apple-touch-icon-57x57-precomposed.png?fd7ac94" rel="apple-touch-icon-precomposed" sizes="57x57"/><meta content="#000000" name="msapplication-TileColor"/><meta content="/s/common/touch-icons/common/mstile-144x144.png" name="msapplication-TileImage"/><meta content="browserconfig.xml" name="msapplication-config"/><link href="https://www.avito.st/favicon.ico?9de48a5" rel="shortcut icon" type="image/x-icon"/><link href="https://www.avito.st/ya-tableau-manifest-ru.json?5ac8b8a" rel="yandex-tableau-widget"/><link href="https://www.avito.st/open_search_ru.xml?4b0fd3d" rel="search" title="Авито" type="application/opensearchdescription+xml"/> <script src="http ...
# <script src="https://static.avito.ru/s/cc/bundles/38d8b30a8fc3f9af7613.js"></script>
# <script src="https://static.avito.ru/s/cc/chunks/vendors~e0704b583294c2ecf03d33677df35305.55722b63ae84b5b80493.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/12403eaeac6f76fd9688.js"></script>
# <script>
#  window.capturedErrors = [];
#  window.addEventListener('error', function(error) {
#  window.capturedErrors.push(error);
#  });
#  </script> <script>
#  window.avito = window.avito || {};
#  window.avito.platform = 'desktop';
#  window.avito.siteName = 'Авито';
#  window.avito.staticPrefix = 'https://www.avito.st';
#  window.avito.supportPrefix = 'https://support.avito.ru';
#  window.avito.pageId = 'catalog';
#  window.avito.categoryId = 24;
#  window.avito.locationId = 644200;
#  window.avito.fromPage = '';
#  window.avito.sentry = {
#  dsn: 'https://1ede3b886c8b4efd9230509682fe2f12@sntr.avito.ru/41',
#  release: "rc-202010231031-161504"
#  };
#  window.avito.clickstream = {
#  buildId: "rc-202010231031-161504",
#  buildUid: null
#  };
#  window.avito.isAuthenticated = '' === '1';
#  window.avito.isVerifiedCompany = '' === '1';
#  window.avito.metrics = {};
#  window.avito.metrics.categoryId = 24;
#  window.avito.metrics.browser = '.0';
#  window.avito.filtersGroup = 'desktop_catalog_filters';
#  window.avito.experiments = window.avito.experiments || {};
#  window.avito.abFeatures = window.avito.abFeatures || {};
#  // Messenger config section
#  window.avito.socketserver = 'wss://socket.avito.ru/socket';
#  window.avito.httpfallback = '';
#  window.avito.socketImageUploadUrl = 'https://socket.avito.ru/images';
#  window.avito.socketMetricsUrl = 'https://socket.avito.ru/metrics';
#  window.avito.isTestAccount = '' === '1';
#  window.avito.userId = '0';
#   </script>
# <script src="/s/a/j/dfp/px.js?ch=1"></script> <script src="/s/a/j/dfp/px.js?ch=2"></script>
# <script>
#  window.avito.ads = {
#  userGroup: 67
#  };
#  </script>
# <script src="https://static.avito.ru/s/cc/chunks/vendors~3d7e85d2c8b51bd652a72c38a1bfd251.a72ebf841c0c92558887.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/df081ed8ffdc65bc03b2.js"></script>
# <script src="https://static.avito.ru/s/cc/chunks/332388eb.1da7aa284d1535a5ac8f.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/7c62e93ae6735680752f.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/a013db767e814590e57f.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/9b8fd62ee61a8dcd42c3.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/4aef3b2a7282d1ed1f98.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/557b181c856a6511ff5b.js"></script>
# <script>
#   window.avito.sendPhoneFromEmployerToChat = '{"enabled":false,"exposure":""}';
#   </script>
# <link href="https://static.avito.ru/s/cc/styles/627a87e060f07ac42424.css" rel="stylesheet"/>
# <script src="https://static.avito.ru/s/cc/bundles/35b4c9775cc26aad4312.js"></script>
# <script>
#  window.avito = window.avito || {};
#  window.avito.banners = {"context_1":[{"sellingSystem":"Yandex RTB","parameters":{"block_id":"P-A-591298-0","stat_id":"100002469","serpNumber":0,"hasSearchText":true,"query":"","guid":"2kcl5mdc.psxk83.12bke4wtl97g0","pageIndex":0,"ip":"92.255.132.163","alid":"0a03c3fcfc1377d1fcd27703de16e5a3"}},{"sellingSystem":"Yandex RTB","parameters":{"block_id":"R-A-419506-35","stat_id":"100002469","serpNumber":0,"alid":"0a03c3fcfc1377d1fcd27703de16e5a3"}}],"context_7":[{"sellingSystem":"Yandex RTB","parameters":{"block_id":"R-A-419506-37","stat_id":"100002469","serpNumber":0,"alid":"ab01e1e2192b2a578c3ae7a59292abc7"}}],"context_12":[{"sellingSystem":"Yandex RTB","parameters":{"block_id":"R-A-419506-39","stat_id":"100002469","serpNumber":0,"alid":"5ddedfad4ae2e7ffb4cf1aaebe2dca8f"}}],"ldr_top":[{"sellingSystem":"AdFox","parameters":{"block_id":"8_bzuem-fhtt","stat_id":"001000000","params":{"puid2":1,"puid18":"search_page","puid1":67,"puid5":4,"puid33":0,"puid14":"92.255.132.163","puid41":"\/perm\/kvartiry","puid6":24,"puid4":643700,"puid3":644200,"puid26":0,"puid30":"0","puid31":0},"alid":"cf705df6730ffe8cf821cf1e8f3016db"}}],"context_15":[{"sellingSystem":"Yandex RTB","parameters":{"block_id":"R-A-419506-41","stat_id":"100002469","serpNumber":0,"alid":"d24ab4ac564dbba9c7e00715caf755b0"}}],"desktop_low":[{"sellingSystem":"Yandex RTB","parameters":{"block_id":"R-A-419506-91","stat_id":"100002469","serpNumber":0,"alid":"1834edc6cea5eafa88da88335ebe0379"}},{"sellingSystem":"Yandex RTB","parameters":{"block_id":"R-A-419506-45","stat_id":"100002469","serpNumber":0,"alid":"1834edc6cea5eafa88da88335ebe0379"}}],"tgb1":[{"sellingSystem":"AdFox","parameters":{"block_id":"8_bzufb-fvlo","stat_id":"100002469","params":{"puid2":1,"puid18":"search_page","puid1":67,"puid5":4,"puid33":0,"puid14":"92.255.132.163","puid41":"\/perm\/kvartiry","puid6":24,"puid4":643700,"puid3":644200,"puid26":0,"puid30":"0","puid31":0,"puid63":"30"},"alid":"d45f79fb837ef53996ec024200c8714a"}},{"sellingSystem":"DFP","parameters":{"dfp_slot":"\/7870\/AR\/nedvizhimost\/kvartiry\/Search\/tgb1","google_adexchange_pf":"10","yandex_rtb_low_block_id":"R-A-419506-8","yandex_rtb_low_stat_id":"100002469","sizes":[[240,160],[240,133],[240,145],[240,200],[300,195],[300,250],[240,400],[300,300]],"count":1,"targetings":{"bp":"tgb1"},"isrmp":1,"page_type":"search_page","AudRandom":67,"keyword":"","g_metro":[],"master_category":4,"pmin":null,"pmax":null,"cat_interests":[],"params_interests":[],"socd":[],"abp":0,"ip":"92.255.132.163","referer":"\/perm\/kvartiry","item_property":[],"slave_category":24,"g_country":621540,"g_reg":643700,"g_city":644200,"g_domofond_reg":"permskiy_kray-r42","Usid":0,"stlogin":"0","phcodedesc":null,"Uname_Get4C":"","has_shop":0,"alid":"d45f79fb837ef53996ec024200c8714a"}}],"vr_low":[{"sellingSystem":"DFP","parameters":{"google_adexchange_pf":"5","yandex_rtb_low_block_id":"R-A-419506-55","yandex_rtb_low_stat_id":"100002469","dfp_slot":"\/7870\/AR\/nedvizhimost\/kvartiry\/Search\/vr_low","sizes":[[240,400],[300,250],[120,600],[160,600],[300,600],[240,133],[240,160],[240,145],[240,600],[250,250],[250,360],[240,200],[300,195]],"count":1,"targetings":{"bp":"vr_low"},"isrmp":1,"page_type":"search_page","AudRandom":67,"keyword":"","g_metro":[],"master_category":4,"pmin":null,"pmax":null,"cat_interests":[],"params_interests":[],"socd":[],"abp":0,"ip":"92.255.132.163","referer":"\/perm\/kvartiry","item_property":[],"slave_category":24,"g_country":621540,"g_reg":643700,"g_city":644200,"g_domofond_reg":"permskiy_kray-r42","Usid":0,"stlogin":"0","phcodedesc":null,"Uname_Get4C":"","has_shop":0,"alid":"dc40c10ba27e828a522b3dfb9540657c"}}],"vr_top":[{"sellingSystem":"AdFox","parameters":{"block_id":"8_bzuez-fvlm","stat_id":"100002469","params":{"puid2":1,"puid18":"search_page","puid1":67,"puid5":4,"puid33":0,"puid14":"92.255.132.163","puid41":"\/perm\/kvartiry","puid6":24,"puid4":643700,"puid3":644200,"puid26":0,"puid30":"0","puid31":0,"puid63":"30"},"alid":"c406c3eab7a72388bf69f4c2 ...
#  window.avito.rmp = window.avito.rmp || {};
#  window.avito.rmp.dfpTargetings = {"isrmp":1,"page_type":"search_page","AudRandom":67,"keyword":"","g_metro":[],"master_category":4,"pmin":null,"pmax":null,"cat_interests":[],"params_interests":[],"socd":[],"abp":0,"ip":"92.255.132.163","referer":"\/perm\/kvartiry","item_property":[],"slave_category":24,"g_country":621540,"g_reg":643700,"g_city":644200,"g_domofond_reg":"permskiy_kray-r42","Usid":0,"stlogin":"0","phcodedesc":null,"Uname_Get4C":"","has_shop":0};
#  window.avito.rmp.enabledBanners = {"context_1":{"code":"context_1"},"context_7":{"code":"context_7"},"context_12":{"code":"context_12"},"ldr_top":{"code":"ldr_top"},"context_15":{"code":"context_15"},"desktop_low":{"code":"desktop_low"},"tgb1":{"code":"tgb1"},"vr_low":{"code":"vr_low"},"vr_top":{"code":"vr_top"},"ldr_low":{"code":"ldr_low"},"vr_lower":{"code":"vr_lower"},"desktop_brandback":{"code":"desktop_brandback"}};
#  window.avito.rmp.enableEventSampling = false;
#  window.avito.rmp.newYandexSearchBanner = true
#  window.avito.abFeatures = window.avito.abFeatures || {};
#       window.avito_desktop = true;
#  </script>
# <script src="https://static.avito.ru/s/cc/bundles/2c34fcd4530b4e05956b.js"></script>
# <script async="" src="https://static.avito.ru/s/cc/chunks/37503a51.4d45eab97997f052f539.js"></script>
# <script async="" src="https://static.avito.ru/s/cc/chunks/default~0a960e5665757d0cef6f38f110dc42bb~62221eeaa822549fec3ffab51aceff75.4f7e32c26bd6eca3c653.js"></script>
# <script async="" src="https://static.avito.ru/s/cc/bundles/6dd22313652171682fc8.js"></script>
# <script async="" src="https://static.avito.ru/s/cc/bundles/6b0581effc6f716196c7.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/ccd64cdeadc1fc475777.js"></script>
# </head> <body class=" ">
# <noscript> <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KP9Q9H" style="display:none;visibility:hidden" width="0"></iframe> </noscript>
# <div class="js-single-page single-page">
# <div class="top-banner-root-1qg8R" data-marker="top-notification/warning/realty-antifraud-desktop"><div class="top-banner-content-2-jho"><img class="top-banner-image-1W_nI" src="https://www.avito.st/s/app/i/snippets/common/realty_antifraud.svg"/><div class="top-banner-textContent-3y0cg"><div class="top-banner-text-GCw-N">Как сдать жильё посуточно и не потерять деньги.<a class="link-link-39EVK link-design-default-2sPEv top-banner-action-KNoaa" data-marker="title" href="https://business.avito.ru/advice/moshenniki-v-posutochnoy" rel="noopener" target="_blank" title="Читать советы">Читать советы</a></div></div><button class="top-banner-cross-1UVkt"><svg fill="none" height="12" width="12" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M6 5.179L11.009.17a.58.58 0 11.82.821L6.822 6l5.009 5.009a.58.58 0 11-.821.82L6 6.822.991 11.83a.58.58 0 11-.82-.821L5.178 6 .17.991a.58.58 0 11.821-.82L6 5.178z" fill="#A3A3A3" fill-rule="evenodd"></path></svg></button></div></div><div class="index-header-2qEhu"><div class=""><div class="header-root-6seVg header-services header-responsive-3jENG" data-marker="header/navbar"><div class="header-inner-2-Vie header-clearfix-2NUk3"><ul class="header-list-2MyMH header-nav-3XgsT header-clearfix-2NUk3"><li class="header-nav-item-125dL"><a class="header-link-nCPL_ header-nav-link-3yDcQ" href="/business" rel="" target="" title="">Для бизнеса</a></li><li class="header-nav-item-125dL"><a class="header-link-nCPL_ header-nav-link-3yDcQ" href="/perm" rel="" target="" title="">Объявления</a></li><li class="header-nav-item-125dL"><a class="header-link-nCPL_ header-nav-link-3yDcQ" href="/shops/perm" rel="" target="" title="">Магазины</a></li><li class="header-nav-item-125dL"><a class="header-link-nCPL_ header-nav-link-3yDcQ" href="//support.avito.ru" rel="noopener noreferrer" target="_blank" title="">Помощь</a></li></ul><div class="header-services-menu-1FqDG"><div class="header-services-menu-item-2VRYK" data-marker="header/favorites"><a class="header-services-menu-link-TRWKh" href="/favorites" title="Избранное"><span class="header-services-menu-icon-wrap-35sjL"><span class="header-services-menu-icon-2ZyUe"><svg height="24" width="21" xmlns="http://www.w3.org/2000/svg"><path d="M10.918 5.085a5.256 5.256 0 0 1 7.524 0c2.077 2.114 2.077 5.541 0 7.655l-7.405 7.534a.75.75 0 0 1-1.074 0L2.558 12.74c-2.077-2.114-2.077-5.54 0-7.655a5.256 5.256 0 0 1 7.524 0c.15.152.289.312.418.479.13-.167.269-.327.418-.479z" fill="#CCC" fill-rule="nonzero"></path></svg></span></span></a></div><div class="header-services-menu-item_username-PkxRh"><a class="header-services-menu-link-TRWKh header-services-menu-link-not-authenticated-3kAga" data-marker="header/login-button" href="#login?authsrc=h">Вход и регистрация</a></div></div><a class="header-button-wrapper-1LlFQ button-button-2Fo5k button-size-s-3-rn6 button-primary-1RhOG" href="#login?next=%2Fadditem&amp;authsrc=ca" target="_self">Подать объявление<span class="element-timing-root-3Xyyc" elementtiming="sx.additem-button"><span class="element-timing-content-25Pdc">timing</span></span></a></div></div></div><div class="index-root-2vXdX index-responsive-2of1I"><div class="index-navigation-Upfiw" data-marker="header-navigation"><div class="index-logo-3NZz1"><span class="logo-root-bqENt"><a class="logo-logo-3ugdk" title="Авито — сайт объявлений о недвижимости"></a></span></div><div class="top-rubricator-root-1edPo"><a class="link-link-39EVK link-design-default-2sPEv link-novisited-1w4JY top-rubricator-item-1ReMn" data-marker="navigation/link" href="/perm/transport?cd=1" target="_self">Авто</a><a class="link-link-39EVK link-design-default-2sPEv link-novisited-1w4JY top-rubricator-item-1ReMn" data-marker="navigation/link" href="/perm/nedvizhimost?cd=1" target="_self">Недвижимость</a><a class="link-link-39EVK link-design-default-2sPEv link-novisited-1w4JY top-rubricator-item-1ReMn" data-marker="navigation/link" href="/perm/rabota?cd=1" target="_self">Работа</a><a class="link-link-39E ...
# <div class="avito-ads-container avito-ads-container_vr_top"> <div class="avito-ads-template" id="template_vr_top"> <div class="ad_vr_top avito-ads-content"> </div> </div> </div>
# <div class="avito-ads-container avito-ads-container_tgb1"> <div class="avito-ads-template" id="template_tgb1"> <div class="ad_tgb avito-ads-content"> </div> </div> </div>
# <div class="avito-ads-container avito-ads-container_vr_low"> <div class="avito-ads-template" id="template_vr_low"> <div class=" avito-ads-content"> </div> </div> </div>
# </div>
# </div></div><div class="index-content-2lnSO"><div class="wrapper-container-3jj3m" data-marker="map-banner-placeholder"><div class="wrapper-footer-1uxj3" data-marker="map-banner-button"><button aria-busy="false" class="wrapper-button-3dcsj button-button-2Fo5k button-size-m-7jtw4 button-default-mSfac width-width-12-2VZLz"><span class="button-textBox-Row9K">Показать объявления на карте</span></button></div><div class="wrapper-root-3Kw6C wrapper-root_shadow-3i7L0" data-marker="map-banner"><div class="wrapper-screen-2hY2r" style="background-image:url(https://12.img.avito.st/geo-map-location/1724x482/9756483112.jpg)"><div class="wrapper-loader-1OuES"></div></div></div></div><div class="index-topPanel-1F0TP"><div class="view-container-3Fm3s"><div class="button-group"><span class="button button-origin " title="Показать большие фото"><i class="view-icon-2bTiA"></i></span><span class="button button-origin is-active" title="Выводить списком с фото"><i class="view-icon-2bTiA view-icon_table-3VL-F"></i></span></div></div><div class="form-select-v2 sort-select-3QxXG"><select><option selected="" value="101">По умолчанию</option><option value="1">Дешевле</option><option value="2">Дороже</option><option value="104">По дате</option></select></div></div><div class="index-correction-2DgAR"></div><div class="index-root-2c0gs" elementtiming="bx.catalog.container"><div>
# <div class="snippet-list" data-marker="catalog-serp" style="display: flex; flex-wrap: wrap; padding-top: 16px;">
# <div class="avito-ads-container avito-ads-container_context_1 catalog-ads-banner"> <div class="avito-ads-template" id="template_context_1"> <div class=" avito-ads-content"> </div> </div> </div>
# <div class="snippet snippet-horizontal snippet-redesign item-snippet-with-aside item item_table clearfix js-catalog-item-enum item-with-contact js-item-extended" data-context='{"stickyCatalogFilters":false,"snippetDevelopmentLink":false,"snippetRedesign":true,"sendPhoneFromEmployerToChat":{"enabled":false,"exposure":""},"newSnippetForCompare":false,"isReactCatalogSnippetEnabled":false,"imageAspectRatio":"4-3","verifiedBadgeRedesignRealty":null}' data-item-id="2024980964" data-marker="item" data-position="" id="i2024980964" itemscope="" itemtype="http://schema.org/Product"> <meta content="..." itemprop="description"/> <div class="item__line">
# <div class="item-photo item-photo--4-3 " data-marker="item-photo">
# <a class="item-slider item-slider--4-3" href="/perm/kvartiry/3-k_kvartira_62_m_25_et._2024980964" target="_blank"> <ul class="item-slider-list">
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="3-к квартира, 62 м², 2/5 эт." class="large-picture-img" src="https://02.img.avito.st/208x156/9643552302.jpg" srcset="https://02.img.avito.st/208x156/9643552302.jpg 1x, https://02.img.avito.st/image/1/85DwGbaDX3mGt81xmgK6lwG6W39IvF1_ULhdc056UOtMul15RPw 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="3-к квартира, 62 м², 2/5 эт." class="large-picture-img" src="https://34.img.avito.st/208x156/9643552434.jpg" srcset="https://34.img.avito.st/208x156/9643552434.jpg 1x, https://34.img.avito.st/image/1/b1_dBLaDw7arqlG-jx0mWCynx7BlocGwfaXBvGNnzCRhp8G2aeE 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="3-к квартира, 62 м², 2/5 эт." class="large-picture-img" src="https://20.img.avito.st/208x156/9644530420.jpg" srcset="https://20.img.avito.st/208x156/9644530420.jpg 1x, https://20.img.avito.st/image/1/KZhbsraDhXEtHBd5BfpZnqoRgXfjF4d3-xOHe-XRiuPnEYdx71c 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="3-к квартира, 62 м², 2/5 эт." class="large-picture-img" src="https://09.img.avito.st/208x156/9644530109.jpg" srcset="https://09.img.avito.st/208x156/9644530109.jpg 1x, https://09.img.avito.st/image/1/YFKAK7aDzLv2hV6zzG4QVHGIyL04js69IIrOsT5Iwyk8iM67NM4 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="3-к квартира, 62 м², 2/5 эт." class="large-picture-img" src="https://04.img.avito.st/208x156/9645333904.jpg" srcset="https://04.img.avito.st/208x156/9645333904.jpg 1x, https://04.img.avito.st/image/1/TWKwc7aD4YvG3XODpiYjZ0HQ5Y0I1uONENLjgQ4Q7hkM0OOLBJY 1.5x"/>
# </div>
# <div class="item-slider-more">
#  Ещё<br/>
#  4 фото
#   </div>
# </li>
# </ul>
# </a>
# <div><div class="favorites-add is-design-simple js-favorites-add" data-marker="favorites-add" data-shape="default"><a class="favorites-add__link js-favorites-add-toggle" data-event-config='{"id":2024980964,"isFavorite":false,"categorySlug":"kvartiry","rootCategoryId":4,"access":{"favorite":true,"compare":true},"searchHash":"k3sz4qsbqrk4ow4cgggo08c0coc0sog","fromPage":"catalog","fromBlock":null}' href="/favorites/add/2024980964" title="Добавить в избранное и в сравнение"><i class="i js-favorites-add-icon i-favorites-big i-favorites_filled-blue" data-root-category-id="" data-state="empty"></i><span class="favorites-add__label pseudo-link js-favorites-add-label">В избранное</span></a></div></div>
# </div>
# <div class="item_table-wrapper">
# <div class="description item_table-description">
# <div class="snippet-title-row"><h3 class="snippet-title" data-shape="default"><a class="snippet-link" data-marker="item-title" href="/perm/kvartiry/3-k_kvartira_62_m_25_et._2024980964" itemprop="url" target="_blank" title="3-к квартира, 62 м², 2/5 эт. в Перми"><span class="snippet-link-name" itemprop="name">
#  3-к квартира, 62 м², 2/5 эт.
#  </span></a></h3></div> <div class="snippet-price-row"><span class="snippet-price " data-marker="item-price" data-shape="default" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer"><meta content="RUB" itemprop="priceCurrency"/><meta content="3050000" itemprop="price"/><meta content="https://schema.org/LimitedAvailability" itemprop="availability"/>
#  3 050 000  ₽
#   </span></div> <div><span class="snippet-badge " data-background-color="green200" data-font-weight="normal">Проверена в ЕГРН</span><span class="snippet-badge " data-background-color="gray8" data-font-weight="normal">Онлайн-показ</span></div> <div data-marker="item-address"><div class="item-address" data-shape="default"><div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span class="item-address__string">
#  ул. Льва Толстого, 33
#  </span><div class="item-address-georeferences"><span class="item-address-georeferences"><span class="item-address-georeferences-item"><span class="item-address-georeferences-item__content">р-н Индустриальный</span></span></span></div><meta content="Пермь" itemprop="addressLocality"/></div></div></div> <div class="snippet-date-row"><div class="snippet-date-info" data-marker="item-date" data-shape="default" data-tooltip="25 октября 15:09" flow="down">
#  23 минуты назад
# </div><div class="snippet-vas js-vas-list-container" data-props='{"vas":[{"title":"Продвинуто","link":"https:\/\/www.avito.ru\/performance?from=item_serp","slug":"x10_1"}]}' data-shape="default"></div></div>
# </div>
# <div class="item_table-aside"><div aria-orientation="vertical" class=" js-item_table-extended-contacts snippet-contacts item_table-extended-contacts item_table-extended-contacts_hidden item_table-extended-contacts_transparent "><div class="js-item-contacts-button item-extended-contacts" data-marker="item-contact" data-props='{"itemId":2024980964,"buttonText":"Показать телефон","searchHash":"k3sz4qsbqrk4ow4cgggo08c0coc0sog","fromBlock":0,"vsrc":"s","loginLink":"#login?authsrc=ps&amp;next=\/perm\/kvartiry\/3-k_kvartira_62_m_25_et._2024980964?showPhoneNumber","authLink":"#login?authsrc=ps","urlPath":"\/perm\/kvartiry\/3-k_kvartira_62_m_25_et._2024980964","signin":0,"hasCVPackage":0,"categoryRootId":4}' id="2024980964"><button class="button button-origin" style="padding: 6px 12px;">
#  Показать телефон
#  </button></div><div class="item-extended-contacts-messenger"><span class="js-messenger-button" data-marker="messenger-button" data-props='{"isOpenInNewTab":null,"isAuthorized":false,"isFullWidth":true,"isMiniMessenger":true,"isIconButton":null,"isHidden":true,"parentSelector":".item-with-contact","hasHidePhoneOnboarding":null,"sellerIdHash":null,"itemId":2024980964,"itemUrl":"\/perm\/kvartiry\/3-k_kvartira_62_m_25_et._2024980964","itemCVViewed":null,"categoryId":24,"buttonText":"Написать","replyTime":null,"logParams":{"wsrc":"s","s":"mi"},"experiments":[],"side":null,"contactlessView":null}' data-side=""><a class="button button-origin contactBar_blueColor button-origin_full-width" style="">
#  Написать
#  </a></span></div></div></div>
# </div>
# </div>
# </div>
# <div class="snippet snippet-horizontal snippet-xl snippet-redesign item-snippet-with-aside item item_table clearfix js-catalog-item-enum item-with-contact js-item-extended" data-context='{"stickyCatalogFilters":false,"snippetDevelopmentLink":false,"snippetRedesign":true,"sendPhoneFromEmployerToChat":{"enabled":false,"exposure":""},"newSnippetForCompare":false,"isReactCatalogSnippetEnabled":false,"imageAspectRatio":"4-3","verifiedBadgeRedesignRealty":null}' data-is-xl="" data-item-id="1850996084" data-marker="item" data-position="" id="i1850996084" itemscope="" itemtype="http://schema.org/Product"> <meta content="Продается полноценная 1-комнатная квартира в новом доме. Надежный застройщик, Аккредитован: Сбербанк, ВТБ, Райффайзен.
#
# Преимущества данного жилого комплекса:
#
# 1. Удачное месторасположение - Тихий Центр, рядом детский сад №195, школа №84, ТЦ «Март», маг..." itemprop="description"/> <div class="item__line">
# <div class="item-photo item-photo--4-3 item-photo_extended" data-marker="item-photo">
# <a class="item-slider item-slider--4-3" href="/perm/kvartiry/1-k_kvartira_37.8_m_56_et._1850996084" target="_blank"> <ul class="item-slider-list">
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="1-к квартира, 37.8 м², 5/6 эт." class="large-picture-img" src="https://68.img.avito.st/208x156/8460453768.jpg" srcset="https://68.img.avito.st/208x156/8460453768.jpg 1x, https://68.img.avito.st/image/1/VWBmRraD-YkQ6GuBQHs5D-_l_Y_e4_uPxuf7g9gl9hva5fuJ0qM 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="1-к квартира, 37.8 м², 5/6 эт." class="large-picture-img" src="https://36.img.avito.st/208x156/8460454336.jpg" srcset="https://36.img.avito.st/208x156/8460454336.jpg 1x, https://36.img.avito.st/image/1/HWAWRraDsYlg6COBIEJxD5_ltY-u47OPtuezg6glvhuq5bOJoqM 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="1-к квартира, 37.8 м², 5/6 эт." class="large-picture-img" src="https://26.img.avito.st/208x156/8460453826.jpg" srcset="https://26.img.avito.st/208x156/8460453826.jpg 1x, https://26.img.avito.st/image/1/H4lCmraDs2A0NCFocKZz5ss5t2b6P7Fm4juxavz5vPL-ObFg9n8 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="1-к квартира, 37.8 м², 5/6 эт." class="large-picture-img" src="https://26.img.avito.st/208x156/8460453126.jpg" srcset="https://26.img.avito.st/208x156/8460453126.jpg 1x, https://26.img.avito.st/image/1/2-ggjLaDdwFWIuUJGru3h6kvcweYKXUHgC11C57veJOcL3UBlGk 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="1-к квартира, 37.8 м², 5/6 эт." class="large-picture-img" src="https://32.img.avito.st/208x156/8460453132.jpg" srcset="https://32.img.avito.st/208x156/8460453132.jpg 1x, https://32.img.avito.st/image/1/0bMKrbaDfVp8A-9SJJq93IMOeVyyCH9cqgx_ULTOcsi2Dn9avkg 1.5x"/>
# </div>
# <div class="item-slider-more">
#  Ещё<br/>
#  3 фото
#   </div>
# </li>
# </ul>
# </a>
# <div class="small-photo-list"> <div> <img alt="1-к квартира, 37.8 м², 5/6 эт." src="https://36.img.avito.st/image/1/HWAWRraDsYlg6COBIEJxD5_ltY-u47OPtuezg6glvhuq5bOJoqM"/> </div> <div> <img alt="1-к квартира, 37.8 м², 5/6 эт." src="https://26.img.avito.st/image/1/H4lCmraDs2A0NCFocKZz5ss5t2b6P7Fm4juxavz5vPL-ObFg9n8"/> </div> </div>
# <div><div class="favorites-add is-design-simple js-favorites-add" data-marker="favorites-add" data-shape="default"><a class="favorites-add__link js-favorites-add-toggle" data-event-config='{"id":1850996084,"isFavorite":false,"categorySlug":"kvartiry","rootCategoryId":4,"access":{"favorite":true,"compare":true},"searchHash":"k3sz4qsbqrk4ow4cgggo08c0coc0sog","fromPage":"catalog","fromBlock":null}' href="/favorites/add/1850996084" title="Добавить в избранное и в сравнение"><i class="i js-favorites-add-icon i-favorites-big i-favorites_filled-blue" data-root-category-id="" data-state="empty"></i><span class="favorites-add__label pseudo-link js-favorites-add-label">В избранное</span></a></div></div>
# </div>
# <div class="item_table-wrapper">
# <div class="description item_table-description">
# <div class="snippet-title-row"><h3 class="snippet-title" data-shape="default"><a class="snippet-link" data-marker="item-title" href="/perm/kvartiry/1-k_kvartira_37.8_m_56_et._1850996084" itemprop="url" target="_blank" title="1-к квартира, 37.8 м², 5/6 эт. в Перми"><span class="snippet-link-name" itemprop="name">
#  1-к квартира, 37.8 м², 5/6 эт.
#  </span></a></h3></div> <div class="snippet-price-row"><span class="snippet-price " data-marker="item-price" data-shape="default" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer"><meta content="RUB" itemprop="priceCurrency"/><meta content="3100000" itemprop="price"/><meta content="https://schema.org/LimitedAvailability" itemprop="availability"/>
#  3 100 000  ₽
#   </span></div>
# <div aria-orientation="horizontal" class=" js-item_table-extended-contacts snippet-contacts item_table-extended-contacts item_table-extended-contacts_xl item_table-extended-contacts_hidden ">
# <div class="js-item-contacts-button item-extended-contacts" data-marker="item-contact" data-props='{"itemId":1850996084,"buttonText":"Показать телефон","searchHash":"k3sz4qsbqrk4ow4cgggo08c0coc0sog","fromBlock":1,"vsrc":"xs","loginLink":"#login?authsrc=ps&amp;next=\/perm\/kvartiry\/1-k_kvartira_37.8_m_56_et._1850996084?showPhoneNumber","authLink":"#login?authsrc=ps","urlPath":"\/perm\/kvartiry\/1-k_kvartira_37.8_m_56_et._1850996084","signin":0,"hasCVPackage":0,"categoryRootId":4}' id="1850996084" style="width: auto;"> <button class="button button-origin" style="padding: 6px 12px;">
#  Показать телефон
#  </button> </div>
# <div class="item-extended-contacts-messenger">
# <span class="js-messenger-button" data-marker="messenger-button" data-props='{"isOpenInNewTab":null,"isAuthorized":false,"isFullWidth":true,"isMiniMessenger":true,"isIconButton":null,"isHidden":true,"parentSelector":".item-with-contact","hasHidePhoneOnboarding":null,"sellerIdHash":null,"itemId":1850996084,"itemUrl":"\/perm\/kvartiry\/1-k_kvartira_37.8_m_56_et._1850996084","itemCVViewed":null,"categoryId":24,"buttonText":"Написать","replyTime":null,"logParams":{"wsrc":"xl","s":"mi"},"experiments":[],"side":null,"contactlessView":null}' data-side=""> <a class="button button-origin contactBar_blueColor button-origin_full-width" style="">
#  Написать
#  </a> </span>
# </div>
# </div>
# <div data-marker="item-address"><div class="item-address" data-shape="default"><div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span class="item-address__string">
#  ул. Решетникова, 18
#  </span><div class="item-address-georeferences"><span class="item-address-georeferences"><span class="item-address-georeferences-item"><span class="item-address-georeferences-item__content">р-н Дзержинский</span></span></span></div><meta content="Пермь" itemprop="addressLocality"/></div></div></div> <div><a class="item_table-extended-description item_table-extended-description_blurred" href="/perm/kvartiry/1-k_kvartira_37.8_m_56_et._1850996084" target="_blank">
#  Продается полноценная 1-комнатная квартира в новом доме. Надежный застройщик, Аккредитован: Сбербанк, ВТБ, Райффайзен.
#
# Преимущества данного жилого комплекса:
#
# 1. Удачное месторасположение - Тихий Центр, рядом детский сад №195, школа №84, ТЦ «Март», магазины ТС «Магнит», «Пятёрочка», поликлиника, аптеки, остановки общественного транспорта и все необходимое.
#
# 2. Наружные стены и стены между квартирами сложены из кирпича, что делает дом теплым и исключает проблемы с шумоизоляцией.
#
# 3. Автономная газовая котельная (коммунальные платежи на 30% дешевле аналогичных домов и нет отключений горячей воды).
#
# 4. Возможность добавить комнату, совместить квартиры или сделать перепланировку на этапе строительства.
#
# 5. Дизайнерская отделка холлов с использованием современных материалов и отделка квартир под чистовую.
#
# 6. Огороженная территория: «зелёная зона», детская игровая и места отдыха, эксплуатируемая крыша с зоной барбекю.
#
# 7. Подземный паркинг на 29 машиномест.
#
# 8. Ипотека БЕЗ первоначального взноса.
#
# Дополнительно:
#
# + Каждому клиенту подарок!
#
# + Экскурсии на стройку!
# </a></div> <div class="snippet-line-row"><a class="snippet-link" data-shape="default" href="/i69084029?gdlkerfdnwq=102&amp;shopId=148002&amp;page_from=from_items_list&amp;iid=1850996084" target="_blank">
#  АН Успех 59
# </a></div> <div class="snippet-date-row"><div class="snippet-date-info" data-marker="item-date" data-shape="default" data-tooltip="24 октября 22:11" flow="down">
#  17 часов назад
# </div><div class="snippet-vas js-vas-list-container" data-props='{"vas":[{"title":"Продвинуто","link":"https:\/\/www.avito.ru\/performance?from=item_serp","slug":"x10_7"},{"title":"XL","link":"https:\/\/support.avito.ru\/articles\/685","slug":"xl"}]}' data-shape="default"></div></div>
# </div>
# <div class="item_table-aside"><div class="item_table-user-logo-container"><a href="/i69084029?page_from=from_items_list_icon&amp;iid=1850996084"><img alt="Логотип" class="item_table-user-logo" src="//29.img.avito.st/user/logo/300x200/69084029_9396245569.jpg"/></a></div></div>
# </div>
# </div>
# </div>
# <div class="snippet snippet-horizontal snippet-redesign item-snippet-with-aside item item_table clearfix js-catalog-item-enum item-with-contact js-item-extended" data-context='{"stickyCatalogFilters":false,"snippetDevelopmentLink":false,"snippetRedesign":true,"sendPhoneFromEmployerToChat":{"enabled":false,"exposure":""},"newSnippetForCompare":false,"isReactCatalogSnippetEnabled":false,"imageAspectRatio":"4-3","verifiedBadgeRedesignRealty":null}' data-item-id="1974170366" data-marker="item" data-position="" id="i1974170366" itemscope="" itemtype="http://schema.org/Product"> <meta content="..." itemprop="description"/> <div class="item__line">
# <div class="item-photo item-photo--4-3 " data-marker="item-photo">
# <a class="item-slider item-slider--4-3" href="/perm/kvartiry/2-k_kvartira_60_m_1425_et._1974170366" target="_blank"> <ul class="item-slider-list">
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="2-к квартира, 60 м², 14/25 эт." class="large-picture-img" src="https://43.img.avito.st/208x156/9103492043.jpg" srcset="https://43.img.avito.st/208x156/9103492043.jpg 1x, https://43.img.avito.st/image/1/FpVMxraDunw6aCh0bOpal7llvnr0Y7h67Ge4dvKlte7wZbh8-CM 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="2-к квартира, 60 м², 14/25 эт." class="large-picture-img" src="https://17.img.avito.st/208x156/9103468217.jpg" srcset="https://17.img.avito.st/208x156/9103468217.jpg 1x, https://17.img.avito.st/image/1/ZGDZSraDyImv5FqBnXMVYizpzI9h78qPeevKg2cpxxtl6cqJba8 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="2-к квартира, 60 м², 14/25 эт." class="large-picture-img" src="https://88.img.avito.st/208x156/9103474088.jpg" srcset="https://88.img.avito.st/208x156/9103474088.jpg 1x, https://88.img.avito.st/image/1/dTigpLaD2dHWCkvZxvEEOlUH3dcYAdvXAAXb2x7H1kMcB9vRFEE 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="2-к квартира, 60 м², 14/25 эт." class="large-picture-img" src="https://57.img.avito.st/208x156/9103470057.jpg" srcset="https://57.img.avito.st/208x156/9103470057.jpg 1x, https://57.img.avito.st/image/1/NGD1SraDmImD5AqBkV5FYgDpnI9N75qPVeuag0splxtJ6ZqJQa8 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="2-к квартира, 60 м², 14/25 эт." class="large-picture-img" src="https://44.img.avito.st/208x156/9103471844.jpg" srcset="https://44.img.avito.st/208x156/9103471844.jpg 1x, https://44.img.avito.st/image/1/OdrSXraDlTOk8Ac7rC5I2Cf9kTVq-5c1cv-XOWw9mqFu_ZczZrs 1.5x"/>
# </div>
# <div class="item-slider-more">
#  Ещё<br/>
#  20 фото
#   </div>
# </li>
# </ul>
# </a>
# <div><div class="favorites-add is-design-simple js-favorites-add" data-marker="favorites-add" data-shape="default"><a class="favorites-add__link js-favorites-add-toggle" data-event-config='{"id":1974170366,"isFavorite":false,"categorySlug":"kvartiry","rootCategoryId":4,"access":{"favorite":true,"compare":true},"searchHash":"k3sz4qsbqrk4ow4cgggo08c0coc0sog","fromPage":"catalog","fromBlock":null}' href="/favorites/add/1974170366" title="Добавить в избранное и в сравнение"><i class="i js-favorites-add-icon i-favorites-big i-favorites_filled-blue" data-root-category-id="" data-state="empty"></i><span class="favorites-add__label pseudo-link js-favorites-add-label">В избранное</span></a></div></div>
# </div>
# <div class="item_table-wrapper">
# <div class="description item_table-description">
# <div class="snippet-title-row"><h3 class="snippet-title" data-shape="default"><a class="snippet-link" data-marker="item-title" href="/perm/kvartiry/2-k_kvartira_60_m_1425_et._1974170366" itemprop="url" target="_blank" title="2-к квартира, 60 м², 14/25 эт. в Перми"><span class="snippet-link-name" itemprop="name">
#  2-к квартира, 60 м², 14/25 эт.
#  </span></a></h3></div> <div class="snippet-price-row"><span class="snippet-price " data-marker="item-price" data-shape="default" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer"><meta content="RUB" itemprop="priceCurrency"/><meta content="5850000" itemprop="price"/><meta content="https://schema.org/LimitedAvailability" itemprop="availability"/>
#  5 850 000  ₽
#   </span></div> <div><span class="snippet-badge " data-background-color="gray8" data-font-weight="normal">Онлайн-показ</span></div> <div data-marker="item-address"><div class="item-address" data-shape="default"><div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span class="item-address__string">
#  ул. Чернышевского, 15А
#  </span><div class="item-address-georeferences"><span class="item-address-georeferences"><span class="item-address-georeferences-item"><span class="item-address-georeferences-item__content">р-н Свердловский</span></span></span></div><meta content="Пермь" itemprop="addressLocality"/></div></div></div> <div class="snippet-line-row"><span class="snippet-text" data-color="gray44" data-shape="default">
#  Агентство
# </span></div> <div class="snippet-date-row"><div class="snippet-date-info" data-marker="item-date" data-shape="default" data-tooltip="24 октября 11:20" flow="down">
#  1 день назад
# </div><div class="snippet-vas js-vas-list-container" data-props='{"vas":[{"title":"Продвинуто","link":"https:\/\/www.avito.ru\/performance?from=item_serp","slug":"x10_7"}]}' data-shape="default"></div></div>
# </div>
# <div class="item_table-aside"><div aria-orientation="vertical" class=" js-item_table-extended-contacts snippet-contacts item_table-extended-contacts item_table-extended-contacts_hidden item_table-extended-contacts_transparent "><div class="js-item-contacts-button item-extended-contacts" data-marker="item-contact" data-props='{"itemId":1974170366,"buttonText":"Показать телефон","searchHash":"k3sz4qsbqrk4ow4cgggo08c0coc0sog","fromBlock":0,"vsrc":"s","loginLink":"#login?authsrc=ps&amp;next=\/perm\/kvartiry\/2-k_kvartira_60_m_1425_et._1974170366?showPhoneNumber","authLink":"#login?authsrc=ps","urlPath":"\/perm\/kvartiry\/2-k_kvartira_60_m_1425_et._1974170366","signin":0,"hasCVPackage":0,"categoryRootId":4}' id="1974170366"><button class="button button-origin" style="padding: 6px 12px;">
#  Показать телефон
#  </button></div><div class="item-extended-contacts-messenger"><span class="js-messenger-button" data-marker="messenger-button" data-props='{"isOpenInNewTab":null,"isAuthorized":false,"isFullWidth":true,"isMiniMessenger":true,"isIconButton":null,"isHidden":true,"parentSelector":".item-with-contact","hasHidePhoneOnboarding":null,"sellerIdHash":null,"itemId":1974170366,"itemUrl":"\/perm\/kvartiry\/2-k_kvartira_60_m_1425_et._1974170366","itemCVViewed":null,"categoryId":24,"buttonText":"Написать","replyTime":null,"logParams":{"wsrc":"s","s":"mi"},"experiments":[],"side":null,"contactlessView":null}' data-side=""><a class="button button-origin contactBar_blueColor button-origin_full-width" style="">
#  Написать
#  </a></span></div></div></div>
# </div>
# </div>
# </div>
# <div class="snippet snippet-horizontal snippet-xl snippet-redesign item-snippet-with-aside item item_table clearfix js-catalog-item-enum item-with-contact js-item-extended" data-context='{"stickyCatalogFilters":false,"snippetDevelopmentLink":false,"snippetRedesign":true,"sendPhoneFromEmployerToChat":{"enabled":false,"exposure":""},"newSnippetForCompare":false,"isReactCatalogSnippetEnabled":false,"imageAspectRatio":"4-3","verifiedBadgeRedesignRealty":null}' data-is-xl="" data-item-id="1851375312" data-marker="item" data-position="" id="i1851375312" itemscope="" itemtype="http://schema.org/Product"> <meta content="Продается полноценная 2-х комн. квартира в новом доме. Надежный застройщик, Аккредитован: Сбербанк, ВТБ, Райффайзен.
#
# Преимущества данного жилого комплекса:
#
# 1. Удачное месторасположение - Тихий Центр, рядом детский сад №195, школа №84, ТЦ «Март», магаз..." itemprop="description"/> <div class="item__line">
# <div class="item-photo item-photo--4-3 item-photo_extended" data-marker="item-photo">
# <a class="item-slider item-slider--4-3" href="/perm/kvartiry/2-k_kvartira_57.9_m_26_et._1851375312" target="_blank"> <ul class="item-slider-list">
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="2-к квартира, 57.9 м², 2/6 эт." class="large-picture-img" src="https://33.img.avito.st/208x156/8452975933.jpg" srcset="https://33.img.avito.st/208x156/8452975933.jpg 1x, https://33.img.avito.st/image/1/4CByp7aDTMkECd7BPrD_NvoESM_KAk7P0gZOw8zEQ1vOBE7JxkI 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="2-к квартира, 57.9 м², 2/6 эт." class="large-picture-img" src="https://97.img.avito.st/208x156/8452976097.jpg" srcset="https://97.img.avito.st/208x156/8452976097.jpg 1x, https://97.img.avito.st/image/1/PKcK47aDkE58TQJGfvcjsYJAlEiyRpJIqkKSRLSAn9y2QJJOvgY 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="2-к квартира, 57.9 м², 2/6 эт." class="large-picture-img" src="https://80.img.avito.st/208x156/8452976080.jpg" srcset="https://80.img.avito.st/208x156/8452976080.jpg 1x, https://80.img.avito.st/image/1/DWsv27aDoYJZdTOKOc8Sfad4pYSXfqOEj3qjiJG4rhCTeKOCmz4 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="2-к квартира, 57.9 м², 2/6 эт." class="large-picture-img" src="https://25.img.avito.st/208x156/8452975925.jpg" srcset="https://25.img.avito.st/208x156/8452975925.jpg 1x, https://25.img.avito.st/image/1/6O99Z7aDRAYLydYOIXD3-fXEQADFwkYA3cZGDMMES5TBxEYGyYI 1.5x"/>
# </div>
# </li>
# <li class="item-slider-item">
# <div class="item-slider-image">
# <img alt="2-к квартира, 57.9 м², 2/6 эт." class="large-picture-img" src="https://69.img.avito.st/208x156/8205501969.jpg" srcset="https://69.img.avito.st/208x156/8205501969.jpg 1x, https://69.img.avito.st/image/1/zNwKT7aDYDV84fI9HnTSpoHsZDOy6mIzqu5iP7Qsb6e27GI1vqo 1.5x"/>
# </div>
# <div class="item-slider-more">
#  Ещё<br/>
#  3 фото
#   </div>
# </li>
# </ul>
# </a>
# <div class="small-photo-list"> <div> <img alt="2-к квартира, 57.9 м², 2/6 эт." src="https://97.img.avito.st/image/1/PKcK47aDkE58TQJGfvcjsYJAlEiyRpJIqkKSRLSAn9y2QJJOvgY"/> </div> <div> <img alt="2-к квартира, 57.9 м², 2/6 эт." src="https://80.img.avito.st/image/1/DWsv27aDoYJZdTOKOc8Sfad4pYSXfqOEj3qjiJG4rhCTeKOCmz4"/> </div> </div>
# ...
# </div> <div class="js-initial" data-state="{&quot;url&quot;:&quot;\/perm\/kvartiry&quot;,&quot;searchHash&quot;:&quot;k3sz4qsbqrk4ow4cgggo08c0coc0sog&quot;,&quot;subscription&quot;:{&quot;id&quot;:null,&quot;subscriber_id&quot;:null,&quot;visible&quot;:true},&quot;totalCount&quot;:7834,&quot;mainCount&quot;:7834,&quot;filterCount&quot;:7834,&quot;extraCount&quot;:&quot;&quot;,&quot;totalElements&quot;:7833,&quot;witchersCount&quot;:0,&quot;itemsOnPage&quot;:53,&quot;itemsOnPageMainSection&quot;:53,&quot;catalog&quot;:{&quot;views&quot;:{&quot;gallery&quot;:{&quot;title&quot;:&quot;Показать большие фото&quot;},&quot;default&quot;:{&quot;title&quot;:&quot;Выводить списком с фото&quot;,&quot;alias&quot;:&quot;table&quot;}},&quot;sortDefault&quot;:101,&quot;sorts&quot;:[{&quot;value&quot;:101,&quot;titles&quot;:{&quot;default&quot;:&quot;По умолчанию&quot;}},{&quot;value&quot;:1,&quot;titles&quot;:{&quot;default&quot;:&quot;Дешевле&quot;,&quot;job&quot;:&quot;Меньше з\/п&quot;}},{&quot;value&quot;:2,&quot;titles&quot;:{&quot;default&quot;:&quot;Дороже&quot;,&quot;job&quot;:&quot;Больше з\/п&quot;}},{&quot;value&quot;:104,&quot;titles&quot;:{&quot;default&quot;:&quot;По дате&quot;}}],&quot;loading&quot;:false,&quot;blocks&quot;:[&quot; \n&lt;div class=\&quot;snippet-list\&quot; data-marker=\&quot;catalog-serp\&quot; style=\&quot;display: flex; flex-wrap: wrap; padding-top: 16px;\&quot;&gt;\n         &lt;div class=\&quot;avito-ads-container avito-ads-container_context_1 catalog-ads-banner\&quot;&gt; &lt;div id=\&quot;template_context_1\&quot; class=\&quot;avito-ads-template\&quot;&gt; &lt;div class=\&quot; avito-ads-content\&quot;&gt; &lt;\/div&gt; &lt;\/div&gt; &lt;\/div&gt;\n                                \n&lt;div class=\&quot;snippet snippet-horizontal  snippet-redesign  item-snippet-with-aside item item_table clearfix js-catalog-item-enum item-with-contact js-item-extended\&quot;\n itemscope\n itemtype=\&quot;http:\/\/schema.org\/Product\&quot;\n id=\&quot;i2024980964\&quot;\n data-item-id=\&quot;2024980964\&quot;\n data-position=\&quot;\&quot;\n  data-marker=\&quot;item\&quot;\n data-context=\&quot;&amp;#x7B;&amp;quot;stickyCatalogFilters&amp;quot;&amp;#x3A;false,&amp;quot;snippetDevelopmentLink&amp;quot;&amp;#x3A;false,&amp;quot;snippetRedesign&amp;quot;&amp;#x3A;true,&amp;quot;sendPhoneFromEmployerToChat&amp;quot;&amp;#x3A;&amp;#x7B;&amp;quot;enabled&amp;quot;&amp;#x3A;false,&amp;quot;exposure&amp;quot;&amp;#x3A;&amp;quot;&amp;quot;&amp;#x7D;,&amp;quot;newSnippetForCompare&amp;quot;&amp;#x3A;false,&amp;quot;isReactCatalogSnippetEnabled&amp;quot;&amp;#x3A;false,&amp;quot;imageAspectRatio&amp;quot;&amp;#x3A;&amp;quot;4-3&amp;quot;,&amp;quot;verifiedBadgeRedesignRealty&amp;quot;&amp;#x3A;null&amp;#x7D;\&quot;\n&gt; &lt;meta itemprop=\&quot;description\&quot; content=\&quot;...\&quot; \/&gt; &lt;div class=\&quot;item__line\&quot;&gt;\n  &lt;div\n class=\&quot;item-photo item-photo--4-3 \&quot;\n data-marker=\&quot;item-photo\&quot;&gt;\n        \n&lt;a class=\&quot;item-slider item-slider--4-3\&quot; href=\&quot;\/perm\/kvartiry\/3-k_kvartira_62_m_25_et._2024980964\&quot; target=\&quot;_blank\&quot;&gt; &lt;ul class=\&quot;item-slider-list\&quot;&gt;\n  \n &lt;li class=\&quot;item-slider-item\&quot;&gt;\n    \n &lt;div class=\&quot;item-slider-image\&quot; &gt;\n    &lt;img srcset=\&quot;https:\/\/02.img.avito.st\/208x156\/9643552302.jpg 1x, https:\/\/02.img.avito.st\/image\/1\/85DwGbaDX3mGt81xmgK6lwG6W39IvF1_ULhdc056UOtMul15RPw 1.5x\&quot; src=\&quot;https:\/\/02.img.avito.st\/208x156\/9643552302.jpg\&quot; class=\&quot;large-picture-img\&quot; alt=\&quot;3-к квартира, 62 м², 2\/5 эт.\&quot;&gt;\n   &lt;\/div&gt;\n  &lt;\/li&gt;\n  \n &lt;li class=\&quot;item-slider-item\&quot;&gt;\n    \n &lt;div class=\&quot;item-slider-image\&quot; &gt;\n    &lt;img srcset=\&quot;https:\/\/34.img.avito.st\/208x156\/9643552434.jpg 1x, https:\/\/34.img.avito.st\/image\/1\/b1_dBLaDw7arqlG-jx0mWCynx7BlocGwfaXBvGNnzCRhp8G2aeE 1.5x\&quot; src=\&q ...
# <div class="counters-invisible" id="counters-invisible">
# <noscript> <img alt="" src="/stat/u?1603621953"/> </noscript>
# <script>
#
#  if (window.devicePixelRatio > 1) {
#  avito.tracking.trackGTMEvent('tracking', 'retina', 'catalog');
#  }
#   </script>
# <script>
#          if (avito.tracking && avito.tracking.initCriteo) {
#  var isRealty = true;
#  avito.tracking.initCriteo(isRealty ? [10019, 39534] : 39534, 0, "");
#  }
#                                                                                                                                       avito.tracking.trackCriteo({
#  event: "viewList",
#  avito: "1",
#  item: ['2024980964','1850996084','1974170366'],
#  keywords: ""
#  });
#
#  var _comscore = _comscore || [];
#  _comscore.push({ c1: "2", c2: "9829393", c4: document.location.href, c5: "nedvizhimost" });
#  (function() {
#  var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#  s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#  el.parentNode.insertBefore(s, el);
#  })();
#
# </script>
# <noscript> <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=9829393&amp;cv=2.0&amp;c4=avito.ru/perm/kvartiry&amp;c5=nedvizhimost&amp;cj=1"/> </noscript>
# <script>
#  var img = new Image();
#  img.src = '//www.tns-counter.ru/V13a***R>' + document.referrer.replace(/\*/g,'%2a') + '*avito_ru/ru/CP1251/tmsec=avito_4-24/' + Math.round(Math.random() * 1000000000);
#  </script> <noscript><img alt="" height="1" src="//www.tns-counter.ru/V13a****avito_ru/ru/CP1251/tmsec=avito_4-24/" width="1"/></noscript>
# <script type="text/javascript">
#  window.avito = window.avito || {};
# </script>
# <!-- Yandex.Metrika counter --> <script>
#  (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#  m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#  (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#  ym(34241905, "init", {
#  id:34241905,
#   webvisor:true,
#   clickmap:true,
#  trackLinks:true,
#  accurateTrackBounce:true,
#  ecommerce:"dataLayer",
#  params: {
#  abFeatures: {"ad_splitter":"one","criteo_push_recommendations":"push_more_auto","geo_multilocations_and_local_priority":"test","marketplace_office":"test","marketplace_witcher":"control","desktop_state_filter_spareparts":"control","web_realty_consultation_form":"test_new_teaser"}
#  }
#  });
#  </script> <noscript><div><img alt="" src="https://mc.yandex.ru/watch/34241905" style="position:absolute; left:-9999px;"/></div></noscript> <!-- /Yandex.Metrika counter -->
# <script>var google_conversion_id=987009030,google_conversion_label="f8JaCLLjvAQQhqDS1gM",google_custom_params=window.google_tag_params,google_remarketing_only=!0;</script><script src="//www.googleadservices.com/pagead/conversion.js"></script> <noscript> <div style="display:inline;"> <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/987009030/?value=0&amp;label=f8JaCLLjvAQQhqDS1gM&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/> </div> </noscript>
# </div>
# <script async="" src="https://static.avito.ru/s/cc/bundles/4c7c3069011c1f129b36.js"></script>
# <input class="js-token" name="token[7028594374186]" type="hidden" value="48ceadedaac7742b"/>
# <div data-captcha-enabled="1" id="js-auth"> </div>
# <script src="https://static.avito.ru/deps/object-assign/4.1.1/prod/web/main.js"></script>
# <script src="https://static.avito.ru/deps/react/16.14.0/prod/web/main.js"></script>
# <script src="https://static.avito.ru/deps/prop-types/15.7.2/prod/web/main.js"></script>
# <script src="https://static.avito.ru/deps/redux/3.7.2/prod/web/main.js"></script>
# <script src="https://static.avito.ru/deps/redux/4.0.5/prod/web/main.js"></script>
# <script src="https://static.avito.ru/deps/react-is/16.13.1/prod/web/main.js"></script>
# <script src="https://static.avito.ru/deps/react-redux/4.4.10/prod/web/main.js"></script>
# <script src="https://static.avito.ru/deps/redux-thunk/2.3.0/prod/web/main.js"></script>
# <script src="https://static.avito.ru/deps/redux-dynamic/1.3.0/prod/web/main.js"></script>
# <script src="https://static.avito.ru/deps/scheduler/0.19.1/prod/web/main.js"></script>
# <script src="https://static.avito.ru/deps/react-dom/16.14.0/prod/web/main.js"></script>
# <script src="https://static.avito.ru/deps/react-popper/1.3.7/prod/web/main.js"></script>
# <script src="https://static.avito.ru/s/cc/chunks/be13086b.3646ef24ee67eae5db54.js"></script>
# <script src="https://static.avito.ru/s/cc/chunks/vendors~c6cf528e4501db21b258d7132506b957.50f0c68bc57605977cd4.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/217f747d992371a6fde0.js"></script>
# <script src="https://static.avito.ru/s/cc/chunks/vendors~a2d3cceca3b7a99aec402f4274daae86~b6c9dd376cf6242aa66aaf78a98e7cd5.74fdc8ed56eaf4c6ee93.js"></script>
# <script src="https://static.avito.ru/s/cc/chunks/vendors~b6c9dd376cf6242aa66aaf78a98e7cd5.6f1541dd9ac435715f98.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/b652660cc6c21ba21ffe.js"></script>
# <script src="https://static.avito.ru/s/cc/chunks/vendors~3aed0e1873f8a9e1501f0b0b51f4c086~91ac0639b450d3cf68aad1b462aa0300~96d322aa0de504f4cdc0ae9171~55a3c65c.49fb280a935eb5753ca7.js"></script>
# <script src="https://static.avito.ru/s/cc/chunks/default~38519037017eb3cb5ae72302e7595f19~5f5005ad3a3dfe086995859dee051424~a89dd147e58ea6b41032c8d371~ec3f4300.7480c416fc4ccae82b42.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/12a2fa08d3b84b3f3b25.js"></script>
# <script src="https://static.avito.ru/s/cc/chunks/96d8cd34.51e923fef2fdc38dda15.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/3b2ebacaa6bb92695d7a.js"></script>
# <script src="https://static.avito.ru/s/cc/bundles/1655e39be94badb0a2b5.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/bundles/24c716a53999d6937f04.js"></script>
# <link href="https://static.avito.ru/s/cc/styles/b4b8fb61231c24858c45.css" rel="stylesheet"/>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/a9dc1428.1c4021c20ee05392add2.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/9a8675f3.bd275fc9b658d10b626b.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/5f944669.2e1173fc7e9a11fa21dc.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/0f3357d6.7b8daeaf79d7a44b0194.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/4f9028be.735f6140005c820a2f2e.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/3469bcc8.f3720245a13424dd1d55.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/1fa346e0.ca21d253a209df08746d.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/a913361c.b03da23f3d71707d337a.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/e47baf8f.7297e1cee13a71d71ff3.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/09dfc480.11989ab174abfe94f8e1.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/vendors~05997dc839760da95e5a11d1fcb9da88~07ce5f9bded6d08b1fdb133a5dfd4885~0c5d337047be3bf395777dff81~503358e0.82c47b66bd85078aa586.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/vendors~0e64b76b3446c1c95780ebc1890b939e~5aa90e2bf60006d0742b1399d0f956e0~a70b94198d2efc235cb54930bb~8a35fc96.0ad2be18a2ddf138b30f.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/vendors~7dbec08b0546735fe1c2719a0c9662e2~a70b94198d2efc235cb54930bbb0e31f~e63b84e38302914e58e1259bd8f186de.b938435a32c0b9705e5a.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/vendors~a70b94198d2efc235cb54930bbb0e31f.5bff4ef085265123c31c.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/bundles/aada8ea5553a04025f92.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/vendors~0b9da262037d874fa7955d225c994702~0c5d337047be3bf395777dff811bf840~0cfd78a1f3e9f8e1dcd0b25040~5da7a282.f94024aea784e9a261af.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/1f73b7f3.f895b219690c77294864.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/vendors~0c5d337047be3bf395777dff811bf840~350ee0a4aed09600712140245cd11992~5ef46a324c9c3373666087a509~ecf525af.c457470e8f0e9c17f05c.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/bundles/ee4b788fe18553568263.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/bundles/b80bdb50a65ba15505a0.js"></script>
# <link href="https://static.avito.ru/s/cc/styles/8f82cc85e4dec8aaa815.css" rel="stylesheet"/>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/2eec4440.6e1c3a7861d8c52ee274.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/e9a3001f.9b7a0b955c79bbd3c16c.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/vendors~0cfd78a1f3e9f8e1dcd0b2504003e7bd~0f064ddc38b7a5b791f790d828360f30~37768e0bd634f81c028c8dc30f~dd28bfaf.68ad32624f065514fdeb.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/vendors~0cfd78a1f3e9f8e1dcd0b2504003e7bd~0f064ddc38b7a5b791f790d828360f30~37768e0bd634f81c028c8dc30f~a053cdac.9a291adeb191884011cd.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/bundles/8efee03e608fed1ba077.js"></script>
# <link href="https://static.avito.ru/s/cc/styles/983fdf3a28aaee9506e0.css" rel="stylesheet"/>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/vendors~1b2b00a60cd03ffec338ef0b0ac78b8e~31040a7aac027533fb02471c77e63023~486d24a3aceca04572b63c1bde~13ea71c7.97bc0d7d9448518f0983.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/vendors~31040a7aac027533fb02471c77e63023~486d24a3aceca04572b63c1bde2f93e3~4c8f84c8026041b236b200a341~03e516d0.6c5a0020813fca2557c4.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/vendors~3bc3062e9edbad2b932d96427bacf10a~5191117a65427069c807d3eac26ba3b6~e9ca99295207711eae7f0cad6f22d9d8.d0fa42a9aac7f6a03020.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/chunks/default~5191117a65427069c807d3eac26ba3b6~e9ca99295207711eae7f0cad6f22d9d8.2b3bf5ec17969fdf02aa.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/bundles/f7aaf8c992fd2d79c585.js"></script>
# <script defer="" src="https://static.avito.ru/@avito/bx-single-page-catalog/2.327.0/prod/web/bundles/62af768f180bf1c86951.js"></script>
# <script defer="" src="https://static.avito.ru/s/cc/bundles/e69eb3f48ae6f3355861.js"></script>
# <script>
#     (function(apps) {
#         for (var key in apps) {
#             if (!apps.hasOwnProperty(key)) {
#                 continue;
#             }
#
#             var app = apps[key];
#
#             if (
#                 avito &&
#                 avito.bundles &&
#                 avito.bundles[app.name] &&
#                 avito.bundles[app.name][app.version] &&
#                 typeof avito.bundles[app.name][app.version].render === 'function'
#             ) {
#                 render = avito.bundles[app.name][app.version].render;
#
#                 app.instances.forEach(function(instance) {
#                     var mountNode = document.querySelector('.' + instance.selector);
#
#                     var props = {};
#
#                     try {
#                         props = JSON.parse(instance.props);
#                     } catch(error) {
#                         console.error('Failed to parse instance.props', error);
#                     }
#
#                     render(mountNode, props);
#                 });
#             }
#         };
#     })({"bx-single-page-catalog":{"name":"@avito\/bx-single-page-catalog","version":"2.327.0","instances":[]}});
# </script><img alt="" height="1" src="https://redirect.frontend.weborama.fr/rd?url=https%3A%2F%2Fwww.avito.ru%2Fadvertisement%2Fweborama.gif%3Fwebouuid%3D{WEBO_CID}" width="1"/></body> </html>

# %% [markdown]
# ### Расширение SelectorGadget в Chrome
# Кликаем по необходимой информации на сайте, получаем CSS-селектор для выбранного элемента

# %%
selector = '.js-item-extended'
for item in page.select(selector):
    print(item.select('.snippet-title-row')[0].text.strip())
    print('--------')
# Out:
# 3-к квартира, 62 м², 2/5 эт.
# --------
# 1-к квартира, 37.8 м², 5/6 эт.
# --------
# 2-к квартира, 60 м², 14/25 эт.
# --------
# 2-к квартира, 57.9 м², 2/6 эт.
# --------
# 1-к квартира, 42 м², 1/16 эт.
# --------
# 2-к квартира, 70 м², 12/25 эт.
# --------
# 1-к квартира, 31 м², 4/5 эт.
# --------
# 2-к квартира, 43 м², 5/5 эт.
# --------
# 3-к квартира, 70 м², 9/10 эт.
# --------
# 1-к квартира, 38.2 м², 1/2 эт.
# --------
# 2-к квартира, 42.7 м², 5/5 эт.
# --------
# 2-к квартира, 41 м², 1/6 эт.
# --------
# 2-к квартира, 44 м², 4/5 эт.
# --------
# 5-к квартира, 160.2 м², 16/16 эт.
# --------
# 3-к квартира, 60 м², 4/5 эт.
# --------
# 4-к квартира, 107.2 м², 13/17 эт.
# --------
# 2-к квартира, 100 м², 6/10 эт.
# --------
# 1-к квартира, 35 м², 21/25 эт.
# --------
# 1-к квартира, 35 м², 6/25 эт.
# --------
# 2-к квартира, 44.3 м², 5/5 эт.
# --------
# 1-к квартира, 42 м², 7/10 эт.
# --------
# 1-к квартира, 42 м², 4/16 эт.
# --------
# 2-к квартира, 60 м², 4/4 эт.
# --------
# 1-к квартира, 56 м², 9/25 эт.
# --------
# 1-к квартира, 18 м², 5/5 эт.
# --------
# 1-к квартира, 56 м², 18/25 эт.
# --------
# 2-к квартира, 43 м², 5/5 эт.
# --------
# 4-к квартира, 73 м², 1/2 эт.
# --------
# Квартира-студия, 24.5 м², 11/25 эт.
# --------
# 4-к квартира, 127.5 м², 8/22 эт.
# --------
# 3-к квартира, 73.4 м², 16/23 эт.
# --------
# 2-к квартира, 46 м², 16/25 эт.
# --------
# 3-к квартира, 73.6 м², 9/23 эт.
# --------
# 3-к квартира, 79.4 м², 11/23 эт.
# --------
# 3-к квартира, 79.5 м², 4/23 эт.
# --------
# 3-к квартира, 60.8 м², 5/5 эт.
# --------
# 3-к квартира, 73.7 м², 4/23 эт.
# --------
# 1-к квартира, 27.6 м², 5/5 эт.
# --------
# 3-к квартира, 79.3 м², 16/23 эт.
# --------
# 3-к квартира, 73.6 м², 3/23 эт.
# --------
# 3-к квартира, 73.6 м², 4/23 эт.
# --------
# 3-к квартира, 107 м², 2/16 эт.
# --------
# 1-к квартира, 40 м², 7/25 эт.
# --------
# 4-к квартира, 210 м², 15/16 эт.
# --------
# 3-к квартира, 78 м², 6/25 эт.
# --------
# 3-к квартира, 77 м², 3/3 эт.
# --------
# 1-к квартира, 40 м², 8/25 эт.
# --------
# 2-к апартаменты, 38 м², 2/16 эт.
# --------
# 2-к квартира, 36.9 м², 10/16 эт.
# --------
# 3-к квартира, 61.7 м², 4/5 эт.
# --------
# 3-к квартира, 62.6 м², 10/10 эт.
# --------
# 2-к квартира, 47.2 м², 5/5 эт.
# --------
# 1-к квартира, 45 м², 5/25 эт.
# --------

# %% [markdown]
# ### Использование библиотеки Selenium для парсинга

# %%
from selenium.webdriver import Chrome
from time import sleep

# In this directory the following file https://chromedriver.storage.googleapis.com/index.html?path=78.0.3904.105/
# chromedriver_win32.zip -> chromedriver.exe
browser = Chrome('chromedriver.exe')
browser.get('https://www.avito.ru/')

# %%
search = browser.find_element_by_css_selector('#search')
search.clear()
search.send_keys('Тойота')
button = browser.find_element_by_css_selector('.button-default-mSfac')
button.click()

# %%
page = BeautifulSoup(browser.page_source, 'html.parser')
